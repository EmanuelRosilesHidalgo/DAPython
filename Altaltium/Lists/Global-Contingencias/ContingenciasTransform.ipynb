# %%
import pandas as pd
import re
import unicodedata
import json
from fuzzywuzzy import process

# %%
csv_file_path = 'LISTAS VIGENTES\MONESIS GLOBAL CONTINGENCIAS AGOSTO 2024.csv'

# %%
try:
    df = pd.read_csv(csv_file_path, encoding='utf-8', delimiter=";")
except UnicodeDecodeError:
    df = pd.read_csv(csv_file_path, encoding='latin1', delimiter=";")

df.dropna(how='all', inplace=True)

# %%
df.columns = df.columns.str.strip()
df.columns
# Out:
# Index(['ID', 'PRESTAMO', 'VEHICULO', 'FECHA DE ULT ACT', 'NOMBRE',
#        'CONTINGENCIA', 'IRRECUPERABLES', 'DICTAMEN DE IRRECUPERABILIDAD',
#        'CONSOLIDADO', 'MACRO ETAPA ACTUALIZADA', 'MICRO ETAPA ACTUALIZADA',
#        'EXPEDIENTE', 'JUZGADO', 'PLAZA JURISDICCION', 'ESTADO JURISDICCION',
#        'DESPACHO', 'SALDO INFONAVIT ACTUALIZADO', 'COFI',
#        'AVALUO ORIGINAL_ORG', 'AVALUO REFERENCIA_ACT', 'MONEDA', 'GTIA_EDO',
#        'GTIA_MPIO', 'GTIA_COLONIA', 'GTIA_UBICACION', 'GTIA_CODPOSTAL',
#        'M2 TERRENO', 'M2 CONSTRUCCION', 'FECHA ORIGEN',
#        'IMPORTE CONCEDIDO VALORIZADO', 'CAPITAL ACT', 'INT ORD ACT',
#        'SDO CONT ACT', 'INT MOR + ACC ACT', 'ADEUD TOT ACT',
#        'Precio individual nuevo', 'Precio Mejorado paquete nuevo'],
#       dtype='object')

# %%
def rename_columns(df):

    df_renamed = df.rename(columns={
        'ID': 'FOLIO',
        'MICRO ETAPA ACTUALIZADA': 'ETAPA',
        'GTIA_EDO': 'ESTADO',
        'GTIA_MPIO': 'MUNICIPIO',
        'GTIA_COLONIA': 'COLONIA',
        'GTIA_UBICACION': 'CALLE_Y_NUMERO',
        'GTIA_CODPOSTAL': 'CP',
        'M2 CONSTRUCCION': 'CONSTRUCCION',
        'M2 TERRENO': 'TERRENO',
        'Precio individual nuevo': '2DO_PAGO'
    })
    return df_renamed

def add_columns(df):
    df["LISTA"] = "MONESIS GLOBAL"

    return df


df = rename_columns(df)
df = df.apply(add_columns, axis=1)

# %% [markdown]
# <h3>LIMPIEZA DE NUMEROS</h3>

# %%
def number_cleaning(df):
    # Limpiar caracteres no numéricos en 'FOLIO' y 'CP'
    df["FOLIO"] = df["FOLIO"].replace({r'\D': ''}, regex=True)
    df["CP"] = df["CP"].replace({r'\D': ''}, regex=True)

    # Convertir a números, manejando errores y valores no convertibles
    df["FOLIO"] = pd.to_numeric(df["FOLIO"], errors='coerce')
    df["CP"] = pd.to_numeric(df["CP"], errors='coerce')

    # Rellenar valores NaN con 0 y convertir a enteros
    df["FOLIO"] = df["FOLIO"].fillna(0).astype(int)
    df["CP"] = df["CP"].fillna(0).astype(int)

    # Limpiar caracteres en '2DO_PAGO' y convertir a float
    df["2DO_PAGO"] = df["2DO_PAGO"].replace({r'\$': '', ',': ''}, regex=True)
    df["2DO_PAGO"] = pd.to_numeric(df["2DO_PAGO"], errors='coerce')  # Convertir a float

    return df

df = number_cleaning(df)

# %% [markdown]
# <h3>LIMPIEZA DE TEXTO</h3>

# %%
from word2number_es import w2n

def remove_punctuation(text):
    if isinstance(text, str):
        clean = re.sub(r'[\-:;]', ' ', text)
        clean_spaces = ' '.join(clean.split())
        return clean_spaces
    
    return text

"""def safe_word_to_number(text):
    if isinstance(text, str):
        try:
            return word_to_number(text)
        except RecursionError:
            return text
    return text"""

df["COLONIA"] = df["COLONIA"].apply(remove_punctuation)
df["CALLE_Y_NUMERO"] = df["CALLE_Y_NUMERO"].apply(remove_punctuation)
df["MUNICIPIO"] = df["MUNICIPIO"].apply(remove_punctuation)
df["ESTADO"] = df["ESTADO"].apply(remove_punctuation)

# %% [markdown]
# <h3>NORMALIZAR DIRECCIONES</h3>

# %%
def normalizar_direccion(df):
    direccion = df["CALLE_Y_NUMERO"]
    # Asegurarse de que la dirección no sea NaN
    if pd.isna(direccion):
        return ''
    
    # Eliminar las comas
    direccion = direccion.replace(',', '')
    
    # Añadir espacio antes y después de números cuando no haya espacio
    direccion = re.sub(r'(?<=\D)(?=\d)', ' ', direccion)
    direccion = re.sub(r'(?<=\d)(?=\D)', ' ', direccion)
    
    # Añadir punto a "ESQ" solo si no lo tiene
    direccion = re.sub(r'\bESQ\b(?!\.)', 'ESQ.', direccion, flags=re.IGNORECASE)
    
    # Reemplazar comillas dobles con comillas simples o eliminarlas
    direccion = direccion.replace('""', '"')
    direccion = direccion.replace('"', '')
    
    # Normalizar caracteres Unicode
    direccion = unicodedata.normalize('NFKC', direccion)
    
    # Reemplazar abreviaturas específicas, considerando todas las combinaciones de mayúsculas y minúsculas
    direccion = re.sub(r'\bNUM\. EXT\.\b', '', direccion, flags=re.IGNORECASE)  # Eliminar "NUM. EXT."
    direccion = re.sub(r'\s*\.\s*', ' ', direccion)
    direccion = re.sub(r'\bEXT\b', '', direccion, flags=re.IGNORECASE)  # Eliminar "NUM. EXT."
    direccion = re.sub(r'\bEXT\. \b', '', direccion, flags=re.IGNORECASE)  # Eliminar "NUM. EXT."
    direccion = re.sub(r'\bNUM\.\b', '', direccion, flags=re.IGNORECASE)  # Eliminar "NUM."
    direccion = re.sub(r'\bEXT\.\b', '', direccion, flags=re.IGNORECASE)  # Eliminar "NUM."
    direccion = re.sub(r'\bNUM\b', '', direccion, flags=re.IGNORECASE)  # Eliminar "NUM."
    direccion = re.sub(r'\bNUMERO\b', '', direccion, flags=re.IGNORECASE)  # Eliminar "NUMERO"
    direccion = re.sub(r'\bOf\b', '', direccion, flags=re.IGNORECASE)  # Eliminar "NUMERO"
    direccion = re.sub(r'\bNo\b', '', direccion, flags=re.IGNORECASE)  # Eliminar "NUMERO"
    direccion = re.sub(r'\bNUMERO\b', '', direccion, flags=re.IGNORECASE)  # Eliminar "NUMERO"
    direccion = re.sub(r'\bNUM\. INT\b', '', direccion, flags=re.IGNORECASE)  # Eliminar "NUM. INT"
    direccion = re.sub(r'\bLt\b', 'Lote', direccion, flags=re.IGNORECASE)  # Reemplazar "Lt." por "Lote"
    direccion = re.sub(r'\bL\.T\.\b', 'Lote', direccion, flags=re.IGNORECASE)  # Reemplazar "L.T." por "Lote"
    direccion = re.sub(r'\bLote\b', 'Lote', direccion, flags=re.IGNORECASE)  # Reemplazar "Lote" sin abreviatura
    direccion = re.sub(r'\bMZA\b', 'Manzana', direccion, flags=re.IGNORECASE)  # Reemplazar "Mza." por "Manzana"
    direccion = re.sub(r'\bM\.Z\.A\.\b', 'Manzana', direccion, flags=re.IGNORECASE)  # Reemplazar "M.Z.A." por "Manzana"
    direccion = re.sub(r'\bManzana\b', 'Manzana', direccion, flags=re.IGNORECASE)  # Reemplazar "Manzana" sin abreviatura
    
    # Reemplazar abreviaturas de calles
    direccion = re.sub(r'\bCalle\b', '', direccion, flags=re.IGNORECASE)  # Eliminar "Calle"
    direccion = re.sub(r'\bAv\.?\b', 'Avenida', direccion, flags=re.IGNORECASE)  # Reemplazar "Av." por "Avenida"
    
    # Reemplazar cualquier " - " o " . " por un espacio simple
    direccion = re.sub(r'\s*-\s*', ' ', direccion)
    direccion = re.sub(r'\s*\.\s*', ' ', direccion)
    # Asegurar que los espacios múltiples sean reducidos a uno solo
    direccion = re.sub(r'\s+', ' ', direccion).strip()
    
    return df

# %%
# Diccionario de abreviaturas
abbreviations = {
    'C.P': 'Código Postal',
    'CP': 'Código Postal',

    'MZ': 'Manzana',
    'MZA': 'Manzana',
    'M': 'Manzana',

    'SM': 'Supermanzana',
    'S.M': 'Supermanzana',

    'U. H.': 'Unidad habitacional',

    'LTE': 'Lote',
    'L': 'Lote',

    'C': 'Calle',
    'CALL': 'Calle',

    'NUM': 'Número',
    'NÚM': 'Número',
    "NO": "Número",


    'AV': 'Avenida',
    'AVE': 'Avenida',

    'BLVD': 'Boulevard',

    'PL': 'Plaza',

    'PARQ': 'Parque',

    'EDIF': 'Edificio',

    'DEPTO': 'Departamento',

    'UNID': 'Unidad',

    'CIRC': "Circuito",

    "HDA": "Hacienda",

    "ED": "Edificio",

    "DEP": "Departamento",
    "DPTO": "Departamento",

    "FRAC": "Fraccionamiento",
    "FRACC": "Fraccionamiento",

    "EXT": "Exterior",

    "INT": "Interior",

    "VIV": "Vivienda",

    "COL": "Colonia"

}

# Función para limpiar direcciones
def clean_street(df):
    street = df["CALLE_Y_NUMERO"]
    street = str(street).upper()
    
    for abbreviation, full_form in abbreviations.items():
        # Usar expresión regular para reemplazar abreviaturas con o sin punto al final
        pattern = r'\b' + re.escape(abbreviation) + r'\b\.?'
        street = re.sub(pattern, full_form, street, flags=re.IGNORECASE)
    
    # Opcional: Eliminar dobles espacios resultantes de reemplazos
    street = ' '.join(street.split())
    df["CALLE_Y_NUMERO"] = street
    
    return df

# %%
df_inegi = pd.read_csv("INEGI.csv", delimiter=",")
df_inegi
def get_location(df):
    # Extract information from the row
    cp = df['CP']  # Postal Code
    #street = row['Dirección']  # Street name
    district = df['COLONIA']  # District
    municipality = df['MUNICIPIO']  # Municipality
    state = df['ESTADO']  # State

    if pd.notna(cp):
        cp = str(cp).zfill(5)
    
    df['CP'] = int(cp)
    
    # Filter the dataset to get data related to the Postal Code
    df_info_cp = df_inegi[df_inegi["cp"] == int(cp)]
    if df_info_cp.empty:
        df["CP"] = "Revisar CP " + cp
    else:        
        # Get lists for comparison
        list_district = df_info_cp["colonia"].tolist()
        list_municipality = df_info_cp["municipio"].tolist()
        list_state = df_info_cp["estado"].tolist()


        if pd.notna(district) and pd.notna(municipality) and pd.notna(state):
            municipality_match, percentage = process.extractOne(municipality, list_municipality)
            if percentage < 50:  # Conditional to match the CP with the municipality based on text similarity
                district_match = process.extractOne(district, list_district)
                state_match = process.extractOne(state, list_state)
                df['COLONIA'] = "REVISAR "+district_match[0]
                df['MUNICIPIO'] = "REVISAR "+municipality_match
                df['ESTADO'] = "REVISAR "+state_match[0]
            else:
                # Compare and normalize district, municipality, and state
                district_match = process.extractOne(district, list_district)
                state_match = process.extractOne(state, list_state)

                # Append the normalized data
                df['COLONIA'] = district_match[0] if district_match else None
                df['MUNICIPIO'] = municipality_match if municipality_match else None
                df['ESTADO'] = state_match[0] if state_match else None
        else:
            print("Values not found")
        # Convert all elements to uppercase
        #output_list = [str(item).upper() if isinstance(item, str) else item for item in normalized_data]
    return df

# %%
df = df.apply(get_location, axis = 1)
df = df.apply(clean_street, axis = 1)

df = df.apply(normalizar_direccion, axis=1)
# Out:
# Values not found
# Values not found
# Values not found
# Values not found
# Values not found
# Values not found
# Values not found
# Values not found
# Values not found
# Values not found
# Values not found
# Values not found
# Values not found
# Values not found
# Values not found
# Values not found
# Values not found
# Values not found
# Values not found
# Values not found
# Values not found
# Values not found
# Values not found
# Values not found
# Values not found
# Values not found
# Values not found
# Values not found
# Values not found
# Values not found

# %%
def clasificar_etapa(df):
    adjudicada = [
        "Auto Aprobatorio",
        "Validacion De Documentacion",
        "Escritura Vehiculo No Inscrita",
        "Adjudicado Originador",
        "Escritura Originador No Inscrita",
        "Termino De Proceso",
        "Dacion En Pago",
        "Adjudicación A Favor Del Originador",
        "Escritura A Favor Del Vehículo Inscrita",
        "Adjudicación A Favor Del Vehículo",
        "Escritura A Favor Del Vehículo No Inscrita",
        "Escritura A Favor Del Originador No Inscrita",
        "Adjudicación",
        "Escritura A Favor Del Originador Inscrita",
        "Adjudicado Vehiculo",
        "Adjudicado Originador",
        "Escritura Vehiculo Inscrita",
        "Escritura Originador Inscrita",
        "Toma De Posesion"
    ]

    sentencia = [
        "Valorizacion",
        "Fecha De Remate",
        "Audiencia De Remate",
        "Sentencia Firme",
        "Sentencia Primera Instancia",
        "Publicacion De Edictos",
        "Sentencia"
    ]

    juicio = [
        "Emplazamiento Por Edictos",
        "Notificacion De Cesion",
        "Diligenciacion De Exhorto",
        "Presentacion De Demanda",
        "Auto Admisorio",
        "Desahogo De Pruebas",
        "Contestacion",
        "Oficios Dependencias",
        "Apelacion Sentencia Primera Instancia",
        "Juicio De Amparo Sentencia",
        "Apelacion Auto Admisorio",
        "Citado Para Sentencia"
    ]

    cobranza = [
        "Busqueda De Documentos",
        "Certificacion Contable",
        "Sin Dato"
    ]
    

    etapa = str(df["ETAPA"]).strip()  # Convert to string and strip whitespace
    
    # Match against each list using fuzzy matching
    match_adjudicada, score_adjudicada = process.extractOne(etapa, adjudicada)
    match_sentencia, score_sentencia = process.extractOne(etapa, sentencia)
    match_juicio, score_juicio = process.extractOne(etapa, juicio)
    match_cobranza, score_cobranza = process.extractOne(etapa, cobranza)

    # Determine the classification based on the highest score
    if score_adjudicada >= 80:
        df["ETAPA_ALTALTIUM"] = "ADJUDICADA"
    elif score_sentencia >= 80:
        df["ETAPA_ALTALTIUM"] = "SENTENCIA"
    elif score_juicio >= 80:
        df["ETAPA_ALTALTIUM"] = "JUICIO"
    elif score_cobranza >= 80:
        df["ETAPA_ALTALTIUM"] = "COBRANZA"
    else:
        df["ETAPA_ALTALTIUM"] = "DESCONOCIDA"

    return df

df = df.apply(clasificar_etapa, axis = 1)

# %%
# Definir las columnas del inventario
columns = [
    "LISTA", "FOTOS", "FICHAS", "FOLIO", "TIPO", "CALLE_Y_NUMERO", "COLONIA",
    "ALCALDIA/MUNICIPIO", "ESTADO", "CP", "TERRENO", "CONSTRUCCIÓN", 
    "RECAMARAS", "SANITARIOS", "ESTACIONAMIENTOS", "1ER_PAGO", 
    "2DO_PAGO", "TOTAL", "VALOR_APROX", "ALREDEDORES", "GOOGLE_MAPS", 
    "CALIF", "CALIF_EV", "LATITUD", "LONGITUD", "ETAPA", "ESTADO_DE_VIVIENDA",
]

# %%
# Comprobar las columnas
columns_to_check = ['RECAMARAS', 'SANITARIOS', 'ESTACIONAMIENTOS']

for column in columns_to_check:
    if column not in df.columns:
        df[column] = pd.NA  # O puedes usar `None` si prefieres

# %%
inventory_df = pd.DataFrame(columns=columns, index=df.index)

inventory_df["LISTA"] = df["LISTA"]
inventory_df["ETAPA"] = df["ETAPA_ALTALTIUM"]

inventory_df["FOLIO"] = df["FOLIO"].apply(lambda x: abs(x)) #Usé abs porque en la limpieza de numero se le agrega -
# inventory_df["TIPO"] = df["Tipo Inmueble"].str.strip().str.title() No hay tipo en global
inventory_df["ESTADO"] = df["ESTADO"].str.strip().str.title()
inventory_df["ALCALDIA/MUNICIPIO"] = df["MUNICIPIO"].str.strip().str.title()
inventory_df["COLONIA"] = df["COLONIA"].str.strip().str.title()
inventory_df["CALLE_Y_NUMERO"] = df["CALLE_Y_NUMERO"].str.strip().str.title()
inventory_df["CP"] = df["CP"]
inventory_df["TERRENO"] = df["TERRENO"]
inventory_df["CONSTRUCCIÓN"] = df["CONSTRUCCION"]
inventory_df["2DO_PAGO"] = df["2DO_PAGO"]

# %%
def calcular_primer_pago(salida_al_mercado):
    if salida_al_mercado <= 499000:
        return 226000
    elif 500000 <= salida_al_mercado <= 1499000:
        return 395000
    elif salida_al_mercado >= 1500000:
        return 474000
    else:
        return None

inventory_df["1ER_PAGO"] = df["2DO_PAGO"].apply(calcular_primer_pago)

inventory_df["1ER_PAGO"].astype(int)
# Out:
# 0      226000
# 1      226000
# 2      226000
# 3      226000
# 4      226000
#         ...
# 314    226000
# 315    226000
# 316    226000
# 317    226000
# 318    226000
# Name: 1ER_PAGO, Length: 319, dtype: int32

# %%
inventory_df["TOTAL"] = inventory_df["1ER_PAGO"] + inventory_df["2DO_PAGO"]

inventory_df["2DO_PAGO"] = inventory_df["2DO_PAGO"].apply(lambda x: f'{x:.0f}' if x.is_integer() else f'{x:.2f}')
inventory_df["TOTAL"] = inventory_df["TOTAL"].apply(lambda x: f'{x:.0f}' if x.is_integer() else f'{x:.2f}')

# %%
def calculate_rooms(construccion, recamaras):
    # Intenta convertir construccion a número
    try:
        construccion = float(construccion)
    except ValueError:
        construccion = pd.NA  # Si la conversión falla, asignar NA
    
    # Si recamaras tiene un valor válido, devuelve ese valor
    if pd.notna(recamaras) and recamaras != 0:
        return recamaras
    elif pd.isna(recamaras) or recamaras == 0:
        if pd.notna(construccion):  # Solo hacer comparaciones si construccion es numérico
            if construccion <= 39:
                return 1
            elif 40 <= construccion <= 80:
                return 2
            elif 81 <= construccion <= 249:
                return 3
            elif 250 <= construccion <= 349:
                return 4
            elif construccion >= 350:
                return 5
    return pd.NA  # Optional: return NA if construccion is not valid


inventory_df["RECAMARAS"] = inventory_df.apply(lambda row: calculate_rooms(row["CONSTRUCCIÓN"], row["RECAMARAS"]), axis=1)

# %%
def calculate_bathrooms(construccion, sanitarios):
    # Intenta convertir construccion a número
    try:
        construccion = float(construccion)
    except ValueError:
        construccion = pd.NA  # Si la conversión falla, asignar NA
    
    # Si sanitarios tiene un valor válido, devuelve ese valor
    if pd.notna(sanitarios) and sanitarios != 0:
        return sanitarios
    elif pd.isna(sanitarios) or sanitarios == 0:
        if pd.notna(construccion):  # Solo hacer comparaciones si construccion es numérico
            if construccion <= 69:
                return 1
            elif 70 <= construccion <= 99:
                return 1.5
            elif 100 <= construccion <= 159:
                return 2
            elif 160 <= construccion <= 209:
                return 2.5
            elif 210 <= construccion <= 250:
                return 3
            elif 251 <= construccion < 300:
                return 3.5
            elif construccion >= 300:
                return 4
    return pd.NA  # Optional: return NA if construccion is not valid

# Supongamos que `inventory_df` es tu DataFrame
inventory_df["SANITARIOS"] = inventory_df.apply(lambda row: calculate_bathrooms(row["CONSTRUCCIÓN"], row["SANITARIOS"]), axis=1)

# %%
def calculate_parking(construccion, estacionamientos):
    # Intenta convertir construccion a número
    try:
        construccion = float(construccion)
    except ValueError:
        construccion = pd.NA  # Si la conversión falla, asignar NA
    
    # Si estacionamientos tiene un valor válido, devuelve ese valor
    if pd.notna(estacionamientos) and estacionamientos != 0:
        return estacionamientos
    elif pd.isna(estacionamientos) or estacionamientos == 0:
        if pd.notna(construccion):  # Solo hacer comparaciones si construccion es numérico
            if construccion <= 99:
                return 1
            elif 100 <= construccion <= 249:
                return 2
            elif 250 <= construccion <= 359:
                return 3
            elif construccion >= 360:
                return 4
    return pd.NA  # Optional: return NA if construccion is not valid

# Supongamos que `inventory_df` es tu DataFrame
inventory_df["ESTACIONAMIENTOS"] = inventory_df.apply(lambda row: calculate_parking(row["CONSTRUCCIÓN"], row["ESTACIONAMIENTOS"]), axis=1)

# %%
#On ths versión, we need to add the state, colony, and cp to the google maps search

def generar_enlace_busqueda_google_maps(row):
    direccion = f"{row['CALLE_Y_NUMERO']}, {row['COLONIA']}, {row['ALCALDIA/MUNICIPIO']}, {row['ESTADO']}, {row['CP']}"
    direccion = re.sub(r'[\""]', '', direccion)
    direccion = re.sub(r'\s+', ' ', direccion).strip()  # Normalizar espacios múltiples
    return f"https://www.google.com/maps/search/?api=1&query={direccion.replace(' ', '+')}"

# Aplicar la función a cada fila del DataFrame
inventory_df["GOOGLE_MAPS"] = inventory_df.apply(generar_enlace_busqueda_google_maps, axis=1)

# %%
inventory_json = inventory_df.to_json(orient="records", force_ascii=False)

print(json.dumps(json.loads(inventory_json), indent=4, ensure_ascii=False))
# Out:
# [
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 1582513741,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Código Postal 77524 Departamento02 Edificio 06 \"17, 18 Y 19 \" 21 Benito Juarez Benito Juarez Código Postal 77524 Quintana Roo",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Benito Juarez",
#         "ESTADO": "Quintana Roo",
#         "CP": 77524,
#         "TERRENO": 1075.4,
#         "CONSTRUCCIÓN": "66.48",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "37200",
#         "TOTAL": "263200",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Código+Postal+77524+Departamento02+Edificio+06+17,+18+Y+19+21+Benito+Juarez+Benito+Juarez+Código+Postal+77524+Quintana+Roo,+nan,+Benito+Juarez,+Quintana+Roo,+77524",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 1582523739,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Código Postal 77524 Departamento03 Edificio 05 \"17, 18 Y 19 \" 21 Benito Juarez Benito Juarez Código Postal 77524 Quintana Roo",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Benito Juarez",
#         "ESTADO": "Quintana Roo",
#         "CP": 77524,
#         "TERRENO": 1075.4,
#         "CONSTRUCCIÓN": "66.48",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "37200",
#         "TOTAL": "263200",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Código+Postal+77524+Departamento03+Edificio+05+17,+18+Y+19+21+Benito+Juarez+Benito+Juarez+Código+Postal+77524+Quintana+Roo,+nan,+Benito+Juarez,+Quintana+Roo,+77524",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 1582533738,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Código Postal 77524 Departamento02 Edificio 05 \"17, 18 Y 19 \" 21 Benito Juarez Benito Juarez Código Postal 77524 Quintana Roo",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Benito Juarez",
#         "ESTADO": "Quintana Roo",
#         "CP": 77524,
#         "TERRENO": 1075.4,
#         "CONSTRUCCIÓN": "66.48",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "37200",
#         "TOTAL": "263200",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Código+Postal+77524+Departamento02+Edificio+05+17,+18+Y+19+21+Benito+Juarez+Benito+Juarez+Código+Postal+77524+Quintana+Roo,+nan,+Benito+Juarez,+Quintana+Roo,+77524",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 1582543736,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Código Postal 77524 Departamento03 Edificio 04 \"17, 18 Y 19 \" 21 Benito Juarez Benito Juarez Código Postal 77524 Quintana Roo",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Benito Juarez",
#         "ESTADO": "Quintana Roo",
#         "CP": 77524,
#         "TERRENO": 1075.4,
#         "CONSTRUCCIÓN": "66.48",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "37200",
#         "TOTAL": "263200",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Código+Postal+77524+Departamento03+Edificio+04+17,+18+Y+19+21+Benito+Juarez+Benito+Juarez+Código+Postal+77524+Quintana+Roo,+nan,+Benito+Juarez,+Quintana+Roo,+77524",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 1582553734,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Código Postal 77524 Departamento01 Edificio 04 \"17, 18 Y 19 \" 21 Benito Juarez Benito Juarez Código Postal 77524 Quintana Roo",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Benito Juarez",
#         "ESTADO": "Quintana Roo",
#         "CP": 77524,
#         "TERRENO": 1075.4,
#         "CONSTRUCCIÓN": "66.48",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "37200",
#         "TOTAL": "263200",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Código+Postal+77524+Departamento01+Edificio+04+17,+18+Y+19+21+Benito+Juarez+Benito+Juarez+Código+Postal+77524+Quintana+Roo,+nan,+Benito+Juarez,+Quintana+Roo,+77524",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 1582563733,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Código Postal 77524 Departamento03 Edificio 03 \"17, 18 Y 19 \" 21 Benito Juarez Benito Juarez Código Postal 77524 Quintana Roo",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Benito Juarez",
#         "ESTADO": "Quintana Roo",
#         "CP": 77524,
#         "TERRENO": 1075.4,
#         "CONSTRUCCIÓN": "66.48",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "37200",
#         "TOTAL": "263200",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Código+Postal+77524+Departamento03+Edificio+03+17,+18+Y+19+21+Benito+Juarez+Benito+Juarez+Código+Postal+77524+Quintana+Roo,+nan,+Benito+Juarez,+Quintana+Roo,+77524",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 1582573732,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Código Postal 77524 Departamento02 Edificio 03 \"17, 18 Y 19 \" 21 Benito Juarez Benito Juarez Código Postal 77524 Quintana Roo",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Benito Juarez",
#         "ESTADO": "Quintana Roo",
#         "CP": 77524,
#         "TERRENO": 1075.4,
#         "CONSTRUCCIÓN": "66.48",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "37200",
#         "TOTAL": "263200",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Código+Postal+77524+Departamento02+Edificio+03+17,+18+Y+19+21+Benito+Juarez+Benito+Juarez+Código+Postal+77524+Quintana+Roo,+nan,+Benito+Juarez,+Quintana+Roo,+77524",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 1582583731,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Código Postal 77524 Departamento01 Edificio 03 \"17, 18 Y 19 \" 21 Benito Juarez Benito Juarez Código Postal 77524 Quintana Roo",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Benito Juarez",
#         "ESTADO": "Quintana Roo",
#         "CP": 77524,
#         "TERRENO": 1075.4,
#         "CONSTRUCCIÓN": "66.48",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "37200",
#         "TOTAL": "263200",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Código+Postal+77524+Departamento01+Edificio+03+17,+18+Y+19+21+Benito+Juarez+Benito+Juarez+Código+Postal+77524+Quintana+Roo,+nan,+Benito+Juarez,+Quintana+Roo,+77524",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 1582593726,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Código Postal 77524 Departamento02 Edificio 01 \"17, 18 Y 19 \" 21 Benito Juarez Benito Juarez Código Postal 77524 Quintana Roo",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Benito Juarez",
#         "ESTADO": "Quintana Roo",
#         "CP": 77524,
#         "TERRENO": 1075.4,
#         "CONSTRUCCIÓN": "66.48",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "37200",
#         "TOTAL": "263200",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Código+Postal+77524+Departamento02+Edificio+01+17,+18+Y+19+21+Benito+Juarez+Benito+Juarez+Código+Postal+77524+Quintana+Roo,+nan,+Benito+Juarez,+Quintana+Roo,+77524",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 1582873740,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Código Postal 77000 Departamento01 Edificio 06 \"17, 18 Y 19 \" 21 Benito Juarez Benito Juarez Código Postal 77000 Quintana Roo",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Benito Juarez",
#         "ESTADO": "Quintana Roo",
#         "CP": 77000,
#         "TERRENO": 1075.4,
#         "CONSTRUCCIÓN": "66.48",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "47700",
#         "TOTAL": "273700",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Código+Postal+77000+Departamento01+Edificio+06+17,+18+Y+19+21+Benito+Juarez+Benito+Juarez+Código+Postal+77000+Quintana+Roo,+nan,+Benito+Juarez,+Quintana+Roo,+77000",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 1582883735,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Código Postal 77524 Departamento02 Edificio 04 \"17, 18 Y 19 \" 21 Benito Juarez Benito Juarez Código Postal 77524 Quintana Roo",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Benito Juarez",
#         "ESTADO": "Quintana Roo",
#         "CP": 77524,
#         "TERRENO": 1075.4,
#         "CONSTRUCCIÓN": "66.48",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "47700",
#         "TOTAL": "273700",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Código+Postal+77524+Departamento02+Edificio+04+17,+18+Y+19+21+Benito+Juarez+Benito+Juarez+Código+Postal+77524+Quintana+Roo,+nan,+Benito+Juarez,+Quintana+Roo,+77524",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 1582893730,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Código Postal 77524 Departamento03 Edificio 02 \"17, 18 Y 19 \" 21 Benito Juarez Benito Juarez Código Postal 77524 Quintana Roo",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Benito Juarez",
#         "ESTADO": "Quintana Roo",
#         "CP": 77524,
#         "TERRENO": 1075.4,
#         "CONSTRUCCIÓN": "66.48",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "47700",
#         "TOTAL": "273700",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Código+Postal+77524+Departamento03+Edificio+02+17,+18+Y+19+21+Benito+Juarez+Benito+Juarez+Código+Postal+77524+Quintana+Roo,+nan,+Benito+Juarez,+Quintana+Roo,+77524",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 1582903725,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Código Postal 77524 Departamento01 Edificio 01 \"17, 18 Y 19 \" 21 Benito Juarez Benito Juarez Código Postal 77524 Quintana Roo",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Benito Juarez",
#         "ESTADO": "Quintana Roo",
#         "CP": 77524,
#         "TERRENO": 1075.4,
#         "CONSTRUCCIÓN": "66.48",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "47700",
#         "TOTAL": "273700",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Código+Postal+77524+Departamento01+Edificio+01+17,+18+Y+19+21+Benito+Juarez+Benito+Juarez+Código+Postal+77524+Quintana+Roo,+nan,+Benito+Juarez,+Quintana+Roo,+77524",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 1583053742,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Código Postal 77524 Departamento03 Edificio 06 \"17, 18 Y 19 \" 21 Benito Juarez Benito Juarez Código Postal 77524 Quintana Roo",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Benito Juarez",
#         "ESTADO": "Quintana Roo",
#         "CP": 77524,
#         "TERRENO": 1075.4,
#         "CONSTRUCCIÓN": "66.48",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "37200",
#         "TOTAL": "263200",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Código+Postal+77524+Departamento03+Edificio+06+17,+18+Y+19+21+Benito+Juarez+Benito+Juarez+Código+Postal+77524+Quintana+Roo,+nan,+Benito+Juarez,+Quintana+Roo,+77524",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 1583054109,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Emiliano Zapata Antes 18 20 Santa Barbara Santa Barbara Chihuahua",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Santa Barbara",
#         "ESTADO": "Chihuahua",
#         "CP": 33580,
#         "TERRENO": 276.0,
#         "CONSTRUCCIÓN": "130.63",
#         "RECAMARAS": 3,
#         "SANITARIOS": 2,
#         "ESTACIONAMIENTOS": 2,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "19500",
#         "TOTAL": "245500",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Emiliano+Zapata+Antes+18+20+Santa+Barbara+Santa+Barbara+Chihuahua,+nan,+Santa+Barbara,+Chihuahua,+33580",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 1583293746,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Circuito Hacienda De Coapan Supermanzana 200 En La Avenida Puerto Juarez Código Postal77500 Casa 1566 B 2 64 Fraccionamiento Haciendas Del Caribe Iii Etapa Benito Juarez Benito Juarez Código Postal 77500 Quintana Roo",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Benito Juarez",
#         "ESTADO": "Quintana Roo",
#         "CP": 77500,
#         "TERRENO": 60.86,
#         "CONSTRUCCIÓN": "110",
#         "RECAMARAS": 3,
#         "SANITARIOS": 2,
#         "ESTACIONAMIENTOS": 2,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "93312",
#         "TOTAL": "319312",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Circuito+Hacienda+De+Coapan+Supermanzana+200+En+La+Avenida+Puerto+Juarez+Código+Postal77500+Casa+1566+B+2+64+Fraccionamiento+Haciendas+Del+Caribe+Iii+Etapa+Benito+Juarez+Benito+Juarez+Código+Postal+77500+Quintana+Roo,+nan,+Benito+Juarez,+Quintana+Roo,+77500",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 1583334076,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Calle 7A. Unidad Privativa 5 Código Postal 31050 5004 5 Fraccionamiento Rincones De Santa Rosa Chihuahua Chihuahua Código Postal 31050 Chihuahua",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Chihuahua",
#         "ESTADO": "Chihuahua",
#         "CP": 31050,
#         "TERRENO": 143.4,
#         "CONSTRUCCIÓN": "107.8",
#         "RECAMARAS": 3,
#         "SANITARIOS": 2,
#         "ESTACIONAMIENTOS": 2,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "169043.16",
#         "TOTAL": "395043.16",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Calle+7A.+Unidad+Privativa+5+Código+Postal+31050+5004+5+Fraccionamiento+Rincones+De+Santa+Rosa+Chihuahua+Chihuahua+Código+Postal+31050+Chihuahua,+nan,+Chihuahua,+Chihuahua,+31050",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 1583584467,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Redio Denominado San Francisco La Piedra 4 P 15 Exhacienda Tierra Nueva Cosoleacaque Cosoleacaque Veracruz",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Cosoleacaque",
#         "ESTADO": "Veracruz",
#         "CP": 96350,
#         "TERRENO": 63750.0,
#         "CONSTRUCCIÓN": " -   ",
#         "RECAMARAS": null,
#         "SANITARIOS": null,
#         "ESTACIONAMIENTOS": null,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "139392",
#         "TOTAL": "365392",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Redio+Denominado+San+Francisco+La+Piedra+4+P+15+Exhacienda+Tierra+Nueva+Cosoleacaque+Cosoleacaque+Veracruz,+nan,+Cosoleacaque,+Veracruz,+96350",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 1583594466,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Predio Denominado San Francisco La Piedra 3 15 Exhacienda Tierra Nueva Cosoleacaque Cosoleacaque Veracruz",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Cosoleacaque",
#         "ESTADO": "Veracruz",
#         "CP": 96350,
#         "TERRENO": 63750.0,
#         "CONSTRUCCIÓN": " -   ",
#         "RECAMARAS": null,
#         "SANITARIOS": null,
#         "ESTACIONAMIENTOS": null,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "139392",
#         "TOTAL": "365392",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Predio+Denominado+San+Francisco+La+Piedra+3+15+Exhacienda+Tierra+Nueva+Cosoleacaque+Cosoleacaque+Veracruz,+nan,+Cosoleacaque,+Veracruz,+96350",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 1583683548,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Popocatepetl Código Postal 55120 21 76 434 Fraccionamiento Azteca Ecatepec De Morelos Ecatepec De Morelos Código Postal 55120 Estado De Mexico",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Ecatepec De Morelos",
#         "ESTADO": "Estado De Mexico",
#         "CP": 55120,
#         "TERRENO": 122.5,
#         "CONSTRUCCIÓN": "101.5",
#         "RECAMARAS": 3,
#         "SANITARIOS": 2,
#         "ESTACIONAMIENTOS": 2,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "255683.26",
#         "TOTAL": "481683.26",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Popocatepetl+Código+Postal+55120+21+76+434+Fraccionamiento+Azteca+Ecatepec+De+Morelos+Ecatepec+De+Morelos+Código+Postal+55120+Estado+De+Mexico,+nan,+Ecatepec+De+Morelos,+Estado+De+Mexico,+55120",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 1583694116,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Socrates 25090 294 9 1 Valle Dorado Saltillo Saltillo Código Postal 25090 Coahuila",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Saltillo",
#         "ESTADO": "Coahuila",
#         "CP": 25090,
#         "TERRENO": 144.0,
#         "CONSTRUCCIÓN": "64",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "150528",
#         "TOTAL": "376528",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Socrates+25090+294+9+1+Valle+Dorado+Saltillo+Saltillo+Código+Postal+25090+Coahuila,+nan,+Saltillo,+Coahuila,+25090",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 1584034309,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Rincon De Las Magnolias Código Postal 72460 Casa 49 Fraccionamiento Rincon Arboledas Puebla Puebla Código Postal 72460 Puebla",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Puebla",
#         "ESTADO": "Puebla",
#         "CP": 72460,
#         "TERRENO": 272.0,
#         "CONSTRUCCIÓN": "262",
#         "RECAMARAS": 4,
#         "SANITARIOS": 3.5,
#         "ESTACIONAMIENTOS": 3,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "407880",
#         "TOTAL": "633880",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Rincon+De+Las+Magnolias+Código+Postal+72460+Casa+49+Fraccionamiento+Rincon+Arboledas+Puebla+Puebla+Código+Postal+72460+Puebla,+nan,+Puebla,+Puebla,+72460",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 1584054430,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Aldama Y Periferico Carlos Pellicer Centro Centro Tabasco",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Centro",
#         "ESTADO": "Tabasco",
#         "CP": 86000,
#         "TERRENO": 135.0,
#         "CONSTRUCCIÓN": "640",
#         "RECAMARAS": 5,
#         "SANITARIOS": 4,
#         "ESTACIONAMIENTOS": 4,
#         "1ER_PAGO": 395000,
#         "2DO_PAGO": "769536",
#         "TOTAL": "1164536",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Aldama+Y+Periferico+Carlos+Pellicer+Centro+Centro+Tabasco,+nan,+Centro,+Tabasco,+86000",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 1584113836,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Maple Entre Paseo Los Sauces Y Paseo Los Juncos Del Fraccionamiento Floresta Código Postal 91940 95 21 38 Floresta Floresta Código Postal 91940 Veracruz",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Floresta",
#         "ESTADO": "Veracruz",
#         "CP": 91940,
#         "TERRENO": 250.0,
#         "CONSTRUCCIÓN": "150",
#         "RECAMARAS": 3,
#         "SANITARIOS": 2,
#         "ESTACIONAMIENTOS": 2,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "353439.32",
#         "TOTAL": "579439.32",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Maple+Entre+Paseo+Los+Sauces+Y+Paseo+Los+Juncos+Del+Fraccionamiento+Floresta+Código+Postal+91940+95+21+38+Floresta+Floresta+Código+Postal+91940+Veracruz,+nan,+Floresta,+Veracruz,+91940",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 1584134118,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Octavio Lopez Hoy Segundo Sector 14 25260 1225 6 11 Conj Villas San Lorenzo Universidad Saltillo Saltillo Código Postal 25260 Coahuila",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Saltillo",
#         "ESTADO": "Coahuila",
#         "CP": 25260,
#         "TERRENO": 192.7,
#         "CONSTRUCCIÓN": "260",
#         "RECAMARAS": 4,
#         "SANITARIOS": 3.5,
#         "ESTACIONAMIENTOS": 3,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "308505.60",
#         "TOTAL": "534505.60",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Octavio+Lopez+Hoy+Segundo+Sector+14+25260+1225+6+11+Conj+Villas+San+Lorenzo+Universidad+Saltillo+Saltillo+Código+Postal+25260+Coahuila,+nan,+Saltillo,+Coahuila,+25260",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 1584173319,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Paseo Del Mar Entre Paseo De Barrio Viejo Y La Salitrera Código Postal 40880 13 13 A Cond Villas Del Mar Residencial Iii Zihuatanejo Zihuatanejo Código Postal 40880 Guerrero",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Zihuatanejo",
#         "ESTADO": "Guerrero",
#         "CP": 40880,
#         "TERRENO": 250.0,
#         "CONSTRUCCIÓN": "99.39",
#         "RECAMARAS": 3,
#         "SANITARIOS": null,
#         "ESTACIONAMIENTOS": null,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "261647.57",
#         "TOTAL": "487647.57",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Paseo+Del+Mar+Entre+Paseo+De+Barrio+Viejo+Y+La+Salitrera+Código+Postal+40880+13+13+A+Cond+Villas+Del+Mar+Residencial+Iii+Zihuatanejo+Zihuatanejo+Código+Postal+40880+Guerrero,+nan,+Zihuatanejo,+Guerrero,+40880",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 1584304305,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Rio Yaqui Código Postal 72570 6125 24 90 Fraccionamiento Jardines De San Manuel Puebla Puebla Código Postal 72570 Puebla",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Puebla",
#         "ESTADO": "Puebla",
#         "CP": 72570,
#         "TERRENO": 169.69,
#         "CONSTRUCCIÓN": "340",
#         "RECAMARAS": 4,
#         "SANITARIOS": 4,
#         "ESTACIONAMIENTOS": 3,
#         "1ER_PAGO": 395000,
#         "2DO_PAGO": "638899.20",
#         "TOTAL": "1033899.20",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Rio+Yaqui+Código+Postal+72570+6125+24+90+Fraccionamiento+Jardines+De+San+Manuel+Puebla+Puebla+Código+Postal+72570+Puebla,+nan,+Puebla,+Puebla,+72570",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 1518023250,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Hacienda San Nicolas Sur, 1103, Lote 27 Manzana 4",
#         "COLONIA": "Colonial Del Valle",
#         "ALCALDIA/MUNICIPIO": "Juárez",
#         "ESTADO": "Chihuahua",
#         "CP": 32553,
#         "TERRENO": 72.0,
#         "CONSTRUCCIÓN": "45.18",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "95100",
#         "TOTAL": "321100",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Hacienda+San+Nicolas+Sur,+1103,+Lote+27+Manzana+4,+Colonial+Del+Valle,+Juárez,+Chihuahua,+32553",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "DESCONOCIDA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 1518283290,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Topacio Número 119, Lt 119, Manzana 1",
#         "COLONIA": "La Cañada",
#         "ALCALDIA/MUNICIPIO": "Tetla De La Solidaridad",
#         "ESTADO": "Tlaxcala",
#         "CP": 90430,
#         "TERRENO": 126.0,
#         "CONSTRUCCIÓN": "48.68",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "62755.23",
#         "TOTAL": "288755.23",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Topacio+Número+119,+Lt+119,+Manzana+1,+La+Cañada,+Tetla+De+La+Solidaridad,+Tlaxcala,+90430",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 1518322392,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Homero Número 619 Cond. Homero 3 Vivienda 32 1L Manzana 32 Lote 12",
#         "COLONIA": "Villa Residencial Del Rey",
#         "ALCALDIA/MUNICIPIO": "Ensenada",
#         "ESTADO": "Baja California",
#         "CP": 22785,
#         "TERRENO": 121.41,
#         "CONSTRUCCIÓN": "60.05",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "118205.31",
#         "TOTAL": "344205.31",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Homero+Número+619+Cond.+Homero+3+Vivienda+32+1L+Manzana+32+Lote+12,+Villa+Residencial+Del+Rey,+Ensenada,+Baja+California,+22785",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "DESCONOCIDA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 1518333265,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Terreno Urbano Y Construcción De Casa Habitación Ub",
#         "COLONIA": "Heroica Matamoros Centro",
#         "ALCALDIA/MUNICIPIO": "Matamoros",
#         "ESTADO": "Tamaulipas",
#         "CP": 87300,
#         "TERRENO": 120.0,
#         "CONSTRUCCIÓN": "110",
#         "RECAMARAS": 3,
#         "SANITARIOS": 2,
#         "ESTACIONAMIENTOS": 2,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "103200",
#         "TOTAL": "329200",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Terreno+Urbano+Y+Construcción+De+Casa+Habitación+Ub,+Heroica+Matamoros+Centro,+Matamoros,+Tamaulipas,+87300",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 1518462522,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Perla 22 Lote 11 Manzana 1",
#         "COLONIA": "Nueva Mina Norte",
#         "ALCALDIA/MUNICIPIO": "Minatitlán",
#         "ESTADO": "Veracruz De Ignacio De La Llave",
#         "CP": 96734,
#         "TERRENO": 105.0,
#         "CONSTRUCCIÓN": "90",
#         "RECAMARAS": 3,
#         "SANITARIOS": 1.5,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "86784",
#         "TOTAL": "312784",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Perla+22+Lote+11+Manzana+1,+Nueva+Mina+Norte,+Minatitlán,+Veracruz+De+Ignacio+De+La+Llave,+96734",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 1518543262,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Alfonso Fernandez # 109, Lt. 21, Manzana 5",
#         "COLONIA": "San Juan De La Cruz",
#         "ALCALDIA/MUNICIPIO": "Toluca",
#         "ESTADO": "México",
#         "CP": 50010,
#         "TERRENO": 145.0,
#         "CONSTRUCCIÓN": "397.21",
#         "RECAMARAS": 5,
#         "SANITARIOS": 4,
#         "ESTACIONAMIENTOS": 4,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "179350.66",
#         "TOTAL": "405350.66",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Alfonso+Fernandez+#+109,+Lt.+21,+Manzana+5,+San+Juan+De+La+Cruz,+Toluca,+México,+50010",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 1518683363,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Nuez De Macadamia 8200 3 Lote 3 Manzana 6",
#         "COLONIA": "Paseo De Los Nogales",
#         "ALCALDIA/MUNICIPIO": "Juárez",
#         "ESTADO": "Chihuahua",
#         "CP": 32668,
#         "TERRENO": 365.33,
#         "CONSTRUCCIÓN": "128.89",
#         "RECAMARAS": 3,
#         "SANITARIOS": 2,
#         "ESTACIONAMIENTOS": 2,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "232320",
#         "TOTAL": "458320",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Nuez+De+Macadamia+8200+3+Lote+3+Manzana+6,+Paseo+De+Los+Nogales,+Juárez,+Chihuahua,+32668",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 1519742994,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Unidad 204 Del Poligono San Jose Del Desarrollo Condominal \"La Isla\"",
#         "COLONIA": "Desarrollo Condominal La Isla",
#         "ALCALDIA/MUNICIPIO": "Los Cabos",
#         "ESTADO": "Baja California Sur",
#         "CP": "Revisar CP 00000",
#         "TERRENO": 0.0,
#         "CONSTRUCCIÓN": "68.35",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "133632",
#         "TOTAL": "359632",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Unidad+204+Del+Poligono+San+Jose+Del+Desarrollo+Condominal+La+Isla,+Desarrollo+Condominal+La+Isla,+Los+Cabos,+Baja+California+Sur,+Revisar+CP+00000",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 1519752048,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Alfonso Vidal Palmas Número 436 Edificio B Departamento 402",
#         "COLONIA": "Villas Nueva Tijuana",
#         "ALCALDIA/MUNICIPIO": "Tijuana",
#         "ESTADO": "Baja California",
#         "CP": "Revisar CP 00000",
#         "TERRENO": 62.42,
#         "CONSTRUCCIÓN": "81.4",
#         "RECAMARAS": 3,
#         "SANITARIOS": 1.5,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "64896",
#         "TOTAL": "290896",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Alfonso+Vidal+Palmas+Número+436+Edificio+B+Departamento+402,+Villas+Nueva+Tijuana,+Tijuana,+Baja+California,+Revisar+CP+00000",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 43535658,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Ret. Bosque De Guayabas Lt 36, Manzana 89, 18, Departamento 2, Bosques Del Valle 2A Secc, Coacalco De Berriozabal, Estado De Mexico",
#         "COLONIA": "Ret. Bosque De Guayabas Lt 36, Mza. 89, 18, Depto 2, Bosques Del Valle 2A Secc, Coacalco De Berriozabal, Estado De Mexico",
#         "ALCALDIA/MUNICIPIO": "Coacalco",
#         "ESTADO": "Estado De Mexico",
#         "CP": "Revisar CP 55701",
#         "TERRENO": 61.25,
#         "CONSTRUCCIÓN": "67.3",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "78336",
#         "TOTAL": "304336",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Ret.+Bosque+De+Guayabas+Lt+36,+Manzana+89,+18,+Departamento+2,+Bosques+Del+Valle+2A+Secc,+Coacalco+De+Berriozabal,+Estado+De+Mexico,+Ret.+Bosque+De+Guayabas+Lt+36,+Mza.+89,+18,+Depto+2,+Bosques+Del+Valle+2A+Secc,+Coacalco+De+Berriozabal,+Estado+De+Mexico,+Coacalco,+Estado+De+Mexico,+Revisar+CP+55701",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 43765653,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Las Americas Lt 4 Manzana 8, Snedif D 2, Departamento 201, Parques De Aragon, Ecatepec De Morelos, Estado De Mexico",
#         "COLONIA": "Parques De Aragón",
#         "ALCALDIA/MUNICIPIO": "Ecatepec De Morelos",
#         "ESTADO": "México",
#         "CP": 55244,
#         "TERRENO": 67.7,
#         "CONSTRUCCIÓN": "67",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "105984",
#         "TOTAL": "331984",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Las+Americas+Lt+4+Manzana+8,+Snedif+D+2,+Departamento+201,+Parques+De+Aragon,+Ecatepec+De+Morelos,+Estado+De+Mexico,+Parques+De+Aragón,+Ecatepec+De+Morelos,+México,+55244",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 43925807,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Circuito Santa Fe Antiguo Camino A Tesistan, 1690, 54 8, Residencial Santa Fe, Zapopan, Jalisco",
#         "COLONIA": "Residencial Santa Fe",
#         "ALCALDIA/MUNICIPIO": "Zapopan",
#         "ESTADO": "Jalisco",
#         "CP": 45138,
#         "TERRENO": 104.4,
#         "CONSTRUCCIÓN": "150.16",
#         "RECAMARAS": 3,
#         "SANITARIOS": 2,
#         "ESTACIONAMIENTOS": 2,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "294660",
#         "TOTAL": "520660",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Circuito+Santa+Fe+Antiguo+Camino+A+Tesistan,+1690,+54+8,+Residencial+Santa+Fe,+Zapopan,+Jalisco,+Residencial+Santa+Fe,+Zapopan,+Jalisco,+45138",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 44045563,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Onimex Lt 3, Manzana 1, 5, Casa 1, El Potrero, Ecatepec De Morelos, Estado De Mexico",
#         "COLONIA": "Onimex Lt 3, Mza. 1, 5, Casa 1, El Potrero, Ecatepec De Morelos, Estado De Mexico",
#         "ALCALDIA/MUNICIPIO": "Ecatepec",
#         "ESTADO": "Estado De Mexico",
#         "CP": "Revisar CP 55035",
#         "TERRENO": 179.4,
#         "CONSTRUCCIÓN": "82",
#         "RECAMARAS": 3,
#         "SANITARIOS": 1.5,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "149376",
#         "TOTAL": "375376",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Onimex+Lt+3,+Manzana+1,+5,+Casa+1,+El+Potrero,+Ecatepec+De+Morelos,+Estado+De+Mexico,+Onimex+Lt+3,+Mza.+1,+5,+Casa+1,+El+Potrero,+Ecatepec+De+Morelos,+Estado+De+Mexico,+Ecatepec,+Estado+De+Mexico,+Revisar+CP+55035",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 44055597,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Valle De Senegal Lt 22 Manzana 18 Supermza 3, 335, Casa 622, Valle De Aragon Norte, Ecatepec De Morelos, Estado De Mexico",
#         "COLONIA": "Renacimiento De Aragón",
#         "ALCALDIA/MUNICIPIO": "Ecatepec De Morelos",
#         "ESTADO": "México",
#         "CP": 55280,
#         "TERRENO": 84.0,
#         "CONSTRUCCIÓN": "102.95",
#         "RECAMARAS": 3,
#         "SANITARIOS": 2,
#         "ESTACIONAMIENTOS": 2,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "152832",
#         "TOTAL": "378832",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Valle+De+Senegal+Lt+22+Manzana+18+Supermza+3,+335,+Casa+622,+Valle+De+Aragon+Norte,+Ecatepec+De+Morelos,+Estado+De+Mexico,+Renacimiento+De+Aragón,+Ecatepec+De+Morelos,+México,+55280",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 44165681,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Tlaltepan, 12, Casa 1, Villas De Cuautitlan, Cuautitlan, Estado De Mexico",
#         "COLONIA": "Tlaltepan, 12, Casa 1, Villas De Cuautitlan, Cuautitlan, Estado De Mexico",
#         "ALCALDIA/MUNICIPIO": "Cuautitlan",
#         "ESTADO": "Estado De Mexico",
#         "CP": "Revisar CP 54801",
#         "TERRENO": 37.2,
#         "CONSTRUCCIÓN": "93.7",
#         "RECAMARAS": 3,
#         "SANITARIOS": 1.5,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "166656",
#         "TOTAL": "392656",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Tlaltepan,+12,+Casa+1,+Villas+De+Cuautitlan,+Cuautitlan,+Estado+De+Mexico,+Tlaltepan,+12,+Casa+1,+Villas+De+Cuautitlan,+Cuautitlan,+Estado+De+Mexico,+Cuautitlan,+Estado+De+Mexico,+Revisar+CP+54801",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 44225562,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Hidalgo, 504 A Edificio Calle, Departamento 5, San Nicolas Tolentino, Iztapalapa, Distrito Federal",
#         "COLONIA": "San Juan Xalpa",
#         "ALCALDIA/MUNICIPIO": "Iztapalapa",
#         "ESTADO": "Ciudad De México",
#         "CP": 9850,
#         "TERRENO": 62.5,
#         "CONSTRUCCIÓN": "56.6",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "175872",
#         "TOTAL": "401872",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Hidalgo,+504+A+Edificio+Calle,+Departamento+5,+San+Nicolas+Tolentino,+Iztapalapa,+Distrito+Federal,+San+Juan+Xalpa,+Iztapalapa,+Ciudad+De+México,+9850",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 44255647,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Ret. Wolstano Pineda Lt 313 Y 314 Manzana 6, S/Ned20Y22, Departamento 2, Atzacoalco Ctm, Gustavo A Madero, Distrito Federal",
#         "COLONIA": "C.T.M. Atzacoalco",
#         "ALCALDIA/MUNICIPIO": "Gustavo A. Madero",
#         "ESTADO": "Ciudad De México",
#         "CP": 7090,
#         "TERRENO": 41.0,
#         "CONSTRUCCIÓN": "68.9",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "184320",
#         "TOTAL": "410320",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
# ...
#         "FICHAS": null,
#         "FOLIO": 561717675,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Manzana F Lote 7 Calle Jean Charlot 1",
#         "COLONIA": "Jean Charlot I",
#         "ALCALDIA/MUNICIPIO": "Tzompantepec",
#         "ESTADO": "Tlaxcala",
#         "CP": 90490,
#         "TERRENO": 108.0,
#         "CONSTRUCCIÓN": "34",
#         "RECAMARAS": 1,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "19800",
#         "TOTAL": "245800",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Manzana+F+Lote+7+Calle+Jean+Charlot+1,+Jean+Charlot+I,+Tzompantepec,+Tlaxcala,+90490",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "JUICIO",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 1222652584,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Calle Número Número 0001 0001Calle Número Número Los Ruise#Ores 45300",
#         "COLONIA": "Los Ruiseñores",
#         "ALCALDIA/MUNICIPIO": "Tala",
#         "ESTADO": "Jalisco",
#         "CP": 45314,
#         "TERRENO": null,
#         "CONSTRUCCIÓN": null,
#         "RECAMARAS": null,
#         "SANITARIOS": null,
#         "ESTACIONAMIENTOS": null,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "58200",
#         "TOTAL": "284200",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Calle+Número+Número+0001+0001Calle+Número+Número+Los+Ruise#Ores+45300,+Los+Ruiseñores,+Tala,+Jalisco,+45314",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "JUICIO",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 1330855299,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Extremadura 00070 109 Real De Valdepe#As 44100",
#         "COLONIA": "Real De Valdepeñas",
#         "ALCALDIA/MUNICIPIO": "Zapopan",
#         "ESTADO": "Jalisco",
#         "CP": 45130,
#         "TERRENO": 187.0,
#         "CONSTRUCCIÓN": "156",
#         "RECAMARAS": 3,
#         "SANITARIOS": 2,
#         "ESTACIONAMIENTOS": 2,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "301800",
#         "TOTAL": "527800",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Extremadura+00070+109+Real+De+Valdepe#As+44100,+Real+De+Valdepeñas,+Zapopan,+Jalisco,+45130",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "JUICIO",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 416961330,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Avenidaprincipal Número12 Villa 30 Vista Brisa Fraccionamiento Cumbres De Lote",
#         "COLONIA": "Cumbres Llano Largo",
#         "ALCALDIA/MUNICIPIO": "Acapulco De Juárez",
#         "ESTADO": "Guerrero",
#         "CP": 39820,
#         "TERRENO": 72.0,
#         "CONSTRUCCIÓN": "72",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1.5,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "227100",
#         "TOTAL": "453100",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Avenidaprincipal+Número12+Villa+30+Vista+Brisa+Fraccionamiento+Cumbres+De+Lote,+Cumbres+Llano+Largo,+Acapulco+De+Juárez,+Guerrero,+39820",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "JUICIO",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 1850141798,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Galaxia 173 Na Sol Naciente 60154",
#         "COLONIA": "La Guadalupana",
#         "ALCALDIA/MUNICIPIO": "Uruapan",
#         "ESTADO": "Michoacán De Ocampo",
#         "CP": 60154,
#         "TERRENO": 210.0,
#         "CONSTRUCCIÓN": "309",
#         "RECAMARAS": 4,
#         "SANITARIOS": 4,
#         "ESTACIONAMIENTOS": 3,
#         "1ER_PAGO": 395000,
#         "2DO_PAGO": "869500.72",
#         "TOTAL": "1264500.72",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Galaxia+173+Na+Sol+Naciente+60154,+La+Guadalupana,+Uruapan,+Michoacán+De+Ocampo,+60154",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "SENTENCIA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 468921493,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Cal Jardin De Invman 14 30 99",
#         "COLONIA": "Santiago Teyahualco",
#         "ALCALDIA/MUNICIPIO": "Tultepec",
#         "ESTADO": "México",
#         "CP": 54980,
#         "TERRENO": 95.0,
#         "CONSTRUCCIÓN": "79",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1.5,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "181200",
#         "TOTAL": "407200",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Cal+Jardin+De+Invman+14+30+99,+Santiago+Teyahualco,+Tultepec,+México,+54980",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "SENTENCIA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 1525078670,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Medrano 00530 Analco 44450",
#         "COLONIA": "Analco",
#         "ALCALDIA/MUNICIPIO": "Guadalajara",
#         "ESTADO": "Jalisco",
#         "CP": 44450,
#         "TERRENO": null,
#         "CONSTRUCCIÓN": null,
#         "RECAMARAS": null,
#         "SANITARIOS": null,
#         "ESTACIONAMIENTOS": null,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "409200",
#         "TOTAL": "635200",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Medrano+00530+Analco+44450,+Analco,+Guadalajara,+Jalisco,+44450",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "SENTENCIA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 1596385384,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Bosques De Africa 29 Bosques De La Hacienda 47690",
#         "COLONIA": "Bosques De La Hacienda 1A Sección",
#         "ALCALDIA/MUNICIPIO": "Cuautitlán Izcalli",
#         "ESTADO": "México",
#         "CP": 54715,
#         "TERRENO": 144.0,
#         "CONSTRUCCIÓN": "136",
#         "RECAMARAS": 3,
#         "SANITARIOS": 2,
#         "ESTACIONAMIENTOS": 2,
#         "1ER_PAGO": 395000,
#         "2DO_PAGO": "1449984",
#         "TOTAL": "1844984",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Bosques+De+Africa+29+Bosques+De+La+Hacienda+47690,+Bosques+De+La+Hacienda+1A+Sección,+Cuautitlán+Izcalli,+México,+54715",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2014447902,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Bulukax Lote 16, Manzana 191",
#         "COLONIA": "Revisar Payo Obispo",
#         "ALCALDIA/MUNICIPIO": "Revisar Othón P. Blanco",
#         "ESTADO": "Revisar Quintana Roo",
#         "CP": 77083,
#         "TERRENO": 128.0,
#         "CONSTRUCCIÓN": "166.88",
#         "RECAMARAS": 3,
#         "SANITARIOS": 2.5,
#         "ESTACIONAMIENTOS": 2,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "252321.96",
#         "TOTAL": "478321.96",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Bulukax+Lote+16,+Manzana+191,+Revisar+Payo+Obispo,+Revisar+Othón+P.+Blanco,+Revisar+Quintana+Roo,+77083",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2014347955,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Avenida San Mateo 1932 Interior 48 Calle Interior Mar Caspio Up 7 Manzana 34 Coto Sol",
#         "COLONIA": "Belissimo Habitat Residencial",
#         "ALCALDIA/MUNICIPIO": "Zapopan",
#         "ESTADO": "Jalisco",
#         "CP": 45200,
#         "TERRENO": 80.0,
#         "CONSTRUCCIÓN": "80.67",
#         "RECAMARAS": null,
#         "SANITARIOS": 1.5,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "110400",
#         "TOTAL": "336400",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Avenida+San+Mateo+1932+Interior+48+Calle+Interior+Mar+Caspio+Up+7+Manzana+34+Coto+Sol,+Belissimo+Habitat+Residencial,+Zapopan,+Jalisco,+45200",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "DESCONOCIDA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2014248174,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Aquiles Serdan Número 100",
#         "COLONIA": "Cuauhtémoc",
#         "ALCALDIA/MUNICIPIO": "Cuauhtémoc",
#         "ESTADO": "Colima",
#         "CP": 28500,
#         "TERRENO": 538.0,
#         "CONSTRUCCIÓN": "320",
#         "RECAMARAS": 4,
#         "SANITARIOS": 4,
#         "ESTACIONAMIENTOS": 3,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "422092.80",
#         "TOTAL": "648092.80",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Aquiles+Serdan+Número+100,+Cuauhtémoc,+Cuauhtémoc,+Colima,+28500",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2014148271,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "De Los Monarcas Número 1932, Lote 52, Manzana 4.",
#         "COLONIA": "Parque Rotario",
#         "ALCALDIA/MUNICIPIO": "Chihuahua",
#         "ESTADO": "Chihuahua",
#         "CP": 31000,
#         "TERRENO": 120.05,
#         "CONSTRUCCIÓN": "41.98",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "98400",
#         "TOTAL": "324400",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=De+Los+Monarcas+Número+1932,+Lote+52,+Manzana+4.,+Parque+Rotario,+Chihuahua,+Chihuahua,+31000",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2014049167,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Priv. Mision De San Javier Número 19000 Vivienda 19 Lote 04 Manzana 68",
#         "COLONIA": "Misión De Las Californias",
#         "ALCALDIA/MUNICIPIO": "Tijuana",
#         "ESTADO": "Baja California",
#         "CP": 22207,
#         "TERRENO": 76.24,
#         "CONSTRUCCIÓN": "57.9",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "86784",
#         "TOTAL": "312784",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Priv.+Mision+De+San+Javier+Número+19000+Vivienda+19+Lote+04+Manzana+68,+Misión+De+Las+Californias,+Tijuana,+Baja+California,+22207",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "SENTENCIA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 1366237799,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Código Postal 77524 Departamento01 Edificio 05 \"17, 18 Y 19 \" 21 Benito Juarez Benito Juarez Código Postal 77524 Quintana Roo",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Benito Juarez",
#         "ESTADO": "Quintana Roo",
#         "CP": 77524,
#         "TERRENO": 1075.4,
#         "CONSTRUCCIÓN": "66.48",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "32100",
#         "TOTAL": "258100",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Código+Postal+77524+Departamento01+Edificio+05+17,+18+Y+19+21+Benito+Juarez+Benito+Juarez+Código+Postal+77524+Quintana+Roo,+nan,+Benito+Juarez,+Quintana+Roo,+77524",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 1366137829,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Predio Tepopotla Al Poniente De La Poblacion San Rafael Ixtapalucan Código Postal 74100 Tlahuapan Tlahuapan Código Postal 74100 Puebla",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Tlahuapan",
#         "ESTADO": "Puebla",
#         "CP": 74100,
#         "TERRENO": 2240.0,
#         "CONSTRUCCIÓN": " -   ",
#         "RECAMARAS": null,
#         "SANITARIOS": null,
#         "ESTACIONAMIENTOS": null,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "9900",
#         "TOTAL": "235900",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Predio+Tepopotla+Al+Poniente+De+La+Poblacion+San+Rafael+Ixtapalucan+Código+Postal+74100+Tlahuapan+Tlahuapan+Código+Postal+74100+Puebla,+nan,+Tlahuapan,+Puebla,+74100",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 417755205,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Circuito Colinas Del Carmen, 161, Lote 29 Manzana 3, El Carmen, Leon, Guanajuato",
#         "COLONIA": "El Carmen",
#         "ALCALDIA/MUNICIPIO": "León",
#         "ESTADO": "Guanajuato",
#         "CP": 37299,
#         "TERRENO": 83.25,
#         "CONSTRUCCIÓN": "83",
#         "RECAMARAS": 3,
#         "SANITARIOS": 1.5,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "129792",
#         "TOTAL": "355792",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Circuito+Colinas+Del+Carmen,+161,+Lote+29+Manzana+3,+El+Carmen,+Leon,+Guanajuato,+El+Carmen,+León,+Guanajuato,+37299",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "DESCONOCIDA",
#         "ESTADO_DE_VIVIENDA": null
#     }
# ]
