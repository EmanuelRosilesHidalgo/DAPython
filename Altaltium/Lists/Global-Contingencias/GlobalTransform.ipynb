# %%
import pandas as pd
import re
import unicodedata
import json
from fuzzywuzzy import process

# %%
csv_file_path = 'LISTAS VIGENTES\MONESIS GLOBAL AGOSTO 2024.csv'

# %%
try:
    df = pd.read_csv(csv_file_path, encoding='utf-8', delimiter=";")
except UnicodeDecodeError:
    df = pd.read_csv(csv_file_path, encoding='latin1', delimiter=";")

df.dropna(how='all', inplace=True)

# %%
df.columns = df.columns.str.strip()
df.columns
# Out:
# Index(['ID', 'VEHICULO', 'FECHA DE ULT ACT', 'NOMBRE',
#        'MACRO ETAPA ACTUALIZADA', 'MICRO ETAPA ACTUALIZADA', 'EXPEDIENTE',
#        'JUZGADO', 'PLAZA JURISDICCION', 'ESTADO JURISDICCION', 'DESPACHO',
#        'SALDO INFONAVIT ACTUALIZADO', 'COFI', 'AVALUO ORIGINAL_ORG',
#        'AVALUO REFERENCIA_ACT', 'MONEDA', 'GTIA_EDO', 'GTIA_MPIO',
#        'GTIA_COLONIA', 'GTIA_UBICACION', 'GTIA_CODPOSTAL', 'M2 TERRENO',
#        'M2 CONSTRUCCION', 'FECHA ORIGEN', 'IMPORTE CONCEDIDO VALORIZADO',
#        'CAPITAL ACT', 'INT ORD ACT', 'SDO CONT ACT', 'INT MOR + ACC ACT',
#        'ADEUD TOT ACT', 'Precio individual nuevo',
#        'Precio Mejorado paquete nuevo'],
#       dtype='object')

# %%
def rename_columns(df):

    df_renamed = df.rename(columns={
        'ID': 'FOLIO',
        'MICRO ETAPA ACTUALIZADA': 'ETAPA',
        'GTIA_EDO': 'ESTADO',
        'GTIA_MPIO': 'MUNICIPIO',
        'GTIA_COLONIA': 'COLONIA',
        'GTIA_UBICACION': 'CALLE_Y_NUMERO',
        'GTIA_CODPOSTAL': 'CP',
        'M2 CONSTRUCCION': 'CONSTRUCCION',
        'M2 TERRENO': 'TERRENO',
        'Precio individual nuevo': '2DO_PAGO'
    })
    return df_renamed

def add_columns(df):
    df["LISTA"] = "MONESIS GLOBAL"

    return df


df = rename_columns(df)
df = df.apply(add_columns, axis=1)

# %% [markdown]
# <h3>LIMPIEZA DE NUMEROS</h3>

# %%
def number_cleaning(df):
    # Limpiar caracteres no numéricos en 'FOLIO' y 'CP'
    df["FOLIO"] = df["FOLIO"].replace({r'\D': ''}, regex=True)
    df["CP"] = df["CP"].replace({r'\D': ''}, regex=True)

    # Convertir a números, manejando errores y valores no convertibles
    df["FOLIO"] = pd.to_numeric(df["FOLIO"], errors='coerce')
    df["CP"] = pd.to_numeric(df["CP"], errors='coerce')

    # Rellenar valores NaN con 0 y convertir a enteros
    df["FOLIO"] = df["FOLIO"].fillna(0).astype(int)
    df["CP"] = df["CP"].fillna(0).astype(int)

    # Limpiar caracteres en '2DO_PAGO' y convertir a float
    df["2DO_PAGO"] = df["2DO_PAGO"].replace({r'\$': '', ',': ''}, regex=True)
    df["2DO_PAGO"] = pd.to_numeric(df["2DO_PAGO"], errors='coerce')  # Convertir a float

    return df

df = number_cleaning(df)

# %% [markdown]
# <h3>LIMPIEZA DE TEXTO</h3>

# %%
from word2number_es import w2n

def remove_punctuation(text):
    if isinstance(text, str):
        clean = re.sub(r'[\-:;]', ' ', text)
        clean_spaces = ' '.join(clean.split())
        return clean_spaces
    
    return text

"""def safe_word_to_number(text):
    if isinstance(text, str):
        try:
            return word_to_number(text)
        except RecursionError:
            return text
    return text"""

df["COLONIA"] = df["COLONIA"].apply(remove_punctuation)
df["CALLE_Y_NUMERO"] = df["CALLE_Y_NUMERO"].apply(remove_punctuation)
df["MUNICIPIO"] = df["MUNICIPIO"].apply(remove_punctuation)
df["ESTADO"] = df["ESTADO"].apply(remove_punctuation)

# %% [markdown]
# <h3>NORMALIZAR DIRECCIONES</h3>

# %%
def normalizar_direccion(df):
    direccion = df["CALLE_Y_NUMERO"]
    # Asegurarse de que la dirección no sea NaN
    if pd.isna(direccion):
        return ''
    
    # Eliminar las comas
    direccion = direccion.replace(',', '')
    
    # Añadir espacio antes y después de números cuando no haya espacio
    direccion = re.sub(r'(?<=\D)(?=\d)', ' ', direccion)
    direccion = re.sub(r'(?<=\d)(?=\D)', ' ', direccion)
    
    # Añadir punto a "ESQ" solo si no lo tiene
    direccion = re.sub(r'\bESQ\b(?!\.)', 'ESQ.', direccion, flags=re.IGNORECASE)
    
    # Reemplazar comillas dobles con comillas simples o eliminarlas
    direccion = direccion.replace('""', '"')
    direccion = direccion.replace('"', '')
    
    # Normalizar caracteres Unicode
    direccion = unicodedata.normalize('NFKC', direccion)
    
    # Reemplazar abreviaturas específicas, considerando todas las combinaciones de mayúsculas y minúsculas
    direccion = re.sub(r'\bNUM\. EXT\.\b', '', direccion, flags=re.IGNORECASE)  # Eliminar "NUM. EXT."
    direccion = re.sub(r'\s*\.\s*', ' ', direccion)
    direccion = re.sub(r'\bEXT\b', '', direccion, flags=re.IGNORECASE)  # Eliminar "NUM. EXT."
    direccion = re.sub(r'\bEXT\. \b', '', direccion, flags=re.IGNORECASE)  # Eliminar "NUM. EXT."
    direccion = re.sub(r'\bNUM\.\b', '', direccion, flags=re.IGNORECASE)  # Eliminar "NUM."
    direccion = re.sub(r'\bEXT\.\b', '', direccion, flags=re.IGNORECASE)  # Eliminar "NUM."
    direccion = re.sub(r'\bNUM\b', '', direccion, flags=re.IGNORECASE)  # Eliminar "NUM."
    direccion = re.sub(r'\bNUMERO\b', '', direccion, flags=re.IGNORECASE)  # Eliminar "NUMERO"
    direccion = re.sub(r'\bOf\b', '', direccion, flags=re.IGNORECASE)  # Eliminar "NUMERO"
    direccion = re.sub(r'\bNo\b', '', direccion, flags=re.IGNORECASE)  # Eliminar "NUMERO"
    direccion = re.sub(r'\bNUMERO\b', '', direccion, flags=re.IGNORECASE)  # Eliminar "NUMERO"
    direccion = re.sub(r'\bNUM\. INT\b', '', direccion, flags=re.IGNORECASE)  # Eliminar "NUM. INT"
    direccion = re.sub(r'\bLt\b', 'Lote', direccion, flags=re.IGNORECASE)  # Reemplazar "Lt." por "Lote"
    direccion = re.sub(r'\bL\.T\.\b', 'Lote', direccion, flags=re.IGNORECASE)  # Reemplazar "L.T." por "Lote"
    direccion = re.sub(r'\bLote\b', 'Lote', direccion, flags=re.IGNORECASE)  # Reemplazar "Lote" sin abreviatura
    direccion = re.sub(r'\bMZA\b', 'Manzana', direccion, flags=re.IGNORECASE)  # Reemplazar "Mza." por "Manzana"
    direccion = re.sub(r'\bM\.Z\.A\.\b', 'Manzana', direccion, flags=re.IGNORECASE)  # Reemplazar "M.Z.A." por "Manzana"
    direccion = re.sub(r'\bManzana\b', 'Manzana', direccion, flags=re.IGNORECASE)  # Reemplazar "Manzana" sin abreviatura
    
    # Reemplazar abreviaturas de calles
    direccion = re.sub(r'\bCalle\b', '', direccion, flags=re.IGNORECASE)  # Eliminar "Calle"
    direccion = re.sub(r'\bAv\.?\b', 'Avenida', direccion, flags=re.IGNORECASE)  # Reemplazar "Av." por "Avenida"
    
    # Reemplazar cualquier " - " o " . " por un espacio simple
    direccion = re.sub(r'\s*-\s*', ' ', direccion)
    direccion = re.sub(r'\s*\.\s*', ' ', direccion)
    # Asegurar que los espacios múltiples sean reducidos a uno solo
    direccion = re.sub(r'\s+', ' ', direccion).strip()
    
    return df

# %%
# Diccionario de abreviaturas
abbreviations = {
    'C.P': 'Código Postal',
    'CP': 'Código Postal',

    'MZ': 'Manzana',
    'MZA': 'Manzana',
    'M': 'Manzana',

    'SM': 'Supermanzana',
    'S.M': 'Supermanzana',

    'U. H.': 'Unidad habitacional',

    'LTE': 'Lote',
    'L': 'Lote',

    'C': 'Calle',
    'CALL': 'Calle',

    'NUM': 'Número',
    'NÚM': 'Número',
    "NO": "Número",


    'AV': 'Avenida',
    'AVE': 'Avenida',

    'BLVD': 'Boulevard',

    'PL': 'Plaza',

    'PARQ': 'Parque',

    'EDIF': 'Edificio',

    'DEPTO': 'Departamento',

    'UNID': 'Unidad',

    'CIRC': "Circuito",

    "HDA": "Hacienda",

    "ED": "Edificio",

    "DEP": "Departamento",
    "DPTO": "Departamento",

    "FRAC": "Fraccionamiento",
    "FRACC": "Fraccionamiento",

    "EXT": "Exterior",

    "INT": "Interior",

    "VIV": "Vivienda",

    "COL": "Colonia"

}

# Función para limpiar direcciones
def clean_street(df):
    street = df["CALLE_Y_NUMERO"]
    street = str(street).upper()
    
    for abbreviation, full_form in abbreviations.items():
        # Usar expresión regular para reemplazar abreviaturas con o sin punto al final
        pattern = r'\b' + re.escape(abbreviation) + r'\b\.?'
        street = re.sub(pattern, full_form, street, flags=re.IGNORECASE)
    
    # Opcional: Eliminar dobles espacios resultantes de reemplazos
    street = ' '.join(street.split())
    df["CALLE_Y_NUMERO"] = street
    
    return df

# %%
df_inegi = pd.read_csv("INEGI.csv", delimiter=",")
df_inegi
def get_location(df):
    # Extract information from the row
    cp = df['CP']  # Postal Code
    #street = row['Dirección']  # Street name
    district = df['COLONIA']  # District
    municipality = df['MUNICIPIO']  # Municipality
    state = df['ESTADO']  # State

    if pd.notna(cp):
        cp = str(cp).zfill(5)
    
    df['CP'] = int(cp)
    
    # Filter the dataset to get data related to the Postal Code
    df_info_cp = df_inegi[df_inegi["cp"] == int(cp)]
    if df_info_cp.empty:
        df["CP"] = "Revisar CP " + cp
    else:
        print(cp)

        #normalized_data = []
        
        # Get lists for comparison
        list_district = df_info_cp["colonia"].tolist()
        print(list_district)
        list_municipality = df_info_cp["municipio"].tolist()
        list_state = df_info_cp["estado"].tolist()

            
        """    
        print(cp)
        print(district)
        print(municipality)
        """
        if pd.notna(district) and pd.notna(municipality) and pd.notna(state):
            print(district)
            print(municipality)
            municipality_match, percentage = process.extractOne(municipality, list_municipality)
            if percentage < 50:  # Conditional to match the CP with the municipality based on text similarity
                district_match = process.extractOne(district, list_district)
                state_match = process.extractOne(state, list_state)
                df['COLONIA'] = "REVISAR "+district_match[0]
                df['MUNICIPIO'] = "REVISAR "+municipality_match
                df['ESTADO'] = "REVISAR "+state_match[0]
            else:
                # Compare and normalize district, municipality, and state
                district_match = process.extractOne(district, list_district)
                state_match = process.extractOne(state, list_state)

                # Append the normalized data
                df['COLONIA'] = district_match[0] if district_match else None
                df['MUNICIPIO'] = municipality_match if municipality_match else None
                df['ESTADO'] = state_match[0] if state_match else None
        else:
            print("Values not found")
        # Convert all elements to uppercase
        #output_list = [str(item).upper() if isinstance(item, str) else item for item in normalized_data]
    return df

# %%
df = df.apply(get_location, axis = 1)
df = df.apply(clean_street, axis = 1)

df = df.apply(normalizar_direccion, axis=1)
# Out:
# 75859
# ['Guadalupe', 'Aveiro', 'San Miguel', 'Juquilita', 'Lázaro Cárdenas Sur', 'Maravillas', 'San Marcos Necoxtla', 'San Diego Chalma', 'San Isidro Sur', 'San Pablo Tepetzingo', 'Santa Cruz Acapa', '21 de Marzo', 'Misión Madrid', 'Municipio Libre', 'Mazateca', 'Vivir', 'Villas de la Loma', 'San Diego I', 'San Diego II']
# Values not found
# 31890
# ['Las Manzanas', 'San Buenaventura Centro', 'Los Flores']
# Values not found
# 38580
# ['Canoas', 'San Felipe de Jesús', 'Lagunilla de Puruagua', 'La Joya de Puruagua']
# Values not found
# 84230
# ['Villa de Andalucía', 'Obrera', 'Deportiva', 'INFONAVIT El Alamito', 'Lomas del Sol', 'Valle Bonito', 'Cueva de los Leones', 'Cerrada San Ángel', 'Las Praderas', 'Loma Linda', 'FOVISSSTE']
# Values not found
# 39713
# ['Luis Donaldo Colosio', 'Vista Hermosa', 'Paraíso', 'Palmera', 'Ampliación Arroyo Seco', 'Batalla Cardenista', 'Guerrero Es Primero', 'Agrícola', 'La Esmeralda', 'La Mica', 'Emperador Moctezuma', 'Nopalitos', 'Villa Sol', 'Leyes de Reforma', 'El Porvenir', 'La Venta', 'Las Flores', 'SEDESOL Uno', 'El Tanque', 'Valle del Palmar II', 'Plácido Domingo', 'Paraíso Palmar III', 'Betania', 'Tamarindos', 'Valle del Palmar I', 'Ampliación la Mica', 'Paso Limonero', 'Villas Real Hacienda']
# Values not found
# 75200
# ['San Miguel', 'Tepeaca Centro', 'Del Santuario', 'La Santísima', 'Santa Apolonia', 'Central de Abastos', 'San José', 'El Calvario', 'Santa Cruz Temilco', 'San Sebastián', 'Jamaica', 'El Vergel', 'Guadalupe', 'San Juan Negrete', 'San Diego', 'Hermosa Provincia', 'Lomas del Calvario', 'San Luis', 'Bella Vista', 'El Divino Salvador', 'Ecchomo', 'El Campo', 'Del Campo', 'Santa Cruz Tlahuilola']
# Values not found
# 93892
# ['Gutiérrez Zamora']
# Values not found
# 24157
# ['Buenavista', 'Turquesa', 'Rinconada', 'Residencial Vistancias', 'Club Residencial Azul', 'Mar Azul', 'Bicentenario', 'Paseo de los Bosques', 'San Joaquín', 'Puesta del Sol', 'San Joaquín', 'Santa Isabel', 'Residencial San Miguel', 'Privada Santa Ana', 'Privada San Joaquín', 'Playa Palmas', 'Las Esperanzas', 'Real del Carmen', 'Hacienda Dorada', 'Girasoles', 'Raíces', 'Villas del Carmen', 'Villa Magna', 'Villa Marina', 'Misión del Carmen', 'Reforma II Sección', 'La Esperanza', 'Evergreén', 'José Ortiz Ávila', 'Hacienda del Mar', 'San Román', 'Canterías', 'Villa Palmeras', '18 de Marzo', 'Privanzas']
# Values not found
# 72990
# ['San Martín', 'Chachapa', 'Ampliación San Lorenzo', 'SIGNORET']
# Values not found
# 77533
# ['Residencial Caracol', 'Supermanzana 313', 'Privada Altus', 'Supermanzana 54', 'Residencial Isla Azul', 'Supermanzana 49', 'Supermanzana 50', 'Supermanzana 51', 'Supermanzana 502', 'Supermanzana 503', 'Supermanzana 504', 'Supermanzana 505', 'Supermanzana 506', 'Supermanzana 507', 'Supermanzana 508', 'Supermanzana 509', 'Supermanzana 501', 'Supermanzana 500', 'Costa del Mar', 'Álamos I', 'Chamuyil', 'Malibú', 'Porto Alegre', 'Quetzales (Supermanzana 523)', 'Supermanzana 57', 'Framboyanes', 'Residencial Sol del Mayab', 'Paraíso Villas', 'Supermanzana 55', 'San José Bonampack', 'Las Torres', 'Supermanzana 312']
# Values not found
# 77533
# ['Residencial Caracol', 'Supermanzana 313', 'Privada Altus', 'Supermanzana 54', 'Residencial Isla Azul', 'Supermanzana 49', 'Supermanzana 50', 'Supermanzana 51', 'Supermanzana 502', 'Supermanzana 503', 'Supermanzana 504', 'Supermanzana 505', 'Supermanzana 506', 'Supermanzana 507', 'Supermanzana 508', 'Supermanzana 509', 'Supermanzana 501', 'Supermanzana 500', 'Costa del Mar', 'Álamos I', 'Chamuyil', 'Malibú', 'Porto Alegre', 'Quetzales (Supermanzana 523)', 'Supermanzana 57', 'Framboyanes', 'Residencial Sol del Mayab', 'Paraíso Villas', 'Supermanzana 55', 'San José Bonampack', 'Las Torres', 'Supermanzana 312']
# Values not found
# 24157
# ['Buenavista', 'Turquesa', 'Rinconada', 'Residencial Vistancias', 'Club Residencial Azul', 'Mar Azul', 'Bicentenario', 'Paseo de los Bosques', 'San Joaquín', 'Puesta del Sol', 'San Joaquín', 'Santa Isabel', 'Residencial San Miguel', 'Privada Santa Ana', 'Privada San Joaquín', 'Playa Palmas', 'Las Esperanzas', 'Real del Carmen', 'Hacienda Dorada', 'Girasoles', 'Raíces', 'Villas del Carmen', 'Villa Magna', 'Villa Marina', 'Misión del Carmen', 'Reforma II Sección', 'La Esperanza', 'Evergreén', 'José Ortiz Ávila', 'Hacienda del Mar', 'San Román', 'Canterías', 'Villa Palmeras', '18 de Marzo', 'Privanzas']
# Values not found
# 24157
# ['Buenavista', 'Turquesa', 'Rinconada', 'Residencial Vistancias', 'Club Residencial Azul', 'Mar Azul', 'Bicentenario', 'Paseo de los Bosques', 'San Joaquín', 'Puesta del Sol', 'San Joaquín', 'Santa Isabel', 'Residencial San Miguel', 'Privada Santa Ana', 'Privada San Joaquín', 'Playa Palmas', 'Las Esperanzas', 'Real del Carmen', 'Hacienda Dorada', 'Girasoles', 'Raíces', 'Villas del Carmen', 'Villa Magna', 'Villa Marina', 'Misión del Carmen', 'Reforma II Sección', 'La Esperanza', 'Evergreén', 'José Ortiz Ávila', 'Hacienda del Mar', 'San Román', 'Canterías', 'Villa Palmeras', '18 de Marzo', 'Privanzas']
# Values not found
# 90807
# ['El Alto', 'La Malinche', 'Villas del Sabinal']
# Values not found
# 24157
# ['Buenavista', 'Turquesa', 'Rinconada', 'Residencial Vistancias', 'Club Residencial Azul', 'Mar Azul', 'Bicentenario', 'Paseo de los Bosques', 'San Joaquín', 'Puesta del Sol', 'San Joaquín', 'Santa Isabel', 'Residencial San Miguel', 'Privada Santa Ana', 'Privada San Joaquín', 'Playa Palmas', 'Las Esperanzas', 'Real del Carmen', 'Hacienda Dorada', 'Girasoles', 'Raíces', 'Villas del Carmen', 'Villa Magna', 'Villa Marina', 'Misión del Carmen', 'Reforma II Sección', 'La Esperanza', 'Evergreén', 'José Ortiz Ávila', 'Hacienda del Mar', 'San Román', 'Canterías', 'Villa Palmeras', '18 de Marzo', 'Privanzas']
# Values not found
# 77533
# ['Residencial Caracol', 'Supermanzana 313', 'Privada Altus', 'Supermanzana 54', 'Residencial Isla Azul', 'Supermanzana 49', 'Supermanzana 50', 'Supermanzana 51', 'Supermanzana 502', 'Supermanzana 503', 'Supermanzana 504', 'Supermanzana 505', 'Supermanzana 506', 'Supermanzana 507', 'Supermanzana 508', 'Supermanzana 509', 'Supermanzana 501', 'Supermanzana 500', 'Costa del Mar', 'Álamos I', 'Chamuyil', 'Malibú', 'Porto Alegre', 'Quetzales (Supermanzana 523)', 'Supermanzana 57', 'Framboyanes', 'Residencial Sol del Mayab', 'Paraíso Villas', 'Supermanzana 55', 'San José Bonampack', 'Las Torres', 'Supermanzana 312']
# Values not found
# 87470
# ['Hacienda los Esteros', 'Miguel Hidalgo', 'Playa Sol', 'Lauro Villar', 'Los Nogales', 'Rodolfo Sánchez Taboada', 'Valle del Campestre', 'Praderas', 'Hacienda del Prado', 'JAD', 'Libre Comercio', 'Hacienda Praderas', 'Parque Industrial CYLSA']
# Values not found
# 52985
# ['La Cruz', 'Lomas de Guadalupe', 'Morelos', 'Rincón de la Charrería']
# Values not found
# 77539
# ['Supermanzana 107', 'Paraíso Maya', 'Urbi Villas del rey', 'Supermanzana 260', 'Real Las Quintas (Supermanzana 202)', 'Real Valencia', 'Cuna Maya (Supermanzana 203)', 'Arcos Paraíso', 'Paseo Kusamil', 'Punta Ikal', 'Paseo de Las Palmas', 'Prado Norte (Supermanzana 256)', 'Villas Lakin', 'Supermanzana 103', 'Hacienda Real del Caribe', 'Tierra Maya', 'Central de Abasto', 'Supermanzana 104', 'Supermanzana 105', 'Supermanzana 106', 'Supermanzana 200', 'México', 'ABC', 'Villas Otoch Paraíso']
# Values not found
# 39172
# ['Chichipico', 'La Villita', 'Los Amates (Adolfo Cienfuegos)', 'Santa Cruz', 'La Huerta', 'San Lucas', 'Santiago', 'Vicente Guerrero', 'Villita', 'Tlapochinalapa', 'Emiliano Zapata', 'Rinconada de Santiago', '6 de Noviembre']
# Values not found
# 29980
# ['La Laguna', 'Tuxtla Gutiérrez', 'Guadalupe', 'Catazaja']
# Values not found
# 39172
# ['Chichipico', 'La Villita', 'Los Amates (Adolfo Cienfuegos)', 'Santa Cruz', 'La Huerta', 'San Lucas', 'Santiago', 'Vicente Guerrero', 'Villita', 'Tlapochinalapa', 'Emiliano Zapata', 'Rinconada de Santiago', '6 de Noviembre']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55530
# ['El Gallito', 'San Jaco (El Gallito)', 'Santa Clara', 'El Gallito']
# Values not found
# 55000
# ['San Cristóbal Centro', 'Ecatepec Centro', 'La Cruz de San Cristóbal']
# Values not found
# 74480
# ['San Juan Coahuixtla', 'San Miguel Izúcar', 'Santo Tomás']
# Values not found
# 55220
# ['Jardines de San Gabriel', 'Jardines del Tepeyac', 'Vicente Guerrero', 'Emiliano Zapata 1a Sección A']
# Values not found
# 39172
# ['Chichipico', 'La Villita', 'Los Amates (Adolfo Cienfuegos)', 'Santa Cruz', 'La Huerta', 'San Lucas', 'Santiago', 'Vicente Guerrero', 'Villita', 'Tlapochinalapa', 'Emiliano Zapata', 'Rinconada de Santiago', '6 de Noviembre']
# Values not found
# 91808
# ['Álika', 'Riveras de Río Medio', 'Lomas del Río Medio V', 'Bahía Libre', 'Chalchihuecan', 'Renacimiento', 'Granjas de Rio Medio', 'Patria (Diez Hectáreas)', 'Condado de Valle Dorado', 'El Campanario', 'Geovillas los Pinos', 'Del Proletariado (Pica Pica)', 'Parke 2000', 'Costa Dorada', 'Los Torrentes', 'Geovillas los Pinos II', 'Colinas de San Jorge', 'Colinas de Santa Fe', 'Lomas de Río Medio IV', 'Heberto Castillo Martínez', 'Arboledas', 'Oasis', 'La Herradura', 'Real de los Pinos']
# Values not found
# 55220
# ['Jardines de San Gabriel', 'Jardines del Tepeyac', 'Vicente Guerrero', 'Emiliano Zapata 1a Sección A']
# Values not found
# 55210
# ['La Estrella', 'La Popular', 'Valle de Anáhuac Sección A']
# Values not found
# 55400
# ['Santa María Tulpetlac', 'Aldeas I', 'Aldeas II', 'Nieves', 'ISSEMYM']
# Values not found
# 55400
# ['Santa María Tulpetlac', 'Aldeas I', 'Aldeas II', 'Nieves', 'ISSEMYM']
# Values not found
# 24010
# ['Guadalupe', 'Pablo Garcia', 'San Francisco', 'Villa del Río', 'Guadalupe']
# Values not found
# 55400
# ['Santa María Tulpetlac', 'Aldeas I', 'Aldeas II', 'Nieves', 'ISSEMYM']
# Values not found
# 55400
# ['Santa María Tulpetlac', 'Aldeas I', 'Aldeas II', 'Nieves', 'ISSEMYM']
# Values not found
# 55400
# ['Santa María Tulpetlac', 'Aldeas I', 'Aldeas II', 'Nieves', 'ISSEMYM']
# Values not found
# 55400
# ['Santa María Tulpetlac', 'Aldeas I', 'Aldeas II', 'Nieves', 'ISSEMYM']
# Values not found
# 55400
# ['Santa María Tulpetlac', 'Aldeas I', 'Aldeas II', 'Nieves', 'ISSEMYM']
# Values not found
# 55400
# ['Santa María Tulpetlac', 'Aldeas I', 'Aldeas II', 'Nieves', 'ISSEMYM']
# Values not found
# 55400
# ['Santa María Tulpetlac', 'Aldeas I', 'Aldeas II', 'Nieves', 'ISSEMYM']
# Values not found
# 55400
# ['Santa María Tulpetlac', 'Aldeas I', 'Aldeas II', 'Nieves', 'ISSEMYM']
# Values not found
# 55400
# ['Santa María Tulpetlac', 'Aldeas I', 'Aldeas II', 'Nieves', 'ISSEMYM']
# Values not found
# 55400
# ['Santa María Tulpetlac', 'Aldeas I', 'Aldeas II', 'Nieves', 'ISSEMYM']
# Values not found
# 55400
# ['Santa María Tulpetlac', 'Aldeas I', 'Aldeas II', 'Nieves', 'ISSEMYM']
# Values not found
# 55000
# ['San Cristóbal Centro', 'Ecatepec Centro', 'La Cruz de San Cristóbal']
# Values not found
# 68335
# ['Linda Vista', 'Las Maravillas', 'Adolfo López Mateos', '12 de Julio', 'El Mirador', 'Papaloapan', 'Lomas del Ingenio', 'Santa Ana']
# Values not found
# 21387
# ['La Ventana Residencial', 'Caminos del Sol', 'Club Campestre de Mexicali - Golf', 'Foresta Residencial', 'Gran Foresta Residencial', 'Pórticos del Valle', 'Los Naranjos', 'Jardines de Calafia', 'Solidaridad Social', 'Popular Leandro Valle', 'Ampliación Solidaridad Social', 'Ladrillera Campestre', 'Rivera Campestre', 'Laguna Campestre', 'Diego Bustamante', 'Vista del Valle', 'Nuevo Milenio', '5 de Julio', 'Misión del Ángel', 'Lago del Sol Residencial', 'Camino del Sur']
# Values not found
# 77500
# ['Villas Tropicales', 'Cancún Centro', 'Supermanzana 20 Centro', 'Supermanzana 1 Centro', 'Supermanzana 2 Centro', 'Supermanzana 2a Centro', 'Supermanzana 3 Centro', 'Supermanzana 4 Centro', 'Supermanzana 5 Centro', 'Supermanzana 22 Centro', 'Supermanzana 23 Centro', 'Zona Hotelera', 'Residencial La Cascada', 'Supermanzana 52', 'Supermanzana 4 A', 'Juárez']
# Values not found
# 55000
# ['San Cristóbal Centro', 'Ecatepec Centro', 'La Cruz de San Cristóbal']
# Values not found
# 55000
# ['San Cristóbal Centro', 'Ecatepec Centro', 'La Cruz de San Cristóbal']
# Values not found
# 55070
# ['Carlos Salinas de Gortari', 'Colonial Ecatepec', '19 de Septiembre', 'Ampliación 19 de Septiembre', 'Plan de Arroyo', 'Jardines de Morelos Sección Cerros', 'Jardines de Morelos Sección Elementos', 'Jardines de Morelos Sección Flores', 'Jardines de Morelos Sección Fuentes', 'Jardines de Morelos Sección Islas', 'Jardines de Morelos Sección Bosques', 'Jardines de Morelos Sección Lagos', 'Jardines de Morelos Sección Montes', 'Jardines de Morelos Sección Playas', 'Jardines de Morelos Sección Ríos', 'Llanos de Morelos I', 'Villas del Sol', 'Llanos de Morelos II', 'Sol II', 'Julia Marin', 'Profopec (Polígonos VII)']
# Values not found
# 91028
# ['Olmeca']
# Values not found
# 90740
# ['Sección Segunda', 'Sección Primera', 'La Libertad', 'Alberto Juárez Blancas', 'Las Palomas']
# Values not found
# 94452
# ['Antonio Luna Andrade', 'Cumbre de Metlac', 'Moyoapan', 'Chiltepec', 'Sumidero']
# Values not found
# 55883
# ['Geovillas de Terranova 1a Sección', 'Real del Valle 1a Seccion', 'Las Brisas', 'Laguna de Chiconautla', 'Geovillas de Terranova 2a Sección', 'Real del Valle 2a Sección']
# Values not found
# 54767
# ['Granjas Lomas de Guadalupe']
# Values not found
# 55289
# ['Bugambilias de Aragón']
# Values not found
# 55289
# ['Bugambilias de Aragón']
# Values not found
# 54767
# ['Granjas Lomas de Guadalupe']
# Values not found
# 90740
# ['Sección Segunda', 'Sección Primera', 'La Libertad', 'Alberto Juárez Blancas', 'Las Palomas']
# Values not found
# 55883
# ['Geovillas de Terranova 1a Sección', 'Real del Valle 1a Seccion', 'Las Brisas', 'Laguna de Chiconautla', 'Geovillas de Terranova 2a Sección', 'Real del Valle 2a Sección']
# Values not found
# 54930
# ['Granjas San Pablo', 'Izcalli Rinconada', 'Jardines de los Claustros IV', 'Jardines de los Claustros V', 'La Granja', 'Llanura Verde', 'Pensamientos', 'San Pablo de las Salinas', 'San Pablo de las Salinas', 'Solidaridad Social (Lote 105)', 'Unidad Morelos 2da. Sección', 'Lote 92 (Las Rosas)', 'Las Granjas', 'Privada los Prados', 'Solar San Pablo', 'Quintas San Pablo', 'Lomas de San Pablo']
# Values not found
# 54930
# ['Granjas San Pablo', 'Izcalli Rinconada', 'Jardines de los Claustros IV', 'Jardines de los Claustros V', 'La Granja', 'Llanura Verde', 'Pensamientos', 'San Pablo de las Salinas', 'San Pablo de las Salinas', 'Solidaridad Social (Lote 105)', 'Unidad Morelos 2da. Sección', 'Lote 92 (Las Rosas)', 'Las Granjas', 'Privada los Prados', 'Solar San Pablo', 'Quintas San Pablo', 'Lomas de San Pablo']
# Values not found
# 96170
# ['Lealtad', 'Santa Ana', 'Luis Donaldo Colosio', 'San Judas Tadeo', 'San Antonio', 'El Manantial', 'Soconusco', 'San Pedro y San Pablo', 'Santa Cruz']
# Values not found
# 72490
# ['2da. Ampliación Guadalupe Hidalgo', 'Arboledas del Pedregal', 'Cabañas de Santa María', 'Granjas Puebla', 'Guadalupe Hidalgo', 'Lomas de Castillotla', 'San Ramón 1a Sección', 'San Ramón 2a Sección', 'San Ramón 3a Sección', 'San Ramón 4a Sección', 'El Sendero', 'Torres Madrid', 'INFONAVIT Agua Santa', 'S.U.T.E.R.M.', 'INFONAVIT Fuentes de San Bartolo', 'Luis Donaldo Colosio', 'Nuevo Plan de Ayala', 'Unidad Antorchista', 'Lomas del Sol', 'Villas Perisur', 'Felipe Carrillo Puerto', 'El Triunfo', 'Nueva Democracia', 'Lomas de San Valentín', 'Hacienda el Cobre', 'Luna', 'Antigua Hacienda', 'Marbella', 'La Giralda', 'Ampliación Unión Antorchista', 'Hacienda del Sur II', 'Hacienda del Sur', 'Joyas del Sur', 'Lomas de Atoyac', 'Los Limones', 'Magisterial Periferico Sur', 'Villas Diamante II', 'Villas San Antonio IV', 'Villas del Sol', 'Hacienda el Cobre 3a. Sección', 'Los Cerezos', 'Rincón de los Cipreses', '2a. Ampliación Unión Antorchista', 'Regina', 'La Chispa', 'Villas el Ensueño']
# Values not found
# 63176
# ['Cáp. Orozco', 'Colonial', 'Gustavo Díaz Ordaz']
# Values not found
# 83553
# ['Oriente', 'Brisas Del Golfo', 'Luis Donaldo Colosio', 'Nuevo Peñasco', 'Josefa Ortiz de Dominguez', 'San Jorge', 'Caracoles', 'El Cárcamo', 'La Termoeléctrica', 'Residencial la Providencia']
# Values not found
# 55714
# ['Residencial Plaza Coacalco', 'Rincón Coahuilense', 'San Lorenzo Tetlixtac', 'Niños Héroes', 'Los Almendros', 'Hacienda San Pablo', 'Potrero II', 'Los Olivos', 'Tetlacolili']
# Values not found
# 73340
# ['San Baltasar Xochitlaxco', 'San Miguel Tonalixco']
# Values not found
# 55885
# ['Privadas de Santa Catarina', 'Granjas Familiares', 'Tepexpan', 'Chimalpa', 'STUNAM', 'La Lola', 'La Lagunilla', 'San Martín (STUNAM)', 'Los Reyes', 'Misión San Agustín', 'La Cazuela Tepexpan (Santa María Magdalena)', 'Tepexpan (San Luis Grande)']
# Values not found
# 55714
# ['Residencial Plaza Coacalco', 'Rincón Coahuilense', 'San Lorenzo Tetlixtac', 'Niños Héroes', 'Los Almendros', 'Hacienda San Pablo', 'Potrero II', 'Los Olivos', 'Tetlacolili']
# Values not found
# 55125
# ['Aldeas de Aragón I', 'Aldeas de Aragón II']
# Values not found
# 95850
# ['Aarón Sáenz', 'Benito Juárez', 'Obrera', 'San Juan Bosco', 'Juan Díaz Covarrubias Centro', 'Chicago', 'Los Empleados', 'Chapala', 'La Plaza', 'Progreso']
# Values not found
# 75480
# ['Tecamachalco Centro']
# Values not found
# 21387
# ['La Ventana Residencial', 'Caminos del Sol', 'Club Campestre de Mexicali - Golf', 'Foresta Residencial', 'Gran Foresta Residencial', 'Pórticos del Valle', 'Los Naranjos', 'Jardines de Calafia', 'Solidaridad Social', 'Popular Leandro Valle', 'Ampliación Solidaridad Social', 'Ladrillera Campestre', 'Rivera Campestre', 'Laguna Campestre', 'Diego Bustamante', 'Vista del Valle', 'Nuevo Milenio', '5 de Julio', 'Misión del Ángel', 'Lago del Sol Residencial', 'Camino del Sur']
# Values not found
# 55883
# ['Geovillas de Terranova 1a Sección', 'Real del Valle 1a Seccion', 'Las Brisas', 'Laguna de Chiconautla', 'Geovillas de Terranova 2a Sección', 'Real del Valle 2a Sección']
# Values not found
# 55140
# ['Jardines de Aragón', 'Rinconada de Aragón']
# Values not found
# 54570
# ['Espíritu Santo', 'San Luis Ayucan', 'Santa Ana Jilotzingo', 'Santa María Mazatla', 'Endonica', 'Ensido', 'Monfi', 'La Cuesta']
# Values not found
# 56538
# ['Santa Bárbara']
# Values not found
# 56538
# ['Santa Bárbara']
# Values not found
# 56530
# ['Capilla I', 'Capilla III', 'Ixtapaluca Centro', 'Jacarandas I y II', 'La Venta', 'Zoquiapan', 'La Era', 'Geovillas San Jacinto', 'Real del Campo']
# Values not found
# 09696
# ['Miravalles']
# Values not found
# 56538
# ['Santa Bárbara']
# Values not found
# 56538
# ['Santa Bárbara']
# Values not found
# 94880
# ['Naranjal', 'Xochitla', 'Agrícola Úrsulo Galván']
# Values not found
# 97289
# ['La Hacienda', 'San Nicolás Del Sur', 'Ampliación La Hacienda']
# Values not found
# 55127
# ['Profopec IV (Polígono IV El Cegor)']
# Values not found
# 13300
# ['Santa Ana Centro', 'Santiago Centro', 'Santa Ana Poniente', 'Santa Ana Norte', 'Santiago Norte']
# Values not found
# 77539
# ['Supermanzana 107', 'Paraíso Maya', 'Urbi Villas del rey', 'Supermanzana 260', 'Real Las Quintas (Supermanzana 202)', 'Real Valencia', 'Cuna Maya (Supermanzana 203)', 'Arcos Paraíso', 'Paseo Kusamil', 'Punta Ikal', 'Paseo de Las Palmas', 'Prado Norte (Supermanzana 256)', 'Villas Lakin', 'Supermanzana 103', 'Hacienda Real del Caribe', 'Tierra Maya', 'Central de Abasto', 'Supermanzana 104', 'Supermanzana 105', 'Supermanzana 106', 'Supermanzana 200', 'México', 'ABC', 'Villas Otoch Paraíso']
# Values not found
# 09830
# ['El Manto', 'El Molino', 'Lomas El Manto', 'Los Ángeles', 'Paraje San Juan']
# Values not found
# 74129
# ['San Buenaventura Tecaltzingo', 'San Francisco Tepeyac', 'San Juan Tuxco', 'Santa María Moyotzingo', 'Tlacomulco', 'La Deportiva', 'Calyeca', 'Santa Anita']
# Values not found
# 85864
# ['FOVISSSTESON', 'Brisas del Valle', 'FOVISSSTE']
# Values not found
# 37408
# ['Barranca de Venaderos', 'León II', 'Balcón de las Hilamas', 'Paseos de Miravalle', 'Valle Imperial', 'Lomas del Pedregal', 'Paseos de La Cima Plus', 'Paseos de la Cima']
# Values not found
# 55885
# ['Privadas de Santa Catarina', 'Granjas Familiares', 'Tepexpan', 'Chimalpa', 'STUNAM', 'La Lola', 'La Lagunilla', 'San Martín (STUNAM)', 'Los Reyes', 'Misión San Agustín', 'La Cazuela Tepexpan (Santa María Magdalena)', 'Tepexpan (San Luis Grande)']
# Values not found
# 33923
# ['Pueblito de Allende', 'Loma de la Cruz']
# Values not found
# 94880
# ['Naranjal', 'Xochitla', 'Agrícola Úrsulo Galván']
# Values not found
# 55715
# ['Santa María Magdalena Huizachitla', 'Los Sabinos II']
# Values not found
# 55515
# ['Los Bordos', 'La Teja']
# Values not found
# 54473
# ['Campestre Liberación', 'Francisco Sarabia 1a. Sección', 'Bulevares del Lago', 'Francisco Sarabia 2a. Sección']
# Values not found
# 32780
# ['Praxedis G. Guerrero', 'Centenario']
# Values not found
# 24090
# ['Fracciorama 2000', 'Samulá', 'San Rafael', 'Valle del Sol', 'Residencial Villas Colosio', 'Villas Residencial', 'Nueva Era', 'Los Sauces', 'Villas de Samula', 'La Vista', 'Ampliación San Rafael', 'Rinconada Samula', 'Infonavit Samula', 'Las Campanillas', 'Flor de Liz', 'San Andrés', 'Girasoles', 'Villa Jazmín']
# Values not found
# 96870
# ['Tacoteno']
# Values not found
# 90750
# ['Sección Tercera Gurdia', 'Sección Cuarta', 'Sección Quinta', 'Exquitla', 'Xochicalco', 'CROM Santa Inés', 'Girasoles', 'Guardia', 'Las Américas', 'Privansa']
# Values not found
# 56530
# ['Capilla I', 'Capilla III', 'Ixtapaluca Centro', 'Jacarandas I y II', 'La Venta', 'Zoquiapan', 'La Era', 'Geovillas San Jacinto', 'Real del Campo']
# Values not found
# 92470
# ['Rancho Nuevo', 'Carmona y Valle', 'Tamalín']
# Values not found
# 56530
# ['Capilla I', 'Capilla III', 'Ixtapaluca Centro', 'Jacarandas I y II', 'La Venta', 'Zoquiapan', 'La Era', 'Geovillas San Jacinto', 'Real del Campo']
# Values not found
# 56530
# ['Capilla I', 'Capilla III', 'Ixtapaluca Centro', 'Jacarandas I y II', 'La Venta', 'Zoquiapan', 'La Era', 'Geovillas San Jacinto', 'Real del Campo']
# Values not found
# 69840
# ['San Miguel Achiutla']
# Values not found
# 40914
# ['Santa Rosa de Lima (Santa Rosa)', 'Papanoa', 'La Palma', 'Los Laureles', 'Rancho Alegre del Llano']
# Values not found
# 56356
# ['Tejedores', 'Jugueteros', 'Canteros', 'Talabarteros', 'Plateros', 'Vidrieros', 'Santa Cruz']
# Values not found
# 56530
# ['Capilla I', 'Capilla III', 'Ixtapaluca Centro', 'Jacarandas I y II', 'La Venta', 'Zoquiapan', 'La Era', 'Geovillas San Jacinto', 'Real del Campo']
# Values not found
# 54300
# ['Villa del Carbón']
# Values not found
# 85864
# ['FOVISSSTESON', 'Brisas del Valle', 'FOVISSSTE']
# Values not found
# 72810
# ['Residencial La Mezza', 'San Andrés Cholula Centro', 'Santa Catarina', 'El Puente', 'Las Américas', 'Futura', 'Santo Niño', 'De la Santísima', 'Santiago Xicohtenco', 'San Juan Aquiahuac', 'Bertha', 'La Alfonsina', 'Aztlán', 'La Aureola', 'San Miguel', 'Santa María', 'Santa María', 'Zona de Profesores', 'Lumaha']
# Values not found
# 97386
# ['Tixpéhual']
# Values not found
# 56538
# ['Santa Bárbara']
# Values not found
# 85864
# ['FOVISSSTESON', 'Brisas del Valle', 'FOVISSSTE']
# Values not found
# 09850
# ['San Juan Xalpa', 'San Nicolás Tolentino', 'Santa María del Monte']
# Values not found
# 09140
# ['Santa Martha Acatitla Norte']
# Values not found
# 09140
# ['Santa Martha Acatitla Norte']
# Values not found
# 56530
# ['Capilla I', 'Capilla III', 'Ixtapaluca Centro', 'Jacarandas I y II', 'La Venta', 'Zoquiapan', 'La Era', 'Geovillas San Jacinto', 'Real del Campo']
# Values not found
# 31650
# ['Portales del Valle', 'Laderas de San Guillermo Etapa II', 'Aquiles Serdán', 'CERESO', 'Centro Santa Eulalia', 'San Guillermo (Santa Elena)', 'Laderas de San Guillermo', 'El Ranchito']
# Values not found
# 31650
# ['Portales del Valle', 'Laderas de San Guillermo Etapa II', 'Aquiles Serdán', 'CERESO', 'Centro Santa Eulalia', 'San Guillermo (Santa Elena)', 'Laderas de San Guillermo', 'El Ranchito']
# Values not found
# 54400
# ['Benito Juárez 1a. Sección (Cabecera Municipal)']
# Values not found
# 57809
# ['Rey Nezahualcóyotl']
# Values not found
# 55070
# ['Carlos Salinas de Gortari', 'Colonial Ecatepec', '19 de Septiembre', 'Ampliación 19 de Septiembre', 'Plan de Arroyo', 'Jardines de Morelos Sección Cerros', 'Jardines de Morelos Sección Elementos', 'Jardines de Morelos Sección Flores', 'Jardines de Morelos Sección Fuentes', 'Jardines de Morelos Sección Islas', 'Jardines de Morelos Sección Bosques', 'Jardines de Morelos Sección Lagos', 'Jardines de Morelos Sección Montes', 'Jardines de Morelos Sección Playas', 'Jardines de Morelos Sección Ríos', 'Llanos de Morelos I', 'Villas del Sol', 'Llanos de Morelos II', 'Sol II', 'Julia Marin', 'Profopec (Polígonos VII)']
# Values not found
# 98730
# ['El Tule', 'Gral. Pánfilo Natera Centro', 'Santa Cruz', 'Buenavista', 'Magisterial', 'Presidentes', 'Santa Fe', 'San Juan Bautista', 'Piedra Azul', 'Las Animas', 'Barrio Alto', 'San Rafael']
# Values not found
# 56225
# ['Lomas de Cristo', 'Villas de Tolimpa', 'Leyes de Reforma', 'Fray Servando Teresa de Mier', 'Ampliación Leyes de Reforma']
# Values not found
# 75160
# ['Nuevo Progreso', 'San Salvador el Seco', 'Tecoac', 'Quecholac', 'Jilotepec', 'Tecamachalco', 'San Juan', 'San Miguel', 'Doctores']
# Values not found
# 31870
# ['Santa Fe', 'Galeana', 'Abdenago C. García (Lagunitas)', 'La Angostura', 'Lebarón']
# Values not found
# 85864
# ['FOVISSSTESON', 'Brisas del Valle', 'FOVISSSTE']
# Values not found
# 96343
# ['El Paraíso', 'Las Palmas', 'Canticas', 'Estero del Pantano', 'Calzadas (Kilómetro 14)', 'Residencial las Olas', 'El Kilómetro Diecisiete', 'Villas Ana María', 'Punta Verde']
# Values not found
# 81430
# ['Agustina Ramírez', 'Niños Héroes', 'El Pedregal', 'Privada San Felipe']
# Values not found
# 40895
# ['Las Gatas', 'Cerro del Vigia', 'La Ropa']
# Values not found
# 36437
# ['El Carmen', 'El Toro', 'El Anteojo (El Cuatro)', 'El Suspiro (El Venado)', 'El Venado', 'La Martinica', 'San Rafael (Posta el Cuatro)', 'Las Tablas', 'Monte de Lara', 'Reserva del Venado', 'San Rafael']
# Values not found
# 62974
# ['Campo Chalpa', 'Los Amates', 'Mariano Matamoros', 'Alondra', 'Cuatro Caminos', 'Nuevo Xochimilco', 'Santa Lucía']
# Values not found
# 74280
# ['Insurgentes', 'El Carmen', 'Guadalupe Victoria', 'La Carolina', 'San José Cuauhtémoc', 'Santa Mónica']
# Values not found
# 22813
# ['Colinas del Paraíso', 'Las Torres', 'Colinas de La Presa', 'Cumbres de La Presa', 'Colinas del Magisterio', 'Nuevo Milenio', 'Mar de Cortez', 'Misiones de La Presa 1', 'Misiones de La Presa 2', 'Misiones de Altamar', 'Mar de Ensenada', 'Lomas de la Presa', 'Residencial del Sol', 'Alta Mar', 'INFONAVIT Nuevo Milenio', 'Misiones del Paraíso']
# Values not found
# 54425
# ['Vicente Guerrero 2a. Sección', 'Vicente Guerrero 1a. Sección']
# Values not found
# 56037
# ['San Alberto', 'Nonoalco', 'Arboledas']
# Values not found
# 72543
# ['Alseseca']
# Values not found
# 06080
# ['Centro (Área 8)']
# Values not found
# 56538
# ['Santa Bárbara']
# Values not found
# 21387
# ['La Ventana Residencial', 'Caminos del Sol', 'Club Campestre de Mexicali - Golf', 'Foresta Residencial', 'Gran Foresta Residencial', 'Pórticos del Valle', 'Los Naranjos', 'Jardines de Calafia', 'Solidaridad Social', 'Popular Leandro Valle', 'Ampliación Solidaridad Social', 'Ladrillera Campestre', 'Rivera Campestre', 'Laguna Campestre', 'Diego Bustamante', 'Vista del Valle', 'Nuevo Milenio', '5 de Julio', 'Misión del Ángel', 'Lago del Sol Residencial', 'Camino del Sur']
# Values not found
# 55050
# ['El Salado', 'La Pradera', 'Vivienda del Taxista', 'Adolfo Ruiz Cortines', 'Aquiles Serdán', 'Bosques de Ecatepec', 'Residencial Fuentes de Ecatepec', 'Gustavo Baz Prada', 'Izcalli Jardines', 'Nuevo Diaz Ordaz', 'San Martín de Porres', 'Rinconada San Martín', 'Hacienda Santa María', 'Ex Rancho Jajalpa', 'Rancho Jajalpa', 'Pirules de Villancico 2a Sección']
# Values not found
# 54710
# ['El Cerrito', 'Las Tinajas', 'Bellavista', 'San José Buenavista', 'El Rosario', 'San José Huilango', 'San Pablo de los Gallos', 'Santa María Tianguistengo', 'Lomas de los Angeles', 'Ejido Santa María Tianguistengo', 'La Era', 'Ejido Santiago Cuautlalpan']
# Values not found
# 75700
# ['Tehuacán Centro']
# Values not found
# 32886
# ['San Luis', 'El Oasis', 'Nueva Holanda', 'Los Cienes']
# Values not found
# 94296
# ['Hípico', 'Manlio Fabio Altamirano (Lecheros)', 'Manuel Nieto', 'Revolución', 'TAMSA', 'Virginia Cordero de Murillo Vidal']
# Values not found
# 83480
# ['Del Bosque']
# Values not found
# 36437
# ['El Carmen', 'El Toro', 'El Anteojo (El Cuatro)', 'El Suspiro (El Venado)', 'El Venado', 'La Martinica', 'San Rafael (Posta el Cuatro)', 'Las Tablas', 'Monte de Lara', 'Reserva del Venado', 'San Rafael']
# Values not found
# 90780
# ['Xicohtzingo', 'Santa Filomena', 'San Isidro', 'Guadalupe', 'El Rancho', 'El Llano', 'Capulín', 'El Cerrito', 'Chalma', 'Techaloya', 'El Llano 2', 'El Llano 1']
# Values not found
# 97240
# ['Francisco I Madero']
# Values not found
# 96150
# ['Nueva Esperanza', 'Comunal', 'Sayula de Alemán', 'Belem', 'Canapa', 'Pobre']
# Values not found
# 93996
# ['Alto de Viñas', 'Gral. Desiderio Pavón', 'La Cruz', 'Maza']
# Values not found
# 83553
# ['Oriente', 'Brisas Del Golfo', 'Luis Donaldo Colosio', 'Nuevo Peñasco', 'Josefa Ortiz de Dominguez', 'San Jorge', 'Caracoles', 'El Cárcamo', 'La Termoeléctrica', 'Residencial la Providencia']
# Values not found
# 55070
# ['Carlos Salinas de Gortari', 'Colonial Ecatepec', '19 de Septiembre', 'Ampliación 19 de Septiembre', 'Plan de Arroyo', 'Jardines de Morelos Sección Cerros', 'Jardines de Morelos Sección Elementos', 'Jardines de Morelos Sección Flores', 'Jardines de Morelos Sección Fuentes', 'Jardines de Morelos Sección Islas', 'Jardines de Morelos Sección Bosques', 'Jardines de Morelos Sección Lagos', 'Jardines de Morelos Sección Montes', 'Jardines de Morelos Sección Playas', 'Jardines de Morelos Sección Ríos', 'Llanos de Morelos I', 'Villas del Sol', 'Llanos de Morelos II', 'Sol II', 'Julia Marin', 'Profopec (Polígonos VII)']
# Values not found
# 59730
# ['Bellas Torres', 'El Arco', 'Guadalupe Victoria', 'La Olla', 'Las Huertas', 'Lázaro Cárdenas', 'Lomas de Ecuandureo', 'San Francisco', 'Ecuandureo']
# Values not found
# 95264
# ['Punta Tiburón, Residencial, Marina y Golf', 'Las Lomas Residencial', 'El Sendero Residencial', 'Dos Riberas Residencial y Club de Golf', 'Las Olas Residencial', 'Mallorca Residencial', 'Costa Diamante', 'Residencial las Higueras', 'El Conchal', 'Playas del Conchal', 'Rincón del Conchal', 'Playa de la Libertad', 'Cormorán', 'Isla del Amor', 'Club de Golf Villa Rica', 'Vista Bella', 'Paraíso del Estero (La Burbuja)', 'La Matoza (Acapulquito)', 'Lomas Diamante', 'Kilómetro Cuatro', 'Lomas del Sol', 'Residencial Playa Dorada']
# Values not found
# 75784
# ['Ingeniero Pastor Rouaix', 'La Purísima', 'La Purísima 1a Secc', 'Sotolin']
# Values not found
# 72499
# ['Balcones del Sur', 'S.N.T.E.', 'Constitución Mexicana', 'Lares de San Alfonso', 'Santa Lucia', 'Fraternidad Antorchista', 'Villa los Encinos', 'Ampliación Fraternidad Antorchista', 'Cabañas del Lago', 'Valle de San Ignacio', 'Santa Lucia', 'Valle de Anáhuac']
# Values not found
# 62760
# ['Emiliano Zapata Centro', 'El Zapote']
# Values not found
# 25600
# ['Frontera Centro']
# Values not found
# 85430
# ['Golondrinas', 'Punta Arena', 'Punta de Lastre', 'Termoeléctrica', 'Monte Lolita', 'Las Batuecas']
# Values not found
# 93628
# ['La Rivera de Puntilla', 'Luis Segura', 'Puntilla Aldama', 'Vega de San Marcos', 'Galvarino Barria Pérez']
# Values not found
# 83284
# ['Santa Anita Residencial', 'Quinta Esmeralda', 'Las Peredas', 'San Fermín', 'Las Tres Reynas', 'Casa Linda', 'Costa del Sol', 'Palo Verde Indeur los Olivos', 'Nueva Esperanza', 'Los Girasoles', 'Hacienda los Alcatraces', 'Hacienda los Lirios', 'Villas del Sur', 'Agaves Residencial', 'Quintas del Sol Residencial', 'Los Olivos', 'Adolfo López Mateos']
# Values not found
# 60650
# ['Benito Juárez', '22 de Octubre']
# Values not found
# 95264
# ['Punta Tiburón, Residencial, Marina y Golf', 'Las Lomas Residencial', 'El Sendero Residencial', 'Dos Riberas Residencial y Club de Golf', 'Las Olas Residencial', 'Mallorca Residencial', 'Costa Diamante', 'Residencial las Higueras', 'El Conchal', 'Playas del Conchal', 'Rincón del Conchal', 'Playa de la Libertad', 'Cormorán', 'Isla del Amor', 'Club de Golf Villa Rica', 'Vista Bella', 'Paraíso del Estero (La Burbuja)', 'La Matoza (Acapulquito)', 'Lomas Diamante', 'Kilómetro Cuatro', 'Lomas del Sol', 'Residencial Playa Dorada']
# Values not found
# 22810
# ['Márques de León', 'Ejido Ruiz Cortines', 'Las Lomitas', 'Lomas y Jardines de Valle Verde', 'Popular Valle Verde 1', 'Lázaro Cárdenas 1', 'Lázaro Cárdenas 2', 'Luis Donaldo Colosio', 'Margaritas', '2 de Septiembre', 'Arco iris', 'Victoria', 'Lomitas III', 'Lomitas IV', 'Villas del Cedro I', 'Villas del Cedro II', 'Villas del Cedro III']
# Values not found
# 25092
# ['Lomas de Santa Cruz', 'Humberto Dávila Esquivel', 'Villas de San Lorenzo', 'Las Huertas de Lourdes']
# Values not found
# 09680
# ['Tenorios']
# Values not found
# 56343
# ['SUTAUR Oriente', 'San José Buenavista', 'Villa San Agustín Atlapulco', 'Jardines de San Agustín (La Isla, Sancho Ganadero)', 'Miramar', 'Tequesquinahuac', 'Tierra Santa (Maravillas)', 'Balcones de San Agustín', 'Ampliación San Agustín', 'Ampliación San Agustín Zona Poniente', 'Zona Comunal San Agustín', 'Diecisiete de Marzo', 'Israel', 'Los Olivos', 'Buenos Aires', 'Adolfo López Mateos', 'Ampliación San Agustín Zona Oriente']
# Values not found
# 08930
# ['Campamento 2 de Octubre']
# Values not found
# 09230
# ['Álvaro Obregón', 'Ejército de Oriente', 'El Paraíso', 'José María Morelos y Pavón']
# Values not found
# 76806
# ['Lomas de San Juan 2da. Sección', 'Pedregal de San Juan', 'San Cayetano', 'San Rafael', 'INDECO', 'INFONAVIT Pedregoso', 'Lomas de San Juan', 'México', 'Nuevo Parque Industrial', 'Nuevo San Juan', 'Deportiva', 'Comevi Banthi', 'Lomas de San Juan Sección Campestre', 'Villas del Parque', 'Villa las Flores', 'Magisterial', 'Las Haciendas', 'Haciendas del Pedregal', 'Villas del Pedregal', 'Villas del Pedregal 1a. Sección', 'Lomas de San Juan Sección Jardines', 'El Marfil', 'Lomas del Pedregal', 'Quintas de Guadalupe', 'Parque Industrial Nuevo San Juan', 'Centro Urbano Nuevo San Juan', 'Colibrí del Pedregal', 'Tomasita', 'Conca', 'El Pedregal', 'Jardines del Pedregal', 'Ferrocarrileros']
# Values not found
# 37420
# ['Buenavista', 'Loma Bonita']
# Values not found
# 72243
# ['Cuauhtémoc']
# Values not found
# 24400
# ['Tierra y Libertad', 'Lindavista', 'Champotón Centro', 'Cristóbal Colon', 'Pozo del Chenpek', 'La Cruz', 'Las Brisas', 'INFONAVIT Miraflores', 'Moch-Cohuo', 'Nueva Esperanza', 'Nueva Esperanza INFONAVIT', 'Plan-chac', 'Pozo del Monte', 'San Patricio', 'Tajonal', 'Venustiano Carranza', 'Arenal', 'Arrocera', 'Aserradero', 'Avenida', 'Cañaveral', 'Cardenal', 'Carolinas', 'Centenario', 'Cocal', 'Concepción Duran', 'Cuauhtémoc', 'Flamboyan', 'Guadalupe', 'Guadalupe Victoria', 'INFONAVIT', 'ISSSTE', 'La Playa', 'La Santa', 'Las Mercedes', 'Las Palomas', 'Laureles', 'Lázaro Cárdenas', 'Malecón', 'Manguitos', 'Nueva Jerusalén', 'Paraíso', 'Pedregal', 'Puente Viejo', 'Ulises Sansores', 'Huanal', 'Camaroncito', 'Microondas', 'Mirador', 'ISSFAM']
# Values not found
# 94298
# ['Joyas de Mocambo (Granjas los Pinos)', 'Adalberto Tejeda', 'Benito Juárez', 'La Cuchilla', 'Lázaro Cárdenas', 'Luis Echeverria Álvarez', 'Obrera', 'Villa Rica', 'Ylang Ylang', 'Ampliación Villa Rica', 'Playa de Oro Mocambo', 'Las Américas']
# Values not found
# 32950
# ['Julimes', 'La Regina', 'Presidentes', 'Tierra y Libertad']
# Values not found
# 90164
# ['Zaragoza', 'Ejido Totolac', 'Eucaliptos']
# Values not found
# 35020
# ['Los Álamos', 'La Esperanza', 'Rosales', 'Morales']
# Values not found
# 24200
# ['Palizada Centro', 'Aviación', 'Justicia Social', 'La Esperanza']
# Values not found
# 09750
# ['Insurgentes', 'La Polvorilla', 'Las Peñas']
# Values not found
# 09790
# ['San Lorenzo Tezonco']
# Values not found
# 65750
# ['Las Arboledas', 'General Zuazua Centro']
# Values not found
# 75259
# ['Ahuatepec']
# Values not found
# 37480
# ['El Paisaje', 'Las Arboledas', 'León Moderno', 'Prados Verdes', 'San Nicolás', 'Puerta San Rafael']
# Values not found
# 52926
# ['Jardines de Monterrey', 'Margarita Maza de Juárez', 'Villa San José']
# Values not found
# 72017
# ['Villa Paraíso', 'Nueva San Salvador', 'México 83', 'Venustiano Carranza', 'Nueva España', 'Las Sonatas', 'Villas Diamante', 'Portanova', 'Villas San José']
# Values not found
# 24200
# ['Palizada Centro', 'Aviación', 'Justicia Social', 'La Esperanza']
# Values not found
# 90224
# ['San Marcos Guaquilpan', 'Santiago Cuaula', 'San Cristóbal Zacacalco', 'La Venta', 'El Rosario', 'Barranca del Tizar', 'Puente del Ocomique']
# Values not found
# 81460
# ['Bebelamas INFONAVIT', 'Chutamonas', 'Del Evora', 'Morelos', 'Los Parques']
# Values not found
# 59617
# ['Los Naranjos de Castilla', 'Huertas del Cerrito', 'Jardines de San Joaquín', 'Huertas de San Joaquín', 'Prados de Valencia', 'Real de Valencia', 'Francisco J. Mújica I', 'Industrial Jericó', 'Lago del Bosque']
# Values not found
# 57460
# ['Juárez Pantitlán']
# Values not found
# 94880
# ['Naranjal', 'Xochitla', 'Agrícola Úrsulo Galván']
# Values not found
# 49500
# ['La Cofradía', 'Mazamitla']
# Values not found
# 24400
# ['Tierra y Libertad', 'Lindavista', 'Champotón Centro', 'Cristóbal Colon', 'Pozo del Chenpek', 'La Cruz', 'Las Brisas', 'INFONAVIT Miraflores', 'Moch-Cohuo', 'Nueva Esperanza', 'Nueva Esperanza INFONAVIT', 'Plan-chac', 'Pozo del Monte', 'San Patricio', 'Tajonal', 'Venustiano Carranza', 'Arenal', 'Arrocera', 'Aserradero', 'Avenida', 'Cañaveral', 'Cardenal', 'Carolinas', 'Centenario', 'Cocal', 'Concepción Duran', 'Cuauhtémoc', 'Flamboyan', 'Guadalupe', 'Guadalupe Victoria', 'INFONAVIT', 'ISSSTE', 'La Playa', 'La Santa', 'Las Mercedes', 'Las Palomas', 'Laureles', 'Lázaro Cárdenas', 'Malecón', 'Manguitos', 'Nueva Jerusalén', 'Paraíso', 'Pedregal', 'Puente Viejo', 'Ulises Sansores', 'Huanal', 'Camaroncito', 'Microondas', 'Mirador', 'ISSFAM']
# Values not found
# 90830
# ['La Magdalena Tlaltelulco']
# Values not found
# 65750
# ['Las Arboledas', 'General Zuazua Centro']
# Values not found
# 32886
# ['San Luis', 'El Oasis', 'Nueva Holanda', 'Los Cienes']
# Values not found
# 94880
# ['Naranjal', 'Xochitla', 'Agrícola Úrsulo Galván']
# Values not found
# 72190
# ['Estrella del Sur', 'San José Vista Hermosa', 'Cortijo la Herradura', 'San Miguel la Rosa', 'Concepción las Lajas']
# Values not found
# 32886
# ['San Luis', 'El Oasis', 'Nueva Holanda', 'Los Cienes']
# Values not found
# 72595
# ...
# LAS PIR�MIDES
# REYNOSA
# 88734
# ['Puerta Sur']
# PUERTA SUR
# REYNOSA
# 40880
# ['Joyas de Ixtapa', 'Morrocoy', 'Playas', 'La Puerta III', 'Miramar', 'Agua Azul', 'La Puerta del Sol', 'Cocos', 'Joyas del Mar', 'Porto Ixtapa', 'Porto Arcano', 'Finestre Ixtapa', 'Punta Ixtapa', 'Centro Comercial Los Patios', 'Villas Aqua Residencial', 'Flamingos', 'Las Perlas', 'Residencial Palmasola', 'Fragatas', '23 de Noviembre (Armada de México)', 'Entronque a Ixtapa', 'La Moraleja', 'La Puerta', 'Club de Golf Marina Ixtapa', 'Villas del Valle', 'Villas las Garzas', 'El Hujal', 'El Posquelite', 'Villas Pelícanos', 'Ixtapa Las Palmas', 'Pelícanos', 'Club de Golf Palma Real', 'Zona Hotelera I', 'Zona Hotelera II']
# EL HUJAL
# ZIHUATANEJO DE AZUETA
# 88285
# ['Blanca Navidad', 'Insurgentes', 'Lomas del Rosario', 'Parque Industrial Oradel', 'Parque Ferroviario Oradel', 'El Campanario', 'Villas del Oradel', 'Valles de Anáhuac', 'Los Ángeles']
# VILLAS DEL ORADEL
# NUEVO LAREDO
# 88595
# ['Corrales', 'Praderas de Oriente', 'El Banco', 'Nuevo Tamaulipas']
# NUEVO TAMAULIPAS
# REYNOSA
# 56386
# ['Rancho San Miguel', 'Hacienda de Costitlán', 'Real de Costitlán I', 'Real de Costitlán II', 'Geovillas de Costitlán', 'La Copalera', 'La Noria', 'San Patricio', 'Loma de Guadalupe']
# GEOVILLAS DE COSTITL�N
# CHICOLOAPAN
# 88290
# ['Viviendas Unidas', 'Tulipanes', 'Balcones del Valle', 'Los Cerezos', 'Los Ciruelos', 'Villas de la Concordia', 'La Paz', 'Lagos', 'Villas del Sol', 'Alfonso Gutiérrez', 'Los Aztecas', 'Los Encinos', 'El Nogal', 'Los Presidentes', 'Villa del Lago', 'Los Fresnos', 'Hacienda de la Concordia', 'Del Valle', 'Santa Elena', 'Santa Martha']
# SANTA MARTHA
# NUEVO LAREDO
# 88776
# ['Villas de Imaq', 'Voluntad y Trabajo', 'Villas Diamante']
# VILLAS DE IMAQ
# REYNOSA
# 88776
# ['Villas de Imaq', 'Voluntad y Trabajo', 'Villas Diamante']
# VILLAS DE IMAQ
# REYNOSA
# 31054
# ['Cerro Grande', 'Las Vencedoras', 'Villas del Sur', 'Loma Alta', 'San Agustín', 'San Jorge', 'San Lázaro', 'San Juan', 'Unidad Proletaria', 'Valle Escondido', 'Villa Dolores', 'Adelitas']
# CERRO GRANDE
# CHIHUAHUA
# 89570
# ['Hidalgo Oriente', 'Hidalgo Poniente']
# HIDALGO PONIENTE
# CIUDAD MADERO
# 23444
# ['Pablo L Martinez', 'Luis Donaldo Colosio', 'Lomas de Rosarito', 'Monte Real Residencial', 'Colinas Plus', 'Country del Mar']
# COUNTRY DEL MAR
# LOS CABOS
# 23435
# ['INFONAVIT', 'Las Veredas', 'FOVISSSTE las Veredas']
# LAS VEREDAS
# LOS CABOS
# 88799
# ['Misión Santa Fe', 'Pedro J Méndez', 'Los Arcos', 'Balcones de Alcalá', 'Paseo de las Flores', 'Los Almendros', 'Parque Industrial STIVA Alcalá', 'Los Olivos Oriente', 'Los Almendros II', 'Los Encinos', 'Pirámides', 'Valle Soleado', 'Los Olivos', 'Terranova']
# LAS PIR�MIDES
# REYNOSA
# 88796
# ['Parque Industrial American Industries Kimco', 'Las Anacuas', 'Artículo 127', 'Río Grande', 'El Rosario', 'México', 'Beatriz Anaya', 'Mano con Mano', 'El Oasis', 'Naranjitos', 'Arboledas de Juárez', 'Rincón de las Flores']
# RINC�N DE LAS FLORES
# REYNOSA
# 88796
# ['Parque Industrial American Industries Kimco', 'Las Anacuas', 'Artículo 127', 'Río Grande', 'El Rosario', 'México', 'Beatriz Anaya', 'Mano con Mano', 'El Oasis', 'Naranjitos', 'Arboledas de Juárez', 'Rincón de las Flores']
# RINC�N DE LAS FLORES
# REYNOSA
# 77710
# ['Playa del Carmen Centro', 'Calica', 'Playa del Carmen']
# MISION DE LAS FLORES
# SOLIDARIDAD
# 52240
# ['Chapultepec', 'El Calvario']
# CHAPULTEPEC
# CHAPULTEPEC
# 87130
# ['Chapultepec', 'Horacio Terán', 'Las Palomas', 'Vista Hermosa', 'Loma Real', 'Mediterráneo', 'Francisco Villa', 'Loma Linda', 'Integración Familiar', 'Viento Huasteco', 'Loma Bonita', 'Paseo de los Olivos', 'Los Prados', 'Las Fuentes', 'Auténticas Playas', 'Paseo de los Olmos']
# PASEO DE LOS OLIVOS
# VICTORIA
# 88730
# ['Granjas Económicas del Norte', 'Lomas del Real de Jarachinas Norte', 'Colinas del Pedregal', 'Lomas del Real de Jarachinas', 'Rosa Linda Guerrero', 'Valle del Vergel', 'Valle del Pedregal', 'Real del Cántaro']
# CAMPESTRE I
# REYNOSA
# 89603
# ['Los Olivos', 'Las Alamedas', 'Santa Mónica', 'Parque de la Pequeña y Mediana Industria', 'Valle Esmeralda Residencial', 'El Roble', 'Comercial FIMEX', 'Francisco I Madero', 'La Pedrera', 'Francisco Villa', 'Laguna de la Puerta', 'Magdaleno Aguilar', 'La Potosina', 'Corredor Industrial', 'Emiliano Zapata', 'José de Escandón', 'Fundadores', 'Industrial Guerrero', 'Jardines de Arboledas', 'Arrecifes', 'Municipios Libres', 'Paraíso', 'Unidad Satélite', 'Venustiano Carranza', 'Villas de Altamira', 'Villas las Flores', 'Satélite Chapala', 'Villas del Sol', 'De los Ríos', 'Municipios Libres las Negras', 'San Jacinto', 'Villa las Rosas', 'Paseo Real', 'Las Palmas', 'Ricardo Flores Magón', 'Francisco Medrano', 'Las Adelitas', 'Colinas de Altamira', 'Las Haciendas', 'Los Prados', 'Hacienda las Palmas', 'Arboledas', 'Real Altamira', 'El Edén', 'Arecas', 'Puerto Industrial de Altamira']
# VILLAS LAS FLORES
# ALTAMIRA
# 56373
# ['El Encino', 'El Arenal', 'San Antonio', 'San Juan', 'Los Ángeles', 'Tejocote', 'Bonito San Vicente', 'Bonito El Manzano', 'Hacienda Vista Real']
# BONITO EL MANZANO
# CHICOLOAPAN
# 88610
# ['Rancho Grande', 'La Rosita', 'Jesús Vega Sánchez', 'Caracoles']
# LOS CARACOLES
# REYNOSA
# 88799
# ['Misión Santa Fe', 'Pedro J Méndez', 'Los Arcos', 'Balcones de Alcalá', 'Paseo de las Flores', 'Los Almendros', 'Parque Industrial STIVA Alcalá', 'Los Olivos Oriente', 'Los Almendros II', 'Los Encinos', 'Pirámides', 'Valle Soleado', 'Los Olivos', 'Terranova']
# LOS ALMENDROS
# REYNOSA
# 31137
# ['20 Aniversario', 'Los Arcos', 'Vida Digna', 'Constituyentes', 'Francisco Ruiz Massieu', 'Inti Peredo', 'José Vasconcelos', 'Juan Guereca', 'Ampliación Juan Guereca', 'Laderas', 'Magisterial Solidaridad', 'Miguel Sigala', 'Niños Héroes', 'Pedro Domínguez', 'Los Portales', 'Pozos del Valle', 'Rodolfo Fierro', 'María Elena Hernandez', 'Santa Cecilia', 'Tarahumara', 'Vicente Guereca', 'Luis Donaldo Colosio Murrieta', 'Luis Fuentes Mares', 'Atanacio Ortega', 'Antorcha Popular', 'El Porvenir', 'Villa del Real', 'Progreso Nacional', 'Villa del Norte', 'Dumas', 'Sahuaros', 'Real de Santa Eulalia', 'Colonial de Minas', 'Solidaridad Popular', 'Puerta Real']
# LOS PORTALES
# CHIHUAHUA, CHIH
# 88500
# ['Reynosa Centro']
# PUERTA SUR
# REYNOSA, TAMPS
# 32310
# ['Los Naranjos', 'Monumental', 'Instituto de Ciencias Biomédicas (ICB)', 'Dalia Residencial', 'Córdova Américas', 'FOVISSSTE Chamizal', 'Los Álamos', 'Los Olmos', 'Mayorga', 'Monumental', 'Patricia', 'Progresista', 'Ricardo Montoya', 'Residencial la Villa']
# LOS OLMOS NORTE
# CD JUAREZ
# 88130
# ['Buenos Aires']
# PASEO DE LOS OLIVOS
# CD VICTORIA
# 32380
# ['La Rosaleda', 'San José', 'San Pedro', 'Tres Fresnos', 'Rincón de San José', 'Ramos Avilés', 'Paso del Norte', 'Fuentes de los Nogales', 'Los Colorines', 'Melchor Ocampo', 'Reforma', 'Reginaldo Kluche', 'Agustín Melgar', 'Villas San José', 'Montemayor', 'Arecco', 'Ingeniero Portillo', 'Tres Hermanos Arecco', 'Parque Industrial Eje Vial Juan Gabriel']
# REFORMA
# CD JUAREZ
# 79200
# ['Tamuín Centro']
# FRACC. "QUINTA DULCE"
# TAMUIN
# 91700
# ['Veracruz Centro', 'Madero', 'Pino Suarez']
# CENTRO
# VERACRUZ
# 22813
# ['Colinas del Paraíso', 'Las Torres', 'Colinas de La Presa', 'Cumbres de La Presa', 'Colinas del Magisterio', 'Nuevo Milenio', 'Mar de Cortez', 'Misiones de La Presa 1', 'Misiones de La Presa 2', 'Misiones de Altamar', 'Mar de Ensenada', 'Lomas de la Presa', 'Residencial del Sol', 'Alta Mar', 'INFONAVIT Nuevo Milenio', 'Misiones del Paraíso']
# LOMAS DE LA PRESA
# ENSENADA
# 72228
# ['Indios Verdes', 'Parque Industrial Resurrección', 'Santa Rosa', 'Tres de Mayo', 'INFONAVIT San Aparicio', 'San Aparicio las Fuentes', 'Torre Fuerte']
# 3 DE MAYO
# PUEBLA
# 91569
# ['Las Bugambilias', 'Jardines de Pastoreza', '2 de Enero', 'Las Primaveras', 'El Cedro', 'Casa Pinta']
# LAS BUGAMBILIAS
# COATEPEC, VER
# 91000
# ['Xalapa Enríquez Centro']
# CENTRO
# XALAPA, VER
# 34214
# ['Armando del Castillo Franco', 'Francisco Sarabia']
# ARMANDO DEL CASTILLO FRANCO
# DURANGO, DGO
# 77500
# ['Villas Tropicales', 'Cancún Centro', 'Supermanzana 20 Centro', 'Supermanzana 1 Centro', 'Supermanzana 2 Centro', 'Supermanzana 2a Centro', 'Supermanzana 3 Centro', 'Supermanzana 4 Centro', 'Supermanzana 5 Centro', 'Supermanzana 22 Centro', 'Supermanzana 23 Centro', 'Zona Hotelera', 'Residencial La Cascada', 'Supermanzana 52', 'Supermanzana 4 A', 'Juárez']
# CONJ. MONTECARLO
# CANCUN
# 95280
# ['Lerdo de Tejada Centro']
# CENTRO
# LERDO DE TEJADA, VER
# 77533
# ['Residencial Caracol', 'Supermanzana 313', 'Privada Altus', 'Supermanzana 54', 'Residencial Isla Azul', 'Supermanzana 49', 'Supermanzana 50', 'Supermanzana 51', 'Supermanzana 502', 'Supermanzana 503', 'Supermanzana 504', 'Supermanzana 505', 'Supermanzana 506', 'Supermanzana 507', 'Supermanzana 508', 'Supermanzana 509', 'Supermanzana 501', 'Supermanzana 500', 'Costa del Mar', 'Álamos I', 'Chamuyil', 'Malibú', 'Porto Alegre', 'Quetzales (Supermanzana 523)', 'Supermanzana 57', 'Framboyanes', 'Residencial Sol del Mayab', 'Paraíso Villas', 'Supermanzana 55', 'San José Bonampack', 'Las Torres', 'Supermanzana 312']
# RIVIERA.
# CANCUN
# 60870
# ['Bellavista', 'El Chumbano', 'El Mangal', 'La Gloria', 'San Miguel', 'Toril Viejo', 'Aquila', 'La Ine']
# 1
# COLIMA, COL
# 44700
# ['Guadalajara Oriente', 'Oblatos', 'Santa Cecilia 1a. sección', 'Santa Rosa', 'Unidad Río Verde', 'Río Verde Oblatos', 'Santa Cecilia 2a. Sección', 'Santa Cecilia 3a. Sección']
# OBLATOS
# GUADALAJARA, JAL
# 34000
# ['Victoria de Durango Centro', 'Dionisio Gallardo', 'Luis Gómez Zepeda', 'Rinconada Mascareñas', 'Herrera Leyva', 'Privada del Sahuaro']
# CENTRO
# DURANGO, DGO
# 85400
# ['Heroica Guaymas Centro']
# CENTRO
# GUAYMAS
# 35000
# ['Gómez Palacio Centro']
# LOS ALAMOS
# GOMEZ PALACIO, DGO
# 50000
# ['Toluca de Lerdo Centro']
# Values not found
# 92800
# ['Túxpam de Rodríguez Cano Centro']
# VISTA HERMOSA
# TUXPAN, VER
# 88780
# ['Brisas de Almaguer', 'Privada de las Palmas', 'Rinconada de la Loma', 'Almaguer', 'Francisco Villa', 'Lampasitos', 'Reynosa', 'Loma Blanca', 'El Mezquite', 'Parque Industrial Center', 'Villas del Parque', 'Nuevo Reynosa', 'Villas del Palmar', 'Los Robles']
# LOMA BLANCA
# REYNOSA, TAMPS
# 96350
# ['Cosoleacaque Centro', 'Primero', 'Rincón de la Colmena']
# FRACC LOS LIMONES
# COSOLEACAQUE, VER
# 44960
# ['18 de Marzo', 'Lomas de Polanco', 'López Portillo', 'Polanco Oriente']
# Ejido Santa Ma. Tequepexpan
# GUADALAJARA, JAL
# 54960
# ['San Juan Xocotla', 'Tultepec Centro', 'San Rafael Ixtlahuaca', 'El Carmen']
# HACIENDA REAL DE TULTEPEC
# TULTEPEC, CUAUTITLAN, EDM
# 90450
# ['La Noria', 'San Dionisio Yauhquemehcan', 'San Francisco Tlacuilohcan', 'San Lorenzo Tlacualoyan', 'Santa Úrsula Zimatepec', 'La Noria II', 'Viky', 'La Corona', 'Cruztitla', 'Malintzi I', 'El Padrino II', 'El Padrino I', 'La Cima de Piedra II', 'Los Sauces IV', 'La Esperanza', 'Los Sauces I', 'La Palma', 'La Huerta', 'La Aurora', 'Xalcuentla', 'La Huerta I', 'Jardines de Santa Úrsula', 'Los Sauces II', 'Los Sauces III', 'El Padrino III', 'Los Sauces V', 'Villa Hermosa', 'El Pedregal', 'Ahuaxtla', 'La Cima de Piedra I', 'Las Rosas 2000']
# FRACC MU�OZ
# MUNICIPIO DE YAUHQUEMECAN, DISTRITO DE CUAUHTEMOC TLAX
# 21240
# ['Prohogar', 'Santa Maria', 'Vista Hermosa', 'Cataviña']
# PRO HOGAR
# MEXICALI
# 90300
# ['Centro']
# FRACC. LA NORIA
# APIZACO
# 89506
# ['Miramar', 'Privada Oasis', 'Joyas Diamante', 'Lienzo Charro', 'Miramapolis', 'SAHOP', 'Puerto Alegre', 'Integración Familiar', 'Rincón Colonial', 'Las Dunas', 'Joyas de Miramapolis', 'Villas del Mar', 'Insurgentes']
# BAHIAS DE MIRAMAPOLIS
# CD MADERO, TAMP
# 85400
# ['Heroica Guaymas Centro']
# VILLA DE MIRAMAR
# GUAYMAS
# 77710
# ['Playa del Carmen Centro', 'Calica', 'Playa del Carmen']
# CERRADA PLAYA CARACOL II
# PLAYA DEL CARMEN
# 54900
# ['Belém', 'La Concepción', 'Los Reyes', 'Nativitas', 'San Bartolo', 'San Juan', 'Santiaguito', 'Tultitlán de Mariano Escobedo Centro', 'Residencial los Reyes', 'Rincón Colonial']
# LOS PORTALES
# TULTITLAN, EDM
# 56535
# ['El Jaral (El Capulín)', 'Jardín Industrial Ixtapaluca', 'Geovillas de Santa Bárbara', 'El Capulín', 'Hacienda las Palmas I y II', 'Las Palmas Tercera Etapa']
# LAS PALMAS HACIENDA
# IXTAPALUCA, EDM
# 61600
# ['Pátzcuaro Centro', 'España', 'Pátzcuaro']
# MARCOS M JIMENEZ
# PATZCUARO
# 57100
# ['Valle de Aragón']
# VALLE DE ARAGON
# NEZAHUALCOYOTL
# 02000
# ['Centro de Azcapotzalco']
# CUAUHTEMOC
# AZCAPOTZALCO
# 02000
# ['Centro de Azcapotzalco']
# SAN MATEO
# AZCAPOTZALCO
# 22245
# ['Paseo Santa María', 'La Morita 2da. Sección', 'El Florido 4ta. Sección', 'La Morita', 'Las Abejas', 'Hacienda las Fuentes', 'Cañadas del Florido', 'Las Colonias', 'Paseos del Florido', 'Hacienda Santa María', 'Fideicomiso el Florido', 'Cañadas del Florido 2da. Sección']
# CA�ADAS DEL FLORIDO
# TIJUANA
# 54870
# ['El Paraíso', 'Lázaro Cárdenas', 'San Blas I', 'San Blas II', 'San José Milla', 'Santa Ana Tlaltepan', 'Misiones I', 'Rancho San Blas']
# EX RANCHO DE SAN BLAS
# CUAUTITLAN IZCALLI
# 50000
# ['Toluca de Lerdo Centro']
# Values not found
# 85400
# ['Heroica Guaymas Centro']
# PETROLERA
# GUAYMAS
# 54000
# ['Tlalnepantla  Centro', 'Alta Vista']
# VALLE DE TENAYO
# TLALNEPANTLA, EDM
# 89000
# ['Tampico Centro']
# ZONA CENTRO
# TAMPICO, TAMP
# 52787
# ['Bosques de las Palmas', 'Paseo de las Palmas', 'Villa de las Lomas', 'Valle de las Palmas', 'Interlomas', 'Palmas Altas Residencial']
# LA HERRADURA
# TLALNEPANTLA, EDM
# 25700
# ['Monclova Centro']
# Values not found
# 31500
# ['Ciudad Cuauhtémoc Centro']
# Values not found
# 55120
# ['Ciudad Azteca Sección Poniente', 'Ciudad Azteca Sección Oriente']
# Values not found
# 25296
# ['Bonanza', 'Bugambilias', 'La Florida', 'Nueva Aurora', 'Villas de la Aurora', 'Hacienda la Aurora Residencial', 'Cruz del Aire', 'Rincón de la Florida', 'La Rosa', 'Los Geranios']
# ANTIMONIO L16 M 9, 477, , CRUZ DEL AIRE, SALTILLO, COAHUILA
# SALTILLO
# 58338
# ['Las Flores']
# MAGNOLIA 468, LAS FLORES, MORELIA MICHOACAN
# MORELIA
# 67174
# ['Rincón del Contry', 'Puesta del Sol', 'Atoyac de Álvarez', 'Contry Sol', 'Las Águilas', 'Riberas del Contry', 'Valle del Contry', '25 de Noviembre', 'Bosques de la Pastora', 'Villa Pastora', 'Bosques del Contry']
# VALLE DEL RHIN, 323, L29 M60, VALLE DEL CONTRY, GUADALUPE, NUEVO LEON
# GUADALUPE
# 66612
# ['Misión del Parque', 'Muran Residencial', 'Lombardía Residencial', 'Aria Residencial', 'Privada Lumena', 'Privada Sundara', 'Sabanah Residencial', 'Privada Marietta', 'Los Ébanos', 'Los Encinos', 'Valle de San Andrés', 'Prados Del Virrey', 'Insurgentes', 'Valle de Apodaca', 'Metroplex', 'Valle de las Bugambilias', 'Nuevo las Puentes Tercer Sector', 'Andalucía', 'Nuevo las Puentes Primer Sector', 'Nuevo las Puentes Segundo Sector', 'Manantial', 'Prados de los Pinos', 'Valle de las Palmas Segundo Sector', 'Cortijo las Palmas', 'Bosque Real', 'Valle de las Palmas Tercer Sector', 'Valle de las Palmas Cuarto Sector', 'Villa las Puentes', 'Jardines de San Andrés', 'Hacienda Santa Isabel', 'Misión de Fundadores', 'Jardines de las Palmas', 'Hacienda las Yucas', 'El Molino', 'Villas Premier', 'Misión de San José Residencias', 'Real de San Andres', 'Valle de las Palmas Quinto Sector', 'Ébanos Norte', 'Las Estancias', 'Las Huertas', 'Misión de San José Privadas', 'Santa Alicia', 'Valle de las Palmas Sexto Sector', 'Privadas del Rey']
# N 7 LOTE 31 MANZANA 36, 461, , METROPLEX 1, APODACA, NUEVO LEON
# APODACA
# 66056
# ['Lomas de Escobedo', 'Los Girasoles I', 'Praderas de Girasoles', 'Topo Grande', 'Valle de Girasoles', 'Villas de Escobedo', 'INFONAVIT Monterreal', 'Hilario Ayala Predio', 'Balcones de Anáhuac', 'Riberas de Girasoles', 'Bosques de Quebéc']
# CLAVELES LOTE 28 M212, 607, , LOS GIRASOLES, GRAL. ESCOBEDO, NUEVO LEON
# GRAL. ESCOBEDO
# 66475
# ['Casa Blanca', 'Jardines de Casa Blanca', 'INFONAVIT los Ángeles Sector Siete', 'INFONAVIT los Ángeles Sector Ocho', 'San Ángel Casa Blanca', 'Villas de Casa Blanca']
# AV. CASA BLANCA L012 M 261, 622, , VILLAS DE CASA BLANCA, SAN NICOLAS DE LOS GARZA, NUEVO LEON
# SAN NICOLAS DE LOS GARZA
# 66072
# ['Brianzzas Residencial', 'La Providencia', 'Mirador del Valle', 'Mirasur II', 'Parque Industrial Libramiento', 'Los Agaves', 'Bosques de Escobedo', 'Hacienda del Topo', 'Progreso Paso Cucharas', 'Quinto Centenario', 'Hacienda los Ayala', 'Cortijo los Ayala', 'Paseo Real', 'Renacimiento', 'Hacienda el Vergel']
# HACIENDA DE PALO SECO L15 M 162, 330, , HACIENDA DEL TOPO, GRAL. ESCOBEDO, NUEVO LEON
# GRAL. ESCOBEDO

# %%
def clasificar_etapa(df):
    adjudicada = [
        "Auto Aprobatorio",
        "Validacion De Documentacion",
        "Escritura Vehiculo No Inscrita",
        "Adjudicado Originador",
        "Escritura Originador No Inscrita",
        "Termino De Proceso",
        "Dacion En Pago",
        "Adjudicación A Favor Del Originador",
        "Escritura A Favor Del Vehículo Inscrita",
        "Adjudicación A Favor Del Vehículo",
        "Escritura A Favor Del Vehículo No Inscrita",
        "Escritura A Favor Del Originador No Inscrita",
        "Adjudicación",
        "Escritura A Favor Del Originador Inscrita",
        "Adjudicado Vehiculo",
        "Adjudicado Originador",
        "Escritura Vehiculo Inscrita",
        "Escritura Originador Inscrita",
        "Toma De Posesion"
    ]

    sentencia = [
        "Valorizacion",
        "Fecha De Remate",
        "Audiencia De Remate",
        "Sentencia Firme",
        "Sentencia Primera Instancia",
        "Publicacion De Edictos",
        "Sentencia"
    ]

    juicio = [
        "Emplazamiento Por Edictos",
        "Notificacion De Cesion",
        "Diligenciacion De Exhorto",
        "Presentacion De Demanda",
        "Auto Admisorio",
        "Desahogo De Pruebas",
        "Contestacion",
        "Oficios Dependencias",
        "Apelacion Sentencia Primera Instancia",
        "Juicio De Amparo Sentencia",
        "Apelacion Auto Admisorio",
        "Citado Para Sentencia"
    ]

    cobranza = [
        "Busqueda De Documentos",
        "Certificacion Contable",
        "Sin Dato"
    ]
    

    etapa = str(df["ETAPA"]).strip()  # Convert to string and strip whitespace
    
    # Match against each list using fuzzy matching
    match_adjudicada, score_adjudicada = process.extractOne(etapa, adjudicada)
    match_sentencia, score_sentencia = process.extractOne(etapa, sentencia)
    match_juicio, score_juicio = process.extractOne(etapa, juicio)
    match_cobranza, score_cobranza = process.extractOne(etapa, cobranza)

    # Determine the classification based on the highest score
    if score_adjudicada >= 80:
        df["ETAPA_ALTALTIUM"] = "ADJUDICADA"
    elif score_sentencia >= 80:
        df["ETAPA_ALTALTIUM"] = "SENTENCIA"
    elif score_juicio >= 80:
        df["ETAPA_ALTALTIUM"] = "JUICIO"
    elif score_cobranza >= 80:
        df["ETAPA_ALTALTIUM"] = "COBRANZA"
    else:
        df["ETAPA_ALTALTIUM"] = "DESCONOCIDA"

    return df

df = df.apply(clasificar_etapa, axis = 1)

# %%
# Definir las columnas del inventario
columns = [
    "LISTA", "FOTOS", "FICHAS", "FOLIO", "TIPO", "CALLE_Y_NUMERO", "COLONIA",
    "ALCALDIA/MUNICIPIO", "ESTADO", "CP", "TERRENO", "CONSTRUCCIÓN", 
    "RECAMARAS", "SANITARIOS", "ESTACIONAMIENTOS", "1ER_PAGO", 
    "2DO_PAGO", "TOTAL", "VALOR_APROX", "ALREDEDORES", "GOOGLE_MAPS", 
    "CALIF", "CALIF_EV", "LATITUD", "LONGITUD", "ETAPA", "ESTADO_DE_VIVIENDA",
]

# %%
# Comprobar las columnas
columns_to_check = ['RECAMARAS', 'SANITARIOS', 'ESTACIONAMIENTOS']

for column in columns_to_check:
    if column not in df.columns:
        df[column] = pd.NA  # O puedes usar `None` si prefieres

# %%
inventory_df = pd.DataFrame(columns=columns, index=df.index)

inventory_df["LISTA"] = df["LISTA"]
inventory_df["ETAPA"] = df["ETAPA_ALTALTIUM"]

inventory_df["FOLIO"] = df["FOLIO"].apply(lambda x: abs(x)) #Usé abs porque en la limpieza de numero se le agrega -
# inventory_df["TIPO"] = df["Tipo Inmueble"].str.strip().str.title() No hay tipo en global
inventory_df["ESTADO"] = df["ESTADO"].str.strip().str.title()
inventory_df["ALCALDIA/MUNICIPIO"] = df["MUNICIPIO"].str.strip().str.title()
inventory_df["COLONIA"] = df["COLONIA"].str.strip().str.title()
inventory_df["CALLE_Y_NUMERO"] = df["CALLE_Y_NUMERO"].str.strip().str.title()
inventory_df["CP"] = df["CP"]
inventory_df["TERRENO"] = df["TERRENO"]
inventory_df["CONSTRUCCIÓN"] = df["CONSTRUCCION"]
inventory_df["2DO_PAGO"] = df["2DO_PAGO"]

# %%
def calcular_primer_pago(salida_al_mercado):
    if salida_al_mercado <= 499000:
        return 226000
    elif 500000 <= salida_al_mercado <= 1499000:
        return 395000
    elif salida_al_mercado >= 1500000:
        return 474000
    else:
        return None

inventory_df["1ER_PAGO"] = df["2DO_PAGO"].apply(calcular_primer_pago)

inventory_df["1ER_PAGO"].astype(int)
# Out:
# 0       226000
# 1       226000
# 2       226000
# 3       226000
# 4       226000
#          ...
# 1593    395000
# 1594    226000
# 1595    226000
# 1596    395000
# 1597    226000
# Name: 1ER_PAGO, Length: 1598, dtype: int32

# %%
inventory_df["TOTAL"] = inventory_df["1ER_PAGO"] + inventory_df["2DO_PAGO"]

inventory_df["2DO_PAGO"] = inventory_df["2DO_PAGO"].apply(lambda x: f'{x:.0f}' if x.is_integer() else f'{x:.2f}')
inventory_df["TOTAL"] = inventory_df["TOTAL"].apply(lambda x: f'{x:.0f}' if x.is_integer() else f'{x:.2f}')

# %%
def calculate_rooms(construccion, recamaras):
    # Intenta convertir construccion a número
    try:
        construccion = float(construccion)
    except ValueError:
        construccion = pd.NA  # Si la conversión falla, asignar NA
    
    # Si recamaras tiene un valor válido, devuelve ese valor
    if pd.notna(recamaras) and recamaras != 0:
        return recamaras
    elif pd.isna(recamaras) or recamaras == 0:
        if pd.notna(construccion):  # Solo hacer comparaciones si construccion es numérico
            if construccion <= 39:
                return 1
            elif 40 <= construccion <= 80:
                return 2
            elif 81 <= construccion <= 249:
                return 3
            elif 250 <= construccion <= 349:
                return 4
            elif construccion >= 350:
                return 5
    return pd.NA  # Optional: return NA if construccion is not valid


inventory_df["RECAMARAS"] = inventory_df.apply(lambda row: calculate_rooms(row["CONSTRUCCIÓN"], row["RECAMARAS"]), axis=1)

# %%
def calculate_bathrooms(construccion, sanitarios):
    # Intenta convertir construccion a número
    try:
        construccion = float(construccion)
    except ValueError:
        construccion = pd.NA  # Si la conversión falla, asignar NA
    
    # Si sanitarios tiene un valor válido, devuelve ese valor
    if pd.notna(sanitarios) and sanitarios != 0:
        return sanitarios
    elif pd.isna(sanitarios) or sanitarios == 0:
        if pd.notna(construccion):  # Solo hacer comparaciones si construccion es numérico
            if construccion <= 69:
                return 1
            elif 70 <= construccion <= 99:
                return 1.5
            elif 100 <= construccion <= 159:
                return 2
            elif 160 <= construccion <= 209:
                return 2.5
            elif 210 <= construccion <= 250:
                return 3
            elif 251 <= construccion < 300:
                return 3.5
            elif construccion >= 300:
                return 4
    return pd.NA  # Optional: return NA if construccion is not valid

# Supongamos que `inventory_df` es tu DataFrame
inventory_df["SANITARIOS"] = inventory_df.apply(lambda row: calculate_bathrooms(row["CONSTRUCCIÓN"], row["SANITARIOS"]), axis=1)

# %%
def calculate_parking(construccion, estacionamientos):
    # Intenta convertir construccion a número
    try:
        construccion = float(construccion)
    except ValueError:
        construccion = pd.NA  # Si la conversión falla, asignar NA
    
    # Si estacionamientos tiene un valor válido, devuelve ese valor
    if pd.notna(estacionamientos) and estacionamientos != 0:
        return estacionamientos
    elif pd.isna(estacionamientos) or estacionamientos == 0:
        if pd.notna(construccion):  # Solo hacer comparaciones si construccion es numérico
            if construccion <= 99:
                return 1
            elif 100 <= construccion <= 249:
                return 2
            elif 250 <= construccion <= 359:
                return 3
            elif construccion >= 360:
                return 4
    return pd.NA  # Optional: return NA if construccion is not valid

# Supongamos que `inventory_df` es tu DataFrame
inventory_df["ESTACIONAMIENTOS"] = inventory_df.apply(lambda row: calculate_parking(row["CONSTRUCCIÓN"], row["ESTACIONAMIENTOS"]), axis=1)

# %%
#On ths versión, we need to add the state, colony, and cp to the google maps search

def generar_enlace_busqueda_google_maps(row):
    direccion = f"{row['CALLE_Y_NUMERO']}, {row['COLONIA']}, {row['ALCALDIA/MUNICIPIO']}, {row['ESTADO']}, {row['CP']}"
    direccion = re.sub(r'[\""]', '', direccion)
    direccion = re.sub(r'\s+', ' ', direccion).strip()  # Normalizar espacios múltiples
    return f"https://www.google.com/maps/search/?api=1&query={direccion.replace(' ', '+')}"

# Aplicar la función a cada fila del DataFrame
inventory_df["GOOGLE_MAPS"] = inventory_df.apply(generar_enlace_busqueda_google_maps, axis=1)

# %%
inventory_json = inventory_df.to_json(orient="records", force_ascii=False)

print(json.dumps(json.loads(inventory_json), indent=4, ensure_ascii=False))
# Out:
# [
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Código Postal 75859 10 14 Colonia Ex Ejido San Diego Chalma Tehuacan Código Postal 75859 Puebla",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Tehuacan",
#         "ESTADO": "Puebla",
#         "CP": 75859,
#         "TERRENO": "120",
#         "CONSTRUCCIÓN": " -   ",
#         "RECAMARAS": null,
#         "SANITARIOS": null,
#         "ESTACIONAMIENTOS": null,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "23460",
#         "TOTAL": "249460",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Código+Postal+75859+10+14+Colonia+Ex+Ejido+San+Diego+Chalma+Tehuacan+Código+Postal+75859+Puebla,+nan,+Tehuacan,+Puebla,+75859",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Sarabia Esq. Calle 12 Código Postal 31890 8 172 Poblado Buenaventura Buenaventura Código Postal 31890 Chihuahua",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Buenaventura",
#         "ESTADO": "Chihuahua",
#         "CP": 31890,
#         "TERRENO": "818.55",
#         "CONSTRUCCIÓN": " -   ",
#         "RECAMARAS": null,
#         "SANITARIOS": null,
#         "ESTACIONAMIENTOS": null,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "23460",
#         "TOTAL": "249460",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Sarabia+Esq.+Calle+12+Código+Postal+31890+8+172+Poblado+Buenaventura+Buenaventura+Código+Postal+31890+Chihuahua,+nan,+Buenaventura,+Chihuahua,+31890",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Predio Rustico Denominado Potrero De Sauz Colonia Habitacional Puruagua Jerecuaro Jerecuaro Guanajuato",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Jerecuaro",
#         "ESTADO": "Guanajuato",
#         "CP": 38580,
#         "TERRENO": "474",
#         "CONSTRUCCIÓN": " -   ",
#         "RECAMARAS": null,
#         "SANITARIOS": null,
#         "ESTACIONAMIENTOS": null,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "31620",
#         "TOTAL": "257620",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Predio+Rustico+Denominado+Potrero+De+Sauz+Colonia+Habitacional+Puruagua+Jerecuaro+Jerecuaro+Guanajuato,+nan,+Jerecuaro,+Guanajuato,+38580",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Porcion B, Rancheta 64 Seccion 3 Predio Denominado El Alamito Código Postal 84230 Agua Prieta Agua Prieta Código Postal 84230 Sonora",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Agua Prieta",
#         "ESTADO": "Sonora",
#         "CP": 84230,
#         "TERRENO": "10000",
#         "CONSTRUCCIÓN": " -   ",
#         "RECAMARAS": null,
#         "SANITARIOS": null,
#         "ESTACIONAMIENTOS": null,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "34680",
#         "TOTAL": "260680",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Porcion+B,+Rancheta+64+Seccion+3+Predio+Denominado+El+Alamito+Código+Postal+84230+Agua+Prieta+Agua+Prieta+Código+Postal+84230+Sonora,+nan,+Agua+Prieta,+Sonora,+84230",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Television Zona 3 Código Postal39713 22 141 Colonia La Venta Y Barrio Nuevo Acapulco De Juarez Acapulco De Juarez Código Postal 39713 Guerrero",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Acapulco",
#         "ESTADO": "Guerrero",
#         "CP": 39713,
#         "TERRENO": "86",
#         "CONSTRUCCIÓN": " -   ",
#         "RECAMARAS": null,
#         "SANITARIOS": null,
#         "ESTACIONAMIENTOS": null,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "33660",
#         "TOTAL": "259660",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Television+Zona+3+Código+Postal39713+22+141+Colonia+La+Venta+Y+Barrio+Nuevo+Acapulco+De+Juarez+Acapulco+De+Juarez+Código+Postal+39713+Guerrero,+nan,+Acapulco,+Guerrero,+39713",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Local Comercial Del Mercado Municipal \"Julian Yunez Arellano\" 17 Tepeaca Tepeaca Puebla",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Tepeaca",
#         "ESTADO": "Puebla",
#         "CP": 75200,
#         "TERRENO": "20",
#         "CONSTRUCCIÓN": "20",
#         "RECAMARAS": 1,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "42840",
#         "TOTAL": "268840",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Local+Comercial+Del+Mercado+Municipal+Julian+Yunez+Arellano+17+Tepeaca+Tepeaca+Puebla,+nan,+Tepeaca,+Puebla,+75200",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "A 2.5 Kms. De La Congregacion De Gutierrez Poblado Gutierrez Zamora Chiconquiaco Chiconquiaco Veracruz",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Chiconquiaco",
#         "ESTADO": "Veracruz",
#         "CP": 93892,
#         "TERRENO": "10045.9",
#         "CONSTRUCCIÓN": " -   ",
#         "RECAMARAS": null,
#         "SANITARIOS": null,
#         "ESTACIONAMIENTOS": null,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "45900",
#         "TOTAL": "271900",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=A+2.5+Kms.+De+La+Congregacion+De+Gutierrez+Poblado+Gutierrez+Zamora+Chiconquiaco+Chiconquiaco+Veracruz,+nan,+Chiconquiaco,+Veracruz,+93892",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Andador Mar De Cortes Código Postal 24157 111 2 Xii Fraccionamiento Puesta Del Sol Carmen Carmen Código Postal 24157 Campeche",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Ciudad Del Carmen",
#         "ESTADO": "Campeche",
#         "CP": 24157,
#         "TERRENO": "87",
#         "CONSTRUCCIÓN": " -   ",
#         "RECAMARAS": null,
#         "SANITARIOS": null,
#         "ESTACIONAMIENTOS": null,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "83640",
#         "TOTAL": "309640",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Andador+Mar+De+Cortes+Código+Postal+24157+111+2+Xii+Fraccionamiento+Puesta+Del+Sol+Carmen+Carmen+Código+Postal+24157+Campeche,+nan,+Ciudad+Del+Carmen,+Campeche,+24157",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Predio Ubicado En Chachapa Amozoc Hoy Calle Ninos Heroes Código Postal 72990 403 Colonia Chachapa Amozoc Amozoc Código Postal 72990 Puebla",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Amozoc",
#         "ESTADO": "Puebla",
#         "CP": 72990,
#         "TERRENO": "337.09",
#         "CONSTRUCCIÓN": "36.4",
#         "RECAMARAS": 1,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "173400",
#         "TOTAL": "399400",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Predio+Ubicado+En+Chachapa+Amozoc+Hoy+Calle+Ninos+Heroes+Código+Postal+72990+403+Colonia+Chachapa+Amozoc+Amozoc+Código+Postal+72990+Puebla,+nan,+Amozoc,+Puebla,+72990",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "84 Poniente Conjunto Habitacional Los Corales Código Postal 77533 278 Edificio 1 Departamento 104 6 17 Fraccionamiento Las Torres Benito Juarez Benito Juarez Código Postal 77533 Quintana Roo",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Benito Juarez",
#         "ESTADO": "Quintana Roo",
#         "CP": 77533,
#         "TERRENO": "49.88",
#         "CONSTRUCCIÓN": "52.72",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "99960",
#         "TOTAL": "325960",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=84+Poniente+Conjunto+Habitacional+Los+Corales+Código+Postal+77533+278+Edificio+1+Departamento+104+6+17+Fraccionamiento+Las+Torres+Benito+Juarez+Benito+Juarez+Código+Postal+77533+Quintana+Roo,+nan,+Benito+Juarez,+Quintana+Roo,+77533",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "86 Poniente Conjunto Habitacional Los Corales Código Postal 77533 280 Edificio 01 Departamento 104 Antes 18 1 12 Fraccionamiento Las Torres Benito Juarez Benito Juarez Código Postal 77533 Quintana Roo",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Benito Juarez",
#         "ESTADO": "Quintana Roo",
#         "CP": 77533,
#         "TERRENO": "49.88",
#         "CONSTRUCCIÓN": "52.72",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "99960",
#         "TOTAL": "325960",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=86+Poniente+Conjunto+Habitacional+Los+Corales+Código+Postal+77533+280+Edificio+01+Departamento+104+Antes+18+1+12+Fraccionamiento+Las+Torres+Benito+Juarez+Benito+Juarez+Código+Postal+77533+Quintana+Roo,+nan,+Benito+Juarez,+Quintana+Roo,+77533",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Andador De La Isla Del Carmen Código Postal 24157 101 8 Xvi Fraccionamiento Puesta Del Sol Ciudad Del Carmen Ciudad Del Carmen Código Postal 24157 Campeche",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Ciudad Del Carmen",
#         "ESTADO": "Campeche",
#         "CP": 24157,
#         "TERRENO": "87",
#         "CONSTRUCCIÓN": " -   ",
#         "RECAMARAS": null,
#         "SANITARIOS": null,
#         "ESTACIONAMIENTOS": null,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "94860",
#         "TOTAL": "320860",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Andador+De+La+Isla+Del+Carmen+Código+Postal+24157+101+8+Xvi+Fraccionamiento+Puesta+Del+Sol+Ciudad+Del+Carmen+Ciudad+Del+Carmen+Código+Postal+24157+Campeche,+nan,+Ciudad+Del+Carmen,+Campeche,+24157",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Circuito De Las Islas Código Postal 24157 110 11 Xvi Fraccionamiento Puesta Del Sol Ciudad Del Carmen Ciudad Del Carmen Código Postal 24157 Campeche",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Ciudad Del Carmen",
#         "ESTADO": "Campeche",
#         "CP": 24157,
#         "TERRENO": "87",
#         "CONSTRUCCIÓN": " -   ",
#         "RECAMARAS": null,
#         "SANITARIOS": null,
#         "ESTACIONAMIENTOS": null,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "94860",
#         "TOTAL": "320860",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Circuito+De+Las+Islas+Código+Postal+24157+110+11+Xvi+Fraccionamiento+Puesta+Del+Sol+Ciudad+Del+Carmen+Ciudad+Del+Carmen+Código+Postal+24157+Campeche,+nan,+Ciudad+Del+Carmen,+Campeche,+24157",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Quirindavara Ejido San Sebastian Atlahapa 90807 7 3 6 Conj Malinche Chiautempan Chiautempan Código Postal 90807 Tlaxcala",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Chiautempan",
#         "ESTADO": "Tlaxcala",
#         "CP": 90807,
#         "TERRENO": "96",
#         "CONSTRUCCIÓN": "55",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "102000",
#         "TOTAL": "328000",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Quirindavara+Ejido+San+Sebastian+Atlahapa+90807+7+3+6+Conj+Malinche+Chiautempan+Chiautempan+Código+Postal+90807+Tlaxcala,+nan,+Chiautempan,+Tlaxcala,+90807",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Predio Urbano Identificado Como Del Andador Del Mar Mediterraneo Código Postal 24157 110 8 Iii Fraccionamiento Puesta Del Sol Ciudad Del Carmen Ciudad Del Carmen Código Postal 24157 Campeche",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Ciudad Del Carmen",
#         "ESTADO": "Campeche",
#         "CP": 24157,
#         "TERRENO": "87",
#         "CONSTRUCCIÓN": " -   ",
#         "RECAMARAS": null,
#         "SANITARIOS": null,
#         "ESTACIONAMIENTOS": null,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "113220",
#         "TOTAL": "339220",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Predio+Urbano+Identificado+Como+Del+Andador+Del+Mar+Mediterraneo+Código+Postal+24157+110+8+Iii+Fraccionamiento+Puesta+Del+Sol+Ciudad+Del+Carmen+Ciudad+Del+Carmen+Código+Postal+24157+Campeche,+nan,+Ciudad+Del+Carmen,+Campeche,+24157",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "86 Poniente Conjunto Habitacional Lo Corales Código Postal 77533 280 Edificio 1 Departamento 103 1 12 Fraccionamiento Las Torres Benito Juarez Benito Juarez Código Postal 77533 Quintana Roo",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Benito Juarez",
#         "ESTADO": "Quintana Roo",
#         "CP": 77533,
#         "TERRENO": "49.88",
#         "CONSTRUCCIÓN": "52.72",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "122400",
#         "TOTAL": "348400",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=86+Poniente+Conjunto+Habitacional+Lo+Corales+Código+Postal+77533+280+Edificio+1+Departamento+103+1+12+Fraccionamiento+Las+Torres+Benito+Juarez+Benito+Juarez+Código+Postal+77533+Quintana+Roo,+nan,+Benito+Juarez,+Quintana+Roo,+77533",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Playa Miramar Código Postal 87470 163 30 22 Fraccionamiento Playa Sol Matamoros Matamoros Código Postal 87470 Tamaulipas",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Matamoros",
#         "ESTADO": "Tamaulipas",
#         "CP": 87470,
#         "TERRENO": "144",
#         "CONSTRUCCIÓN": "127",
#         "RECAMARAS": 3,
#         "SANITARIOS": 2,
#         "ESTACIONAMIENTOS": 2,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "270000",
#         "TOTAL": "496000",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Playa+Miramar+Código+Postal+87470+163+30+22+Fraccionamiento+Playa+Sol+Matamoros+Matamoros+Código+Postal+87470+Tamaulipas,+nan,+Matamoros,+Tamaulipas,+87470",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Vicente Guerrero ( Cerro Madrid ) Código Postal 52985 8 643 Colonia Ampliacion Lomas De Guadalupe Atizapan De Zaragoza Atizapan De Zaragoza Código Postal 52985 Estado De Mexico",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Atizapan",
#         "ESTADO": "Estado De Mexico",
#         "CP": 52985,
#         "TERRENO": "200",
#         "CONSTRUCCIÓN": " -   ",
#         "RECAMARAS": null,
#         "SANITARIOS": null,
#         "ESTACIONAMIENTOS": null,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "118320",
#         "TOTAL": "344320",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Vicente+Guerrero+(+Cerro+Madrid+)+Código+Postal+52985+8+643+Colonia+Ampliacion+Lomas+De+Guadalupe+Atizapan+De+Zaragoza+Atizapan+De+Zaragoza+Código+Postal+52985+Estado+De+Mexico,+nan,+Atizapan,+Estado+De+Mexico,+52985",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Avenida Cuzama 1569 B 5 64 Haciendas Real Del Caribe Benito Juarez Benito Juarez Quintana Roo",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Benito Juarez",
#         "ESTADO": "Quintana Roo",
#         "CP": 77539,
#         "TERRENO": "900",
#         "CONSTRUCCIÓN": "67.76",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "128520",
#         "TOTAL": "354520",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Avenida+Cuzama+1569+B+5+64+Haciendas+Real+Del+Caribe+Benito+Juarez+Benito+Juarez+Quintana+Roo,+nan,+Benito+Juarez,+Quintana+Roo,+77539",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Octavio Paz Modulo 2 Código Postal 39172 Casa 20 6 6 Colonia Los Amates Tixtla De Guerrero Tixtla De Guerrero Código Postal 39172 Guerrero",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Tixtla De Guerrero",
#         "ESTADO": "Guerrero",
#         "CP": 39172,
#         "TERRENO": "60",
#         "CONSTRUCCIÓN": "56.28",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "122400",
#         "TOTAL": "348400",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Octavio+Paz+Modulo+2+Código+Postal+39172+Casa+20+6+6+Colonia+Los+Amates+Tixtla+De+Guerrero+Tixtla+De+Guerrero+Código+Postal+39172+Guerrero,+nan,+Tixtla+De+Guerrero,+Guerrero,+39172",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Predio Urbano Baldio Avenida 5 De Mayo Playas De Catazaja Catazaja Catazaja Chiapas",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Catazaja",
#         "ESTADO": "Chiapas",
#         "CP": 29980,
#         "TERRENO": "1377",
#         "CONSTRUCCIÓN": " -   ",
#         "RECAMARAS": null,
#         "SANITARIOS": null,
#         "ESTACIONAMIENTOS": null,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "122400",
#         "TOTAL": "348400",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Predio+Urbano+Baldio+Avenida+5+De+Mayo+Playas+De+Catazaja+Catazaja+Catazaja+Chiapas,+nan,+Catazaja,+Chiapas,+29980",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Carlos Pellicer S/N Modulo I Código Postal 39172 36 5 4 Colonia Loas Amates Tixtla De Guerrero Tixtla De Guerrero Código Postal 39172 Guerrero",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Tixtla De Guerrero",
#         "ESTADO": "Guerrero",
#         "CP": 39172,
#         "TERRENO": "60",
#         "CONSTRUCCIÓN": "56",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "122400",
#         "TOTAL": "348400",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Carlos+Pellicer+S/N+Modulo+I+Código+Postal+39172+36+5+4+Colonia+Loas+Amates+Tixtla+De+Guerrero+Tixtla+De+Guerrero+Código+Postal+39172+Guerrero,+nan,+Tixtla+De+Guerrero,+Guerrero,+39172",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Morelos 24 Departamento A 404 Edificio 8 Fraccionamiento Santa Clara Ecatepec De Morelos Ecatepec De Morelos Estado De Mexico",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Ecatepec De Morelos",
#         "ESTADO": "Estado De Mexico",
#         "CP": 55530,
#         "TERRENO": "54.69",
#         "CONSTRUCCIÓN": "54.69",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "129540",
#         "TOTAL": "355540",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Morelos+24+Departamento+A+404+Edificio+8+Fraccionamiento+Santa+Clara+Ecatepec+De+Morelos+Ecatepec+De+Morelos+Estado+De+Mexico,+nan,+Ecatepec+De+Morelos,+Estado+De+Mexico,+55530",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Morelos 24 Departamento A 403 Edificio 8 Fraccionamiento Santa Clara Ecatepec De Morelos Ecatepec De Morelos Estado De Mexico",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Ecatepec De Morelos",
#         "ESTADO": "Estado De Mexico",
#         "CP": 55530,
#         "TERRENO": "54.69",
#         "CONSTRUCCIÓN": "54.69",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "129540",
#         "TOTAL": "355540",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Morelos+24+Departamento+A+403+Edificio+8+Fraccionamiento+Santa+Clara+Ecatepec+De+Morelos+Ecatepec+De+Morelos+Estado+De+Mexico,+nan,+Ecatepec+De+Morelos,+Estado+De+Mexico,+55530",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Morelos 24 Departamento A 402 Edificio 8 Fraccionamiento Santa Clara Ecatepec De Morelos Ecatepec De Morelos Estado De Mexico",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Ecatepec De Morelos",
#         "ESTADO": "Estado De Mexico",
#         "CP": 55530,
#         "TERRENO": "54.69",
#         "CONSTRUCCIÓN": "54.69",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "129540",
#         "TOTAL": "355540",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Morelos+24+Departamento+A+402+Edificio+8+Fraccionamiento+Santa+Clara+Ecatepec+De+Morelos+Ecatepec+De+Morelos+Estado+De+Mexico,+nan,+Ecatepec+De+Morelos,+Estado+De+Mexico,+55530",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Morelos 24 Departamento A 401 Edificio 8 Fraccionamiento Santa Clara Ecatepec De Morelos Ecatepec De Morelos Estado De Mexico",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Ecatepec De Morelos",
#         "ESTADO": "Estado De Mexico",
#         "CP": 55530,
#         "TERRENO": "54.69",
#         "CONSTRUCCIÓN": "54.69",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "129540",
#         "TOTAL": "355540",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Morelos+24+Departamento+A+401+Edificio+8+Fraccionamiento+Santa+Clara+Ecatepec+De+Morelos+Ecatepec+De+Morelos+Estado+De+Mexico,+nan,+Ecatepec+De+Morelos,+Estado+De+Mexico,+55530",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Morelos 24 Departamento A 304 Edificio 8 Fraccionamiento Santa Clara Ecatepec De Morelos Ecatepec De Morelos Estado De Mexico",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Ecatepec De Morelos",
#         "ESTADO": "Estado De Mexico",
#         "CP": 55530,
#         "TERRENO": "54.69",
#         "CONSTRUCCIÓN": "54.69",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "129540",
#         "TOTAL": "355540",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Morelos+24+Departamento+A+304+Edificio+8+Fraccionamiento+Santa+Clara+Ecatepec+De+Morelos+Ecatepec+De+Morelos+Estado+De+Mexico,+nan,+Ecatepec+De+Morelos,+Estado+De+Mexico,+55530",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Morelos 24 Departamento A 302 Edificio 8 Fraccionamiento Santa Clara Ecatepec De Morelos Ecatepec De Morelos Estado De Mexico",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Ecatepec De Morelos",
#         "ESTADO": "Estado De Mexico",
#         "CP": 55530,
#         "TERRENO": "54.69",
#         "CONSTRUCCIÓN": "54.69",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "129540",
#         "TOTAL": "355540",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Morelos+24+Departamento+A+302+Edificio+8+Fraccionamiento+Santa+Clara+Ecatepec+De+Morelos+Ecatepec+De+Morelos+Estado+De+Mexico,+nan,+Ecatepec+De+Morelos,+Estado+De+Mexico,+55530",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Morelos 24 Departamento A 301 Edificio 8 Fraccionamiento Santa Clara Ecatepec De Morelos Ecatepec De Morelos Estado De Mexico",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Ecatepec De Morelos",
#         "ESTADO": "Estado De Mexico",
#         "CP": 55530,
#         "TERRENO": "54.69",
#         "CONSTRUCCIÓN": "54.69",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "129540",
#         "TOTAL": "355540",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Morelos+24+Departamento+A+301+Edificio+8+Fraccionamiento+Santa+Clara+Ecatepec+De+Morelos+Ecatepec+De+Morelos+Estado+De+Mexico,+nan,+Ecatepec+De+Morelos,+Estado+De+Mexico,+55530",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Morelos 24 Departamento A 3 Edificio 8 Fraccionamiento Santa Clara Ecatepec De Morelos Ecatepec De Morelos Estado De Mexico",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Ecatepec De Morelos",
#         "ESTADO": "Estado De Mexico",
#         "CP": 55530,
#         "TERRENO": "54.69",
#         "CONSTRUCCIÓN": "54.69",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "129540",
#         "TOTAL": "355540",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Morelos+24+Departamento+A+3+Edificio+8+Fraccionamiento+Santa+Clara+Ecatepec+De+Morelos+Ecatepec+De+Morelos+Estado+De+Mexico,+nan,+Ecatepec+De+Morelos,+Estado+De+Mexico,+55530",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Morelos 24 Departamento A 204 Edificio 8 Fraccionamiento Santa Clara Ecatepec De Morelos Ecatepec De Morelos Estado De Mexico",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Ecatepec De Morelos",
#         "ESTADO": "Estado De Mexico",
#         "CP": 55530,
#         "TERRENO": "54.69",
#         "CONSTRUCCIÓN": "54.69",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "129540",
#         "TOTAL": "355540",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Morelos+24+Departamento+A+204+Edificio+8+Fraccionamiento+Santa+Clara+Ecatepec+De+Morelos+Ecatepec+De+Morelos+Estado+De+Mexico,+nan,+Ecatepec+De+Morelos,+Estado+De+Mexico,+55530",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Morelos 24 Departamento A 203 Edificio 8 Fraccionamiento Santa Clara Ecatepec De Morelos Ecatepec De Morelos Estado De Mexico",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Ecatepec De Morelos",
#         "ESTADO": "Estado De Mexico",
#         "CP": 55530,
#         "TERRENO": "54.69",
#         "CONSTRUCCIÓN": "54.69",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "129540",
#         "TOTAL": "355540",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Morelos+24+Departamento+A+203+Edificio+8+Fraccionamiento+Santa+Clara+Ecatepec+De+Morelos+Ecatepec+De+Morelos+Estado+De+Mexico,+nan,+Ecatepec+De+Morelos,+Estado+De+Mexico,+55530",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Morelos 24 Departamento A 202 Edificio 8 Fraccionamiento Santa Clara Ecatepec De Morelos Ecatepec De Morelos Estado De Mexico",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Ecatepec De Morelos",
#         "ESTADO": "Estado De Mexico",
#         "CP": 55530,
#         "TERRENO": "54.69",
#         "CONSTRUCCIÓN": "54.69",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "129540",
#         "TOTAL": "355540",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Morelos+24+Departamento+A+202+Edificio+8+Fraccionamiento+Santa+Clara+Ecatepec+De+Morelos+Ecatepec+De+Morelos+Estado+De+Mexico,+nan,+Ecatepec+De+Morelos,+Estado+De+Mexico,+55530",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Morelos 24 Departamento A 201 Edificio 8 Fraccionamiento Santa Clara Ecatepec De Morelos Ecatepec De Morelos Estado De Mexico",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Ecatepec De Morelos",
#         "ESTADO": "Estado De Mexico",
#         "CP": 55530,
#         "TERRENO": "54.69",
#         "CONSTRUCCIÓN": "54.69",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "129540",
#         "TOTAL": "355540",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Morelos+24+Departamento+A+201+Edificio+8+Fraccionamiento+Santa+Clara+Ecatepec+De+Morelos+Ecatepec+De+Morelos+Estado+De+Mexico,+nan,+Ecatepec+De+Morelos,+Estado+De+Mexico,+55530",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Morelos 24 Departamento A 103 Edificio 8 Fraccionamiento Santa Clara Ecatepec De Morelos Ecatepec De Morelos Estado De Mexico",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Ecatepec De Morelos",
#         "ESTADO": "Estado De Mexico",
#         "CP": 55530,
#         "TERRENO": "54.69",
#         "CONSTRUCCIÓN": "54.69",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "129540",
#         "TOTAL": "355540",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Morelos+24+Departamento+A+103+Edificio+8+Fraccionamiento+Santa+Clara+Ecatepec+De+Morelos+Ecatepec+De+Morelos+Estado+De+Mexico,+nan,+Ecatepec+De+Morelos,+Estado+De+Mexico,+55530",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Morelos 24 Departamento A 102 Edificio 8 Fraccionamiento Santa Clara Ecatepec De Morelos Ecatepec De Morelos Estado De Mexico",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Ecatepec De Morelos",
#         "ESTADO": "Estado De Mexico",
#         "CP": 55530,
#         "TERRENO": "54.69",
#         "CONSTRUCCIÓN": "54.69",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "129540",
#         "TOTAL": "355540",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Morelos+24+Departamento+A+102+Edificio+8+Fraccionamiento+Santa+Clara+Ecatepec+De+Morelos+Ecatepec+De+Morelos+Estado+De+Mexico,+nan,+Ecatepec+De+Morelos,+Estado+De+Mexico,+55530",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Morelos 24 Departamento A 101 Edificio 8 Fraccionamiento Santa Clara Ecatepec De Morelos Ecatepec De Morelos Estado De Mexico",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Ecatepec De Morelos",
#         "ESTADO": "Estado De Mexico",
#         "CP": 55530,
#         "TERRENO": "54.69",
#         "CONSTRUCCIÓN": "54.69",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "129540",
#         "TOTAL": "355540",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Morelos+24+Departamento+A+101+Edificio+8+Fraccionamiento+Santa+Clara+Ecatepec+De+Morelos+Ecatepec+De+Morelos+Estado+De+Mexico,+nan,+Ecatepec+De+Morelos,+Estado+De+Mexico,+55530",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Morelos 24 Departamento A 1 Edificio 8 Fraccionamiento Santa Clara Ecatepec De Morelos Ecatepec De Morelos Estado De Mexico",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Ecatepec De Morelos",
#         "ESTADO": "Estado De Mexico",
#         "CP": 55530,
#         "TERRENO": "54.69",
#         "CONSTRUCCIÓN": "54.69",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "129540",
#         "TOTAL": "355540",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Morelos+24+Departamento+A+1+Edificio+8+Fraccionamiento+Santa+Clara+Ecatepec+De+Morelos+Ecatepec+De+Morelos+Estado+De+Mexico,+nan,+Ecatepec+De+Morelos,+Estado+De+Mexico,+55530",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Morelos 24 Departamento A 404 Edificio 7 Fraccionamiento Santa Clara Ecatepec De Morelos Ecatepec De Morelos Estado De Mexico",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Ecatepec De Morelos",
#         "ESTADO": "Estado De Mexico",
#         "CP": 55530,
#         "TERRENO": "54.69",
#         "CONSTRUCCIÓN": "54.69",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "129540",
#         "TOTAL": "355540",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Morelos+24+Departamento+A+404+Edificio+7+Fraccionamiento+Santa+Clara+Ecatepec+De+Morelos+Ecatepec+De+Morelos+Estado+De+Mexico,+nan,+Ecatepec+De+Morelos,+Estado+De+Mexico,+55530",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Morelos 24 Departamento A 403 Edificio 7 Fraccionamiento Santa Clara Ecatepec De Morelos Ecatepec De Morelos Estado De Mexico",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Ecatepec De Morelos",
#         "ESTADO": "Estado De Mexico",
#         "CP": 55530,
#         "TERRENO": "54.69",
#         "CONSTRUCCIÓN": "54.69",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "129540",
#         "TOTAL": "355540",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Morelos+24+Departamento+A+403+Edificio+7+Fraccionamiento+Santa+Clara+Ecatepec+De+Morelos+Ecatepec+De+Morelos+Estado+De+Mexico,+nan,+Ecatepec+De+Morelos,+Estado+De+Mexico,+55530",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Morelos 24 Departamento A 402 Edificio 7 Fraccionamiento Santa Clara Ecatepec De Morelos Ecatepec De Morelos Estado De Mexico",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Ecatepec De Morelos",
#         "ESTADO": "Estado De Mexico",
#         "CP": 55530,
#         "TERRENO": "54.69",
#         "CONSTRUCCIÓN": "54.69",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "129540",
#         "TOTAL": "355540",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Morelos+24+Departamento+A+402+Edificio+7+Fraccionamiento+Santa+Clara+Ecatepec+De+Morelos+Ecatepec+De+Morelos+Estado+De+Mexico,+nan,+Ecatepec+De+Morelos,+Estado+De+Mexico,+55530",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Morelos 24 Departamento A 4 Edificio 7 Fraccionamiento Santa Clara Ecatepec De Morelos Ecatepec De Morelos Estado De Mexico",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Ecatepec De Morelos",
#         "ESTADO": "Estado De Mexico",
#         "CP": 55530,
#         "TERRENO": "54.69",
#         "CONSTRUCCIÓN": "54.69",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "129540",
#         "TOTAL": "355540",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Morelos+24+Departamento+A+4+Edificio+7+Fraccionamiento+Santa+Clara+Ecatepec+De+Morelos+Ecatepec+De+Morelos+Estado+De+Mexico,+nan,+Ecatepec+De+Morelos,+Estado+De+Mexico,+55530",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
# ...
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=San+Luis+Número+18,+Continuacion+De+Boulevard+Tultitlan+Ote.+Calle+Interior+Mision+De+Autlan+Casa+Número+18,+Lote+13,+Manzana+11.+Segun+Escrituras+Conjunto+Hab.+Misiones+Número+68,+De+La+Avenida+Seis,+Condominio+11,+Vivienda+51+Lt.+13,+Manzana+11,,+Rancho+San+Blas,+Cuautitlán,+México,+54870",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Nopal # 119 Edificio B Departamento 503",
#         "COLONIA": "Atlampa",
#         "ALCALDIA/MUNICIPIO": null,
#         "ESTADO": "Estado De Mexico",
#         "CP": 50000,
#         "TERRENO": "45.15",
#         "CONSTRUCCIÓN": "45.15",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "330480",
#         "TOTAL": "556480",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Nopal+#+119+Edificio+B+Departamento+503,+Atlampa,+nan,+Estado+De+Mexico,+50000",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Baja California Nte, Lote 8 Manzana 21",
#         "COLONIA": "Heroica Guaymas Centro",
#         "ALCALDIA/MUNICIPIO": "Guaymas",
#         "ESTADO": "Sonora",
#         "CP": 85400,
#         "TERRENO": "249.25",
#         "CONSTRUCCIÓN": "128",
#         "RECAMARAS": 3,
#         "SANITARIOS": 2,
#         "ESTACIONAMIENTOS": 2,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "195840",
#         "TOTAL": "421840",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Baja+California+Nte,+Lote+8+Manzana+21,+Heroica+Guaymas+Centro,+Guaymas,+Sonora,+85400",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Los Arboles #29, Edificio A, Departamento 204",
#         "COLONIA": "Tlalnepantla  Centro",
#         "ALCALDIA/MUNICIPIO": "Tlalnepantla De Baz",
#         "ESTADO": "México",
#         "CP": 54000,
#         "TERRENO": "0",
#         "CONSTRUCCIÓN": "57.6",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "388620",
#         "TOTAL": "614620",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Los+Arboles+#29,+Edificio+A,+Departamento+204,+Tlalnepantla+Centro,+Tlalnepantla+De+Baz,+México,+54000",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Aquiles Serdan # 115 Pte, Departamento \"D\".",
#         "COLONIA": "Tampico Centro",
#         "ALCALDIA/MUNICIPIO": "Tampico",
#         "ESTADO": "Tamaulipas",
#         "CP": 89000,
#         "TERRENO": "40.06",
#         "CONSTRUCCIÓN": "78.5",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1.5,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "65280",
#         "TOTAL": "291280",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Aquiles+Serdan+#+115+Pte,+Departamento+D.,+Tampico+Centro,+Tampico,+Tamaulipas,+89000",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Paseo De La Herradura # 5, Local Comercial Az E 2 Centro Comercial Interlomas",
#         "COLONIA": "Revisar Villa De Las Lomas",
#         "ALCALDIA/MUNICIPIO": "Revisar Huixquilucan",
#         "ESTADO": "Revisar México",
#         "CP": 52787,
#         "TERRENO": "14.41",
#         "CONSTRUCCIÓN": "28.83",
#         "RECAMARAS": 1,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "308040",
#         "TOTAL": "534040",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Paseo+De+La+Herradura+#+5,+Local+Comercial+Az+E+2+Centro+Comercial+Interlomas,+Revisar+Villa+De+Las+Lomas,+Revisar+Huixquilucan,+Revisar+México,+52787",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Paseo De Las Privanzas Del Conjunto Denominado Portugal 2 Fraccionamiento Residencial Privanzas Monclova Monclova Coahuila",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Monclova",
#         "ESTADO": "Coahuila",
#         "CP": 25700,
#         "TERRENO": "154.13",
#         "CONSTRUCCIÓN": "90",
#         "RECAMARAS": 3,
#         "SANITARIOS": 1.5,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 395000,
#         "2DO_PAGO": "591600",
#         "TOTAL": "986600",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Paseo+De+Las+Privanzas+Del+Conjunto+Denominado+Portugal+2+Fraccionamiento+Residencial+Privanzas+Monclova+Monclova+Coahuila,+nan,+Monclova,+Coahuila,+25700",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Sexta , Fraccion Del Solar B 636 119 Colonia Centro Cuauhtemoc Cuauhtemoc Chihuahua",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Cuauhtemoc",
#         "ESTADO": "Chihuahua",
#         "CP": 31500,
#         "TERRENO": "150",
#         "CONSTRUCCIÓN": "147.8",
#         "RECAMARAS": 3,
#         "SANITARIOS": 2,
#         "ESTACIONAMIENTOS": 2,
#         "1ER_PAGO": 395000,
#         "2DO_PAGO": "850800",
#         "TOTAL": "1245800",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Sexta+,+Fraccion+Del+Solar+B+636+119+Colonia+Centro+Cuauhtemoc+Cuauhtemoc+Chihuahua,+nan,+Cuauhtemoc,+Chihuahua,+31500",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Tollocan Código Postal 55120 Casa 42 21 545 Fraccionamiento Azteca Ecatepec Ecatepec Código Postal 55120 Estado De Mexico",
#         "COLONIA": null,
#         "ALCALDIA/MUNICIPIO": "Ecatepec De Morelos",
#         "ESTADO": "Estado De Mexico",
#         "CP": 55120,
#         "TERRENO": "122.5",
#         "CONSTRUCCIÓN": "170",
#         "RECAMARAS": 3,
#         "SANITARIOS": 2.5,
#         "ESTACIONAMIENTOS": 2,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "494700",
#         "TOTAL": "720700",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Tollocan+Código+Postal+55120+Casa+42+21+545+Fraccionamiento+Azteca+Ecatepec+Ecatepec+Código+Postal+55120+Estado+De+Mexico,+nan,+Ecatepec+De+Morelos,+Estado+De+Mexico,+55120",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Antimonio L16 Manzana 9, 477, , Cruz Del Aire, Saltillo, Coahuila",
#         "COLONIA": "Cruz Del Aire",
#         "ALCALDIA/MUNICIPIO": "Saltillo",
#         "ESTADO": "Coahuila De Zaragoza",
#         "CP": 25296,
#         "TERRENO": "209",
#         "CONSTRUCCIÓN": "167.5",
#         "RECAMARAS": 3,
#         "SANITARIOS": 2.5,
#         "ESTACIONAMIENTOS": 2,
#         "1ER_PAGO": 395000,
#         "2DO_PAGO": "723180",
#         "TOTAL": "1118180",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Antimonio+L16+Manzana+9,+477,+,+Cruz+Del+Aire,+Saltillo,+Coahuila,+Cruz+Del+Aire,+Saltillo,+Coahuila+De+Zaragoza,+25296",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Magnolia 468, Las Flores, Morelia Michoacan",
#         "COLONIA": "Las Flores",
#         "ALCALDIA/MUNICIPIO": "Morelia",
#         "ESTADO": "Michoacán De Ocampo",
#         "CP": 58338,
#         "TERRENO": "133",
#         "CONSTRUCCIÓN": "200",
#         "RECAMARAS": 3,
#         "SANITARIOS": 2.5,
#         "ESTACIONAMIENTOS": 2,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "147900",
#         "TOTAL": "373900",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Magnolia+468,+Las+Flores,+Morelia+Michoacan,+Las+Flores,+Morelia,+Michoacán+De+Ocampo,+58338",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Valle Del Rhin, 323, L29 M60, Valle Del Contry, Guadalupe, Nuevo Leon",
#         "COLONIA": "Valle Del Contry",
#         "ALCALDIA/MUNICIPIO": "Guadalupe",
#         "ESTADO": "Nuevo León",
#         "CP": 67174,
#         "TERRENO": "180",
#         "CONSTRUCCIÓN": "92",
#         "RECAMARAS": 3,
#         "SANITARIOS": 1.5,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 395000,
#         "2DO_PAGO": "1167900",
#         "TOTAL": "1562900",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Valle+Del+Rhin,+323,+L29+M60,+Valle+Del+Contry,+Guadalupe,+Nuevo+Leon,+Valle+Del+Contry,+Guadalupe,+Nuevo+León,+67174",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "N 7 Lote 31 Manzana 36, 461, , Metroplex 1, Apodaca, Nuevo Leon",
#         "COLONIA": "Metroplex",
#         "ALCALDIA/MUNICIPIO": "Apodaca",
#         "ESTADO": "Nuevo León",
#         "CP": 66612,
#         "TERRENO": "85",
#         "CONSTRUCCIÓN": "145",
#         "RECAMARAS": 3,
#         "SANITARIOS": 2,
#         "ESTACIONAMIENTOS": 2,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "497760",
#         "TOTAL": "723760",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=N+7+Lote+31+Manzana+36,+461,+,+Metroplex+1,+Apodaca,+Nuevo+Leon,+Metroplex,+Apodaca,+Nuevo+León,+66612",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Claveles Lote 28 M212, 607, , Los Girasoles, Gral. Escobedo, Nuevo Leon",
#         "COLONIA": "Lomas De Escobedo",
#         "ALCALDIA/MUNICIPIO": "General Escobedo",
#         "ESTADO": "Nuevo León",
#         "CP": 66056,
#         "TERRENO": "90",
#         "CONSTRUCCIÓN": "62",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "162180",
#         "TOTAL": "388180",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Claveles+Lote+28+M212,+607,+,+Los+Girasoles,+Gral.+Escobedo,+Nuevo+Leon,+Lomas+De+Escobedo,+General+Escobedo,+Nuevo+León,+66056",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Avenida Casa Blanca L012 Manzana 261, 622, , Villas De Casa Blanca, San Nicolas De Los Garza, Nuevo Leon",
#         "COLONIA": "Villas De Casa Blanca",
#         "ALCALDIA/MUNICIPIO": "San Nicolás De Los Garza",
#         "ESTADO": "Nuevo León",
#         "CP": 66475,
#         "TERRENO": "140",
#         "CONSTRUCCIÓN": "152",
#         "RECAMARAS": 3,
#         "SANITARIOS": 2,
#         "ESTACIONAMIENTOS": 2,
#         "1ER_PAGO": 395000,
#         "2DO_PAGO": "680340",
#         "TOTAL": "1075340",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Avenida+Casa+Blanca+L012+Manzana+261,+622,+,+Villas+De+Casa+Blanca,+San+Nicolas+De+Los+Garza,+Nuevo+Leon,+Villas+De+Casa+Blanca,+San+Nicolás+De+Los+Garza,+Nuevo+León,+66475",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     },
#     {
#         "LISTA": "MONESIS GLOBAL",
#         "FOTOS": null,
#         "FICHAS": null,
#         "FOLIO": 2147483648,
#         "TIPO": null,
#         "CALLE_Y_NUMERO": "Hacienda De Palo Seco L15 Manzana 162, 330, , Hacienda Del Topo, Gral. Escobedo, Nuevo Leon",
#         "COLONIA": "Hacienda Del Topo",
#         "ALCALDIA/MUNICIPIO": "General Escobedo",
#         "ESTADO": "Nuevo León",
#         "CP": 66072,
#         "TERRENO": "85.8",
#         "CONSTRUCCIÓN": "60",
#         "RECAMARAS": 2,
#         "SANITARIOS": 1,
#         "ESTACIONAMIENTOS": 1,
#         "1ER_PAGO": 226000,
#         "2DO_PAGO": "154020",
#         "TOTAL": "380020",
#         "VALOR_APROX": null,
#         "ALREDEDORES": null,
#         "GOOGLE_MAPS": "https://www.google.com/maps/search/?api=1&query=Hacienda+De+Palo+Seco+L15+Manzana+162,+330,+,+Hacienda+Del+Topo,+Gral.+Escobedo,+Nuevo+Leon,+Hacienda+Del+Topo,+General+Escobedo,+Nuevo+León,+66072",
#         "CALIF": null,
#         "CALIF_EV": null,
#         "LATITUD": null,
#         "LONGITUD": null,
#         "ETAPA": "ADJUDICADA",
#         "ESTADO_DE_VIVIENDA": null
#     }
# ]
