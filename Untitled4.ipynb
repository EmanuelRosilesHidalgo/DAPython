# %%
from sklearn.datasets import load_iris
import pandas as pd
import seaborn as sns

# %%
iris = load_iris()

# %%
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_df['target'] = iris.target
iris_df = iris_df.rename(columns={'petal length (cm)': 'petal length'})
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length  petal width (cm)
# 0                  5.1               3.5           1.4               0.2  \
# 1                  4.9               3.0           1.4               0.2
# 2                  4.7               3.2           1.3               0.2
# 3                  4.6               3.1           1.5               0.2
# 4                  5.0               3.6           1.4               0.2
# ..                 ...               ...           ...               ...
# 145                6.7               3.0           5.2               2.3
# 146                6.3               2.5           5.0               1.9
# 147                6.5               3.0           5.2               2.0
# 148                6.2               3.4           5.4               2.3
# 149                5.9               3.0           5.1               1.8
#
#      target
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ...

# %%
x_axis = iris_df.index
y_axis = iris_df['petal length']
sns.scatterplot(x=x_axis, y=y_axis, hue=iris_df['target'])
# Out:
# <Axes: ylabel='petal length'>
