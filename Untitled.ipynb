# %%
# Out:
#   Cell In[1], line 1
#     <h1>Dataframe</h1>
#     ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np

# %%
lista = [[1,2,3], [4,5,6]]

# %%
df = pd.DataFrame(lista, columns = ['Edad', 'Rango', 'Si'])

df
# Out:
#    Edad  Rango  Si
# 0     1      2   3
# 1     4      5   6

# %%
array = np.array([[1, 2, 3], [3,4,5], [6,7,8]])
array

arraySuma = array + 3

arraySuma
# Out:
# array([[ 4,  5,  6],
#        [ 6,  7,  8],
#        [ 9, 10, 11]])

# %%
df2 = pd.DataFrame(arraySuma)
df2
# Out:
#    0   1   2
# 0  4   5   6
# 1  6   7   8
# 2  9  10  11

# %%
diccionario = {'Nombres':['Emanuel', 'Yineth'], 'Edad':[22, 20]}
df3 = pd.DataFrame(diccionario)
df3
# Out:
#    Nombres  Edad
# 0  Emanuel    22
# 1   Yineth    20

# %%
df3.set_index('Nombres')
# Out:
#          Edad
# Nombres
# Emanuel    22
# Yineth     20

# %%
consulta = df3['Nombres'] == 'Yineth'
df3[consulta]
# Out:
#   Nombres  Edad
# 1  Yineth    20

# %%
pokemon = pd.read_csv('Pokemon.csv')

pokemon
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49  \
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
iniciales = pokemon.loc[0:9, ['Name', 'Total']]
iniciales
# Out:
#                         Name  Total
# 0                  Bulbasaur    318
# 1                    Ivysaur    405
# 2                   Venusaur    525
# 3      VenusaurMega Venusaur    625
# 4                 Charmander    309
# 5                 Charmeleon    405
# 6                  Charizard    534
# 7  CharizardMega Charizard X    634
# 8  CharizardMega Charizard Y    634
# 9                   Squirtle    314

# %%
pokemon2 = pokemon.set_index('Type 1')
pokemon2
# Out:
#            #                   Name  Type 2  Total  HP  Attack  Defense
# Type 1
# Grass      1              Bulbasaur  Poison    318  45      49       49  \
# Grass      2                Ivysaur  Poison    405  60      62       63
# Grass      3               Venusaur  Poison    525  80      82       83
# Grass      3  VenusaurMega Venusaur  Poison    625  80     100      123
# Fire       4             Charmander     NaN    309  39      52       43
# ...      ...                    ...     ...    ...  ..     ...      ...
# Rock     719                Diancie   Fairy    600  50     100      150
# Rock     719    DiancieMega Diancie   Fairy    700  50     160      110
# Psychic  720    HoopaHoopa Confined   Ghost    600  80     110       60
# Psychic  720     HoopaHoopa Unbound    Dark    680  80     160       60
# Fire     721              Volcanion   Water    600  80     110      120
#
#          Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Type 1
# ...

# %%
#cond1 = pokemon['Attack'] > 100
legendary = pokemon[pokemon['Legendary'] == True]

# %%
type(legendary)
# Out:
# pandas.core.frame.DataFrame

# %%
legendary.head()
# Out:
#        #                 Name    Type 1    Type 2  Total   HP  Attack
# 156  144             Articuno       Ice    Flying    580   90      85  \
# 157  145               Zapdos  Electric    Flying    580   90      90
# 158  146              Moltres      Fire    Flying    580   90     100
# 162  150               Mewtwo   Psychic       NaN    680  106     110
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 156      100       95      125     85           1       True
# 157       85      125       90    100           1       True
# 158       90      125       85     90           1       True
# 162       90      154       90    130           1       True
# 163      100      154      100    130           1       True

# %%
legendary.loc[156:163, 'Name':'Speed']
# Out:
#                     Name    Type 1    Type 2  Total   HP  Attack  Defense
# 156             Articuno       Ice    Flying    580   90      85      100  \
# 157               Zapdos  Electric    Flying    580   90      90       85
# 158              Moltres      Fire    Flying    580   90     100       90
# 162               Mewtwo   Psychic       NaN    680  106     110       90
# 163  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190      100
#
#      Sp. Atk  Sp. Def  Speed
# 156       95      125     85
# 157      125       90    100
# 158      125       85     90
# 162      154       90    130
# 163      154      100    130

# %%
pokemon.loc[801] = [801, 'Emanuel', 'Grass', 'Flying', 500, 100, 54, 52, 85, 822, 65, 9, False]
pokemon
# Out:
#        #                   Name   Type 1  Type 2  Total   HP  Attack  Defense
# 0      1              Bulbasaur    Grass  Poison    318   45      49       49  \
# 1      2                Ivysaur    Grass  Poison    405   60      62       63
# 2      3               Venusaur    Grass  Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625   80     100      123
# 4      4             Charmander     Fire     NaN    309   39      52       43
# ..   ...                    ...      ...     ...    ...  ...     ...      ...
# 796  719    DiancieMega Diancie     Rock   Fairy    700   50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
# 799  721              Volcanion     Fire   Water    600   80     110      120
# 801  801                Emanuel    Grass  Flying    500  100      54       52
#
# ...

# %%
pokemon.sort_values(by = 'Attack', ascending = False)
# Out:
#        #                     Name   Type 1    Type 2  Total   HP  Attack
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190  \
# 232  214  HeracrossMega Heracross      Bug  Fighting    600   80     185
# 424  383    GroudonPrimal Groudon   Ground      Fire    770  100     180
# 429  386       DeoxysAttack Forme  Psychic       NaN    600   50     180
# 426  384    RayquazaMega Rayquaza   Dragon    Flying    780  105     180
# ..   ...                      ...      ...       ...    ...  ...     ...
# 261  242                  Blissey   Normal       NaN    540  255      10
# 230  213                  Shuckle      Bug      Rock    505   20      10
# 139  129                 Magikarp    Water       NaN    200   20      10
# 488  440                  Happiny   Normal       NaN    220  100       5
# 121  113                  Chansey   Normal       NaN    450  250       5
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
pokemon
# Out:
#        #                   Name   Type 1  Type 2  Total   HP  Attack  Defense
# 0      1              Bulbasaur    Grass  Poison    318   45      49       49  \
# 1      2                Ivysaur    Grass  Poison    405   60      62       63
# 2      3               Venusaur    Grass  Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625   80     100      123
# 4      4             Charmander     Fire     NaN    309   39      52       43
# ..   ...                    ...      ...     ...    ...  ...     ...      ...
# 796  719    DiancieMega Diancie     Rock   Fairy    700   50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
# 799  721              Volcanion     Fire   Water    600   80     110      120
# 801  801                Emanuel    Grass  Flying    500  100      54       52
#
# ...

# %%
tipo1 =pokemon.groupby(pokemon['Generation']).mean()
tipo1
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File D:\Program Files\Python39\Lib\site-packages\pandas\core\groupby\groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File D:\Program Files\Python39\Lib\site-packages\pandas\core\groupby\ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958 ngroups = self.ngroups
# ...

# %%
pokemon['Type 1'].value_counts()
# Out:
# Type 1
# Water       112
# Normal       98
# Grass        71
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: count, dtype: int64
