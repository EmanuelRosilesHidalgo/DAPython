# %%
import matplotlib.pyplot as plt

# %%
x = [4, 7, 2]
y = [7, 5, 2]

plt.plot(x, y)
plt.title("Grafico")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend(['Linea'])

# %%
lista = [1, 4, 6, 9]
plt.hist(lista, [1, 2, 3, 4])
# Out:
# (array([1., 0., 1.]),
#  array([1., 2., 3., 4.]),
#  <BarContainer object of 3 artists>)

# %%
lista = [1, 4, 2, 9]
plt.bar(lista, [10, 9, 8, 7])
# Out:
# <BarContainer object of 4 artists>

# %%
lista = [25, 40, 15, 20]
plt.pie(lista, labels = ['a', 'b', 'c', 'd'], explode = [0.1, 0.1, 0.1, 0.1])
# Out:
# ([<matplotlib.patches.Wedge at 0x14cc3639790>,
# ...
#  [Text(0.8485281374238571, 0.8485281374238571, 'a'),
#   Text(-1.1412678264979264, 0.3708203718792959, 'b'),
#   Text(-0.18772129146695665, -1.1852260192596085, 'c'),
#   Text(0.9708204526849543, -0.7053422209456772, 'd')])
